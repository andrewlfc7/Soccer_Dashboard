# %%
from bs4 import  BeautifulSoup
import json
import re
import requests
from bs4 import BeautifulSoup
import pandas as pd
import sqlite3

# %%
con = sqlite3.connect("../Database/Shots22_23.db")
cur = con.cursor()

# %%
#team_id = input("Enter Team Id:")

team_fixtures = requests.get('https://www.fotmob.com/api/teams?id=8650&ccode3=USA_MA')


data = json.loads(team_fixtures.content)

#data1 = pd.DataFrame(data1)

data
# Out:
# {'tabs': ['overview',
#   'news',
#   'table',
#   'fixtures',
#   'squad',
#   'stats',
#   'transfers',
#   'history'],
#  'allAvailableSeasons': [],
#  'details': {'id': 8650,
#   'type': 'team',
#   'name': 'Liverpool',
#   'latestSeason': '2022/2023',
#   'shortName': 'Liverpool',
#   'country': 'England',
#   'faqJSONLD': {'@context': 'https://schema.org',
#    '@type': 'FAQPage',
#    'mainEntity': [{'@type': 'Question',
#      'name': "When is Liverpool's next match?",
#      'acceptedAnswer': {'@type': 'Answer',
#       'text': "Liverpool's next match is at 12:30 BST on Sat, 1 Apr 2023 against Manchester City."}},
#     {'@type': 'Question',
#      'name': "Who is Liverpool's top scorer?",
#      'acceptedAnswer': {'@type': 'Answer',
#       'text': 'Mohamed Salah has scored the most goals for Liverpool, with 11 goals.'}},
#     {'@type': 'Question',
#      'name': "Who is Liverpool's best player?",
#      'acceptedAnswer': {'@type': 'Answer',
#       'text': 'Thiago Alcántara is the top-rated player for Liverpool with a FotMob rating of 7.36.'}},
#     {'@type': 'Question',
#      'name': 'Who has the most assists for Liverpool?',
#      'acceptedAnswer': {'@type': 'Answer',
#       'text': 'Mohamed Salah has the most assists on Liverpool, with 7 assists.'}},
#     {'@type': 'Question',
#      'name': "Where is Liverpool's stadium?",
#      'acceptedAnswer': {'@type': 'Answer',
#       'text': 'Liverpool stadium is located in Liverpool and is called Anfield.'}},
#     {'@type': 'Question',
#      'name': 'What is the capacity of Anfield?',
#      'acceptedAnswer': {'@type': 'Answer',
#       'text': 'The capacity for Anfield is 55,212.'}},
#     {'@type': 'Question',
#      'name': 'When was Anfield opened?',
#      'acceptedAnswer': {'@type': 'Answer',
#       'text': 'Anfield opened in 1884.'}}]},
#   'sportsTeamJSONLD': {'@context': 'https://schema.org',
#    '@type': 'SportsTeam',
#    'name': 'Liverpool',
#    'sport': 'Football/Soccer',
#    'gender': 'https://schema.org/Male',
#    'logo': 'https://images.fotmob.com/image_resources/logo/teamlogo/8650.png',
#    'url': 'https://www.fotmob.com/teams/8650/overview/liverpool',
#    'coach': {'@context': 'https://schema.org',
#     '@type': 'Person',
#     'name': 'Jürgen Klopp',
#     'url': 'https://www.fotmob.com/players/78660/jrgen-klopp'},
#    'athlete': [{'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Adrian',
#      'url': 'https://www.fotmob.com/players/169756/adrian',
#      'nationality': {'@type': 'Country', 'name': 'Spain'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Alisson Becker',
#      'url': 'https://www.fotmob.com/players/319784/alisson-becker',
#      'nationality': {'@type': 'Country', 'name': 'Brazil'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Caoimhin Kelleher',
#      'url': 'https://www.fotmob.com/players/776689/caoimhin-kelleher',
#      'nationality': {'@type': 'Country', 'name': 'Ireland'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Joel Matip',
#      'url': 'https://www.fotmob.com/players/171698/joel-matip',
#      'nationality': {'@type': 'Country', 'name': 'Cameroon'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Virgil van Dijk',
#      'url': 'https://www.fotmob.com/players/209405/virgil-van-dijk',
#      'nationality': {'@type': 'Country', 'name': 'Netherlands'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Andrew Robertson',
#      'url': 'https://www.fotmob.com/players/357880/andrew-robertson',
#      'nationality': {'@type': 'Country', 'name': 'Scotland'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Joseph Gomez',
#      'url': 'https://www.fotmob.com/players/568571/joseph-gomez',
#      'nationality': {'@type': 'Country', 'name': 'England'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Konstantinos Tsimikas',
#      'url': 'https://www.fotmob.com/players/671529/konstantinos-tsimikas',
#      'nationality': {'@type': 'Country', 'name': 'Greece'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Trent Alexander-Arnold',
#      'url': 'https://www.fotmob.com/players/760712/trent-alexander-arnold',
#      'nationality': {'@type': 'Country', 'name': 'England'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Ibrahima Konaté',
#      'url': 'https://www.fotmob.com/players/820140/ibrahima-konat',
#      'nationality': {'@type': 'Country', 'name': 'France'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Nathaniel Phillips',
#      'url': 'https://www.fotmob.com/players/948567/nathaniel-phillips',
#      'nationality': {'@type': 'Country', 'name': 'England'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Calvin Ramsay',
#      'url': 'https://www.fotmob.com/players/1076952/calvin-ramsay',
#      'nationality': {'@type': 'Country', 'name': 'Scotland'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Rhys Williams',
#      'url': 'https://www.fotmob.com/players/1081076/rhys-williams',
#      'nationality': {'@type': 'Country', 'name': 'England'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'James Milner',
#      'url': 'https://www.fotmob.com/players/38807/james-milner',
#      'nationality': {'@type': 'Country', 'name': 'England'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Jordan Henderson',
#      'url': 'https://www.fotmob.com/players/156008/jordan-henderson',
#      'nationality': {'@type': 'Country', 'name': 'England'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Thiago Alcántara',
#      'url': 'https://www.fotmob.com/players/172949/thiago-alcntara',
#      'nationality': {'@type': 'Country', 'name': 'Spain'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Fabinho',
#      'url': 'https://www.fotmob.com/players/359188/fabinho',
#      'nationality': {'@type': 'Country', 'name': 'Brazil'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Naby Keita',
#      'url': 'https://www.fotmob.com/players/508889/naby-keita',
#      'nationality': {'@type': 'Country', 'name': 'Guinea'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Arthur',
#      'url': 'https://www.fotmob.com/players/654044/arthur',
#      'nationality': {'@type': 'Country', 'name': 'Brazil'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Curtis Jones',
#      'url': 'https://www.fotmob.com/players/933768/curtis-jones',
#      'nationality': {'@type': 'Country', 'name': 'England'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Harvey Elliott',
#      'url': 'https://www.fotmob.com/players/963964/harvey-elliott',
#      'nationality': {'@type': 'Country', 'name': 'England'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Fabio Carvalho',
#      'url': 'https://www.fotmob.com/players/963965/fabio-carvalho',
#      'nationality': {'@type': 'Country', 'name': 'Portugal'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Stefan Bajcetic',
#      'url': 'https://www.fotmob.com/players/1310118/stefan-bajcetic',
#      'nationality': {'@type': 'Country', 'name': 'Spain'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Alex Oxlade-Chamberlain',
#      'url': 'https://www.fotmob.com/players/196386/alex-oxlade-chamberlain',
#      'nationality': {'@type': 'Country', 'name': 'England'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Roberto Firmino',
#      'url': 'https://www.fotmob.com/players/242709/roberto-firmino',
#      'nationality': {'@type': 'Country', 'name': 'Brazil'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Mohamed Salah',
#      'url': 'https://www.fotmob.com/players/292462/mohamed-salah',
#      'nationality': {'@type': 'Country', 'name': 'Egypt'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Diogo Jota',
#      'url': 'https://www.fotmob.com/players/570461/diogo-jota',
#      'nationality': {'@type': 'Country', 'name': 'Portugal'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Cody Gakpo',
#      'url': 'https://www.fotmob.com/players/806552/cody-gakpo',
#      'nationality': {'@type': 'Country', 'name': 'Netherlands'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Luis Diaz',
#      'url': 'https://www.fotmob.com/players/860914/luis-diaz',
#      'nationality': {'@type': 'Country', 'name': 'Colombia'}},
#     {'@context': 'https://schema.org',
#      '@type': 'Person',
#      'name': 'Darwin Nunez',
#      'url': 'https://www.fotmob.com/players/950561/darwin-nunez',
#      'nationality': {'@type': 'Country', 'name': 'Uruguay'}}],
#    'location': {'@type': 'Place',
#     'name': 'Anfield',
#     'address': {'@type': 'PostalAddress',
#      'addressCountry': 'England',
#      'addressLocality': 'Liverpool'},
#     'geo': {'@type': 'GeoCoordinates',
#      'latitude': '53.430828',
#      'longitude': '-2.960853'}},
#    'memberOf': {'@type': 'SportsOrganization',
#     'name': 'Premier League',
#     'url': 'https://www.fotmob.com/leagues/47/overview/premier-league'}},
#   'breadcrumbJSONLD': {'@context': 'https://schema.org',
#    '@type': 'BreadcrumbList',
#    'itemListElement': [{'@type': 'ListItem',
#      'position': 1,
#      'name': 'Home',
#      'item': 'https://www.fotmob.com'},
#     {'@type': 'ListItem',
#      'position': 2,
#      'name': 'Premier League',
#      'item': 'https://www.fotmob.com/leagues/47/overview/premier-league'},
#     {'@type': 'ListItem',
#      'position': 3,
#      'name': 'Liverpool',
#      'item': 'https://www.fotmob.com/teams/8650/overview/liverpool'}]},
#   'canSyncCalendar': True},
#  'seostr': 'liverpool',
#  'QAData': [{'question': "When is Liverpool's next match?",
#    'answer': "Liverpool's next match is at 12:30 BST on Sat, 1 Apr 2023 against Manchester City."},
#   {'question': "Who is Liverpool's top scorer?",
#    'answer': 'Mohamed Salah has scored the most goals for Liverpool, with 11 goals.'},
#   {'question': "Who is Liverpool's best player?",
#    'answer': 'Thiago Alcántara is the top-rated player for Liverpool with a FotMob rating of 7.36.'},
#   {'question': 'Who has the most assists for Liverpool?',
#    'answer': 'Mohamed Salah has the most assists on Liverpool, with 7 assists.'},
#   {'question': "Where is Liverpool's stadium?",
#    'answer': 'Liverpool stadium is located in Liverpool and is called Anfield.'},
#   {'question': 'What is the capacity of Anfield?',
#    'answer': 'The capacity for Anfield is 55,212.'},
#   {'question': 'When was Anfield opened?',
#    'answer': 'Anfield opened in 1884.'}],
#  'table': [{'data': {'ccode': 'ENG',
#     'leagueId': 47,
#     'pageUrl': '/leagues/47/overview/premier-league',
#     'leagueName': 'Premier League',
#     'legend': [{'title': 'Champions League',
#       'color': '#2AD572',
#       'indices': [0, 1, 2, 3]},
#      {'title': 'Europa League', 'color': '#0046A7', 'indices': [4]},
#      {'title': 'Relegation', 'color': '#FF4646', 'indices': [17, 18, 19]}],
#     'ongoing': [],
#     'table': {'all': [{'name': 'Arsenal',
#        'shortName': 'Arsenal',
#        'id': 9825,
#        'pageUrl': '/teams/9825/overview/arsenal',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 28,
#        'wins': 22,
#        'draws': 3,
#        'losses': 3,
#        'scoresStr': '66-26',
#        'goalConDiff': 40,
#        'pts': 69,
#        'idx': 1,
#        'qualColor': '#2AD572'},
#       {'name': 'Manchester City',
#        'shortName': 'Man City',
#        'id': 8456,
#        'pageUrl': '/teams/8456/overview/manchester-city',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 27,
#        'wins': 19,
#        'draws': 4,
#        'losses': 4,
#        'scoresStr': '67-25',
#        'goalConDiff': 42,
#        'pts': 61,
#        'idx': 2,
#        'qualColor': '#2AD572'},
#       {'name': 'Manchester United',
#        'shortName': 'Man United',
#        'id': 10260,
#        'pageUrl': '/teams/10260/overview/manchester-united',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 26,
#        'wins': 15,
#        'draws': 5,
#        'losses': 6,
#        'scoresStr': '41-35',
#        'goalConDiff': 6,
#        'pts': 50,
#        'idx': 3,
#        'qualColor': '#2AD572'},
#       {'name': 'Tottenham Hotspur',
#        'shortName': 'Tottenham',
#        'id': 8586,
#        'pageUrl': '/teams/8586/overview/tottenham-hotspur',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 28,
#        'wins': 15,
#        'draws': 4,
#        'losses': 9,
#        'scoresStr': '52-40',
#        'goalConDiff': 12,
#        'pts': 49,
#        'idx': 4,
#        'qualColor': '#2AD572'},
#       {'name': 'Newcastle United',
#        'shortName': 'Newcastle',
#        'id': 10261,
#        'pageUrl': '/teams/10261/overview/newcastle-united',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 26,
#        'wins': 12,
#        'draws': 11,
#        'losses': 3,
#        'scoresStr': '39-19',
#        'goalConDiff': 20,
#        'pts': 47,
#        'idx': 5,
#        'qualColor': '#0046A7'},
#       {'name': 'Liverpool',
#        'shortName': 'Liverpool',
#        'id': 8650,
#        'pageUrl': '/teams/8650/overview/liverpool',
#        'featuredInMatch': True,
#        'deduction': None,
#        'ongoing': None,
#        'played': 26,
#        'wins': 12,
#        'draws': 6,
#        'losses': 8,
#        'scoresStr': '47-29',
#        'goalConDiff': 18,
#        'pts': 42,
#        'idx': 6,
#        'qualColor': None},
#       {'name': 'Brighton & Hove Albion',
#        'shortName': 'Brighton',
#        'id': 10204,
#        'pageUrl': '/teams/10204/overview/brighton--hove-albion',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 25,
#        'wins': 12,
#        'draws': 6,
#        'losses': 7,
#        'scoresStr': '46-31',
#        'goalConDiff': 15,
#        'pts': 42,
#        'idx': 7,
#        'qualColor': None},
#       {'name': 'Brentford',
#        'shortName': 'Brentford',
#        'id': 9937,
#        'pageUrl': '/teams/9937/overview/brentford',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 27,
#        'wins': 10,
#        'draws': 12,
#        'losses': 5,
#        'scoresStr': '43-34',
#        'goalConDiff': 9,
#        'pts': 42,
#        'idx': 8,
#        'qualColor': None},
#       {'name': 'Fulham',
#        'shortName': 'Fulham',
#        'id': 9879,
#        'pageUrl': '/teams/9879/overview/fulham',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 27,
#        'wins': 11,
#        'draws': 6,
#        'losses': 10,
#        'scoresStr': '38-37',
#        'goalConDiff': 1,
#        'pts': 39,
#        'idx': 9,
#        'qualColor': None},
#       {'name': 'Chelsea',
#        'shortName': 'Chelsea',
#        'id': 8455,
#        'pageUrl': '/teams/8455/overview/chelsea',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 27,
#        'wins': 10,
#        'draws': 8,
#        'losses': 9,
#        'scoresStr': '29-28',
#        'goalConDiff': 1,
#        'pts': 38,
#        'idx': 10,
#        'qualColor': None},
#       {'name': 'Aston Villa',
#        'shortName': 'Aston Villa',
#        'id': 10252,
#        'pageUrl': '/teams/10252/overview/aston-villa',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 27,
#        'wins': 11,
#        'draws': 5,
#        'losses': 11,
#        'scoresStr': '35-39',
#        'goalConDiff': -4,
#        'pts': 38,
#        'idx': 11,
#        'qualColor': None},
#       {'name': 'Crystal Palace',
#        'shortName': 'Crystal Palace',
#        'id': 9826,
#        'pageUrl': '/teams/9826/overview/crystal-palace',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 28,
#        'wins': 6,
#        'draws': 9,
#        'losses': 13,
#        'scoresStr': '22-38',
#        'goalConDiff': -16,
#        'pts': 27,
#        'idx': 12,
#        'qualColor': None},
#       {'name': 'Wolverhampton Wanderers',
#        'shortName': 'Wolves',
#        'id': 8602,
#        'pageUrl': '/teams/8602/overview/wolverhampton-wanderers',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 28,
#        'wins': 7,
#        'draws': 6,
#        'losses': 15,
#        'scoresStr': '22-41',
#        'goalConDiff': -19,
#        'pts': 27,
#        'idx': 13,
#        'qualColor': None},
#       {'name': 'Leeds United',
#        'shortName': 'Leeds',
#        'id': 8463,
#        'pageUrl': '/teams/8463/overview/leeds-united',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 27,
#        'wins': 6,
#        'draws': 8,
#        'losses': 13,
#        'scoresStr': '35-44',
#        'goalConDiff': -9,
#        'pts': 26,
#        'idx': 14,
#        'qualColor': None},
#       {'name': 'Everton',
#        'shortName': 'Everton',
#        'id': 8668,
#        'pageUrl': '/teams/8668/overview/everton',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 28,
#        'wins': 6,
#        'draws': 8,
#        'losses': 14,
#        'scoresStr': '22-40',
#        'goalConDiff': -18,
#        'pts': 26,
#        'idx': 15,
#        'qualColor': None},
#       {'name': 'Nottingham Forest',
#        'shortName': 'Nottm Forest',
#        'id': 10203,
#        'pageUrl': '/teams/10203/overview/nottingham-forest',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 27,
#        'wins': 6,
#        'draws': 8,
#        'losses': 13,
#        'scoresStr': '22-49',
#        'goalConDiff': -27,
#        'pts': 26,
#        'idx': 16,
#        'qualColor': None},
#       {'name': 'Leicester City',
#        'shortName': 'Leicester',
#        'id': 8197,
#        'pageUrl': '/teams/8197/overview/leicester-city',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 27,
#        'wins': 7,
#        'draws': 4,
#        'losses': 16,
#        'scoresStr': '38-47',
#        'goalConDiff': -9,
#        'pts': 25,
#        'idx': 17,
#        'qualColor': None},
#       {'name': 'West Ham United',
#        'shortName': 'West Ham',
#        'id': 8654,
#        'pageUrl': '/teams/8654/overview/west-ham-united',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 26,
#        'wins': 6,
#        'draws': 6,
#        'losses': 14,
#        'scoresStr': '24-34',
#        'goalConDiff': -10,
#        'pts': 24,
#        'idx': 18,
#        'qualColor': '#FF4646'},
#       {'name': 'AFC Bournemouth',
#        'shortName': 'Bournemouth',
#        'id': 8678,
#        'pageUrl': '/teams/8678/overview/afc-bournemouth',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 27,
#        'wins': 6,
#        'draws': 6,
#        'losses': 15,
#        'scoresStr': '25-54',
#        'goalConDiff': -29,
#        'pts': 24,
#        'idx': 19,
#        'qualColor': '#FF4646'},
#       {'name': 'Southampton',
#        'shortName': 'Southampton',
#        'id': 8466,
#        'pageUrl': '/teams/8466/overview/southampton',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 28,
#        'wins': 6,
#        'draws': 5,
#        'losses': 17,
#        'scoresStr': '23-46',
#        'goalConDiff': -23,
#        'pts': 23,
#        'idx': 20,
#        'qualColor': '#FF4646'}],
#      'home': [{'name': 'Arsenal',
#        'shortName': 'Arsenal',
#        'id': 9825,
#        'pageUrl': '/teams/9825/overview/arsenal',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 14,
#        'wins': 11,
#        'draws': 2,
#        'losses': 1,
#        'scoresStr': '38-17',
#        'goalConDiff': 21,
#        'pts': 35,
#        'idx': 1,
#        'qualColor': '#2AD572'},
#       {'name': 'Manchester City',
#        'shortName': 'Man City',
#        'id': 8456,
#        'pageUrl': '/teams/8456/overview/manchester-city',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 13,
#        'wins': 11,
#        'draws': 1,
#        'losses': 1,
#        'scoresStr': '43-13',
#        'goalConDiff': 30,
#        'pts': 34,
#        'idx': 2,
#        'qualColor': '#2AD572'},
#       {'name': 'Liverpool',
#        'shortName': 'Liverpool',
#        'id': 8650,
#        'pageUrl': '/teams/8650/overview/liverpool',
#        'featuredInMatch': True,
#        'deduction': None,
#        'ongoing': None,
#        'played': 13,
#        'wins': 9,
#        'draws': 3,
#        'losses': 1,
#        'scoresStr': '34-9',
#        'goalConDiff': 25,
#        'pts': 30,
#        'idx': 3,
#        'qualColor': '#2AD572'},
#       {'name': 'Manchester United',
#        'shortName': 'Man United',
#        'id': 10260,
#        'pageUrl': '/teams/10260/overview/manchester-united',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 13,
#        'wins': 9,
#        'draws': 3,
#        'losses': 1,
#        'scoresStr': '24-8',
#        'goalConDiff': 16,
#        'pts': 30,
#        'idx': 4,
#        'qualColor': '#2AD572'},
#       {'name': 'Tottenham Hotspur',
#        'shortName': 'Tottenham',
#        'id': 8586,
#        'pageUrl': '/teams/8586/overview/tottenham-hotspur',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 14,
#        'wins': 10,
#        'draws': 0,
#        'losses': 4,
#        'scoresStr': '29-16',
#        'goalConDiff': 13,
#        'pts': 30,
#        'idx': 5,
#        'qualColor': '#0046A7'},
#       {'name': 'Brentford',
#        'shortName': 'Brentford',
#        'id': 9937,
#        'pageUrl': '/teams/9937/overview/brentford',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 14,
#        'wins': 7,
#        'draws': 6,
#        'losses': 1,
#        'scoresStr': '28-14',
#        'goalConDiff': 14,
#        'pts': 27,
#        'idx': 6,
#        'qualColor': None},
#       {'name': 'Newcastle United',
#        'shortName': 'Newcastle',
#        'id': 10261,
#        'pageUrl': '/teams/10261/overview/newcastle-united',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 13,
#        'wins': 7,
#        'draws': 5,
#        'losses': 1,
#        'scoresStr': '21-9',
#        'goalConDiff': 12,
#        'pts': 26,
#        'idx': 7,
#        'qualColor': None},
#       {'name': 'Brighton & Hove Albion',
#        'shortName': 'Brighton',
#        'id': 10204,
#        'pageUrl': '/teams/10204/overview/brighton--hove-albion',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 13,
#        'wins': 7,
#        'draws': 2,
#        'losses': 4,
#        'scoresStr': '22-11',
#        'goalConDiff': 11,
#        'pts': 23,
#        'idx': 8,
#        'qualColor': None},
#       {'name': 'Aston Villa',
#        'shortName': 'Aston Villa',
#        'id': 10252,
#        'pageUrl': '/teams/10252/overview/aston-villa',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 14,
#        'wins': 7,
#        'draws': 2,
#        'losses': 5,
#        'scoresStr': '23-19',
#        'goalConDiff': 4,
#        'pts': 23,
#        'idx': 9,
#        'qualColor': None},
#       {'name': 'Chelsea',
#        'shortName': 'Chelsea',
#        'id': 8455,
#        'pageUrl': '/teams/8455/overview/chelsea',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 13,
#        'wins': 6,
#        'draws': 4,
#        'losses': 3,
#        'scoresStr': '16-10',
#        'goalConDiff': 6,
#        'pts': 22,
#        'idx': 10,
#        'qualColor': None},
#       {'name': 'Fulham',
#        'shortName': 'Fulham',
#        'id': 9879,
#        'pageUrl': '/teams/9879/overview/fulham',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 14,
#        'wins': 6,
#        'draws': 4,
#        'losses': 4,
#        'scoresStr': '21-20',
#        'goalConDiff': 1,
#        'pts': 22,
#        'idx': 11,
#        'qualColor': None},
#       {'name': 'Nottingham Forest',
#        'shortName': 'Nottm Forest',
#        'id': 10203,
#        'pageUrl': '/teams/10203/overview/nottingham-forest',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 14,
#        'wins': 5,
#        'draws': 5,
#        'losses': 4,
#        'scoresStr': '18-17',
#        'goalConDiff': 1,
#        'pts': 20,
#        'idx': 12,
#        'qualColor': None},
#       {'name': 'West Ham United',
#        'shortName': 'West Ham',
#        'id': 8654,
#        'pageUrl': '/teams/8654/overview/west-ham-united',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 13,
#        'wins': 5,
#        'draws': 3,
#        'losses': 5,
#        'scoresStr': '17-14',
#        'goalConDiff': 3,
#        'pts': 18,
#        'idx': 13,
#        'qualColor': None},
#       {'name': 'Leeds United',
#        'shortName': 'Leeds',
#        'id': 8463,
#        'pageUrl': '/teams/8463/overview/leeds-united',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 13,
#        'wins': 4,
#        'draws': 5,
#        'losses': 4,
#        'scoresStr': '18-18',
#        'goalConDiff': 0,
#        'pts': 17,
#        'idx': 14,
#        'qualColor': None},
#       {'name': 'Everton',
#        'shortName': 'Everton',
#        'id': 8668,
#        'pageUrl': '/teams/8668/overview/everton',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 14,
#        'wins': 5,
#        'draws': 2,
#        'losses': 7,
#        'scoresStr': '12-16',
#        'goalConDiff': -4,
#        'pts': 17,
#        'idx': 15,
#        'qualColor': None},
#       {'name': 'Crystal Palace',
#        'shortName': 'Crystal Palace',
#        'id': 9826,
#        'pageUrl': '/teams/9826/overview/crystal-palace',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 14,
#        'wins': 4,
#        'draws': 5,
#        'losses': 5,
#        'scoresStr': '12-18',
#        'goalConDiff': -6,
#        'pts': 17,
#        'idx': 16,
#        'qualColor': None},
#       {'name': 'Wolverhampton Wanderers',
#        'shortName': 'Wolves',
#        'id': 8602,
#        'pageUrl': '/teams/8602/overview/wolverhampton-wanderers',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 14,
#        'wins': 5,
#        'draws': 2,
#        'losses': 7,
#        'scoresStr': '12-19',
#        'goalConDiff': -7,
#        'pts': 17,
#        'idx': 17,
#        'qualColor': None},
#       {'name': 'AFC Bournemouth',
#        'shortName': 'Bournemouth',
#        'id': 8678,
#        'pageUrl': '/teams/8678/overview/afc-bournemouth',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 13,
#        'wins': 4,
#        'draws': 4,
#        'losses': 5,
#        'scoresStr': '13-16',
#        'goalConDiff': -3,
#        'pts': 16,
#        'idx': 18,
#        'qualColor': '#FF4646'},
#       {'name': 'Leicester City',
#        'shortName': 'Leicester',
#        'id': 8197,
#        'pageUrl': '/teams/8197/overview/leicester-city',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 13,
#        'wins': 3,
#        'draws': 3,
#        'losses': 7,
#        'scoresStr': '16-17',
#        'goalConDiff': -1,
#        'pts': 12,
#        'idx': 19,
#        'qualColor': '#FF4646'},
#       {'name': 'Southampton',
#        'shortName': 'Southampton',
#        'id': 8466,
#        'pageUrl': '/teams/8466/overview/southampton',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 14,
#        'wins': 2,
#        'draws': 4,
#        'losses': 8,
#        'scoresStr': '14-24',
#        'goalConDiff': -10,
#        'pts': 10,
#        'idx': 20,
#        'qualColor': '#FF4646'}],
#      'away': [{'name': 'Arsenal',
#        'shortName': 'Arsenal',
#        'id': 9825,
#        'pageUrl': '/teams/9825/overview/arsenal',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 14,
#        'wins': 11,
#        'draws': 1,
#        'losses': 2,
#        'scoresStr': '28-9',
#        'goalConDiff': 19,
#        'pts': 34,
#        'idx': 1,
#        'qualColor': '#2AD572'},
#       {'name': 'Manchester City',
#        'shortName': 'Man City',
#        'id': 8456,
#        'pageUrl': '/teams/8456/overview/manchester-city',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 14,
#        'wins': 8,
#        'draws': 3,
#        'losses': 3,
#        'scoresStr': '24-12',
#        'goalConDiff': 12,
#        'pts': 27,
#        'idx': 2,
#        'qualColor': '#2AD572'},
#       {'name': 'Newcastle United',
#        'shortName': 'Newcastle',
#        'id': 10261,
#        'pageUrl': '/teams/10261/overview/newcastle-united',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 13,
#        'wins': 5,
#        'draws': 6,
#        'losses': 2,
#        'scoresStr': '18-10',
#        'goalConDiff': 8,
#        'pts': 21,
#        'idx': 3,
#        'qualColor': '#2AD572'},
#       {'name': 'Manchester United',
#        'shortName': 'Man United',
#        'id': 10260,
#        'pageUrl': '/teams/10260/overview/manchester-united',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 13,
#        'wins': 6,
#        'draws': 2,
#        'losses': 5,
#        'scoresStr': '17-27',
#        'goalConDiff': -10,
#        'pts': 20,
#        'idx': 4,
#        'qualColor': '#2AD572'},
#       {'name': 'Brighton & Hove Albion',
#        'shortName': 'Brighton',
#        'id': 10204,
#        'pageUrl': '/teams/10204/overview/brighton--hove-albion',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 12,
#        'wins': 5,
#        'draws': 4,
#        'losses': 3,
#        'scoresStr': '24-20',
#        'goalConDiff': 4,
#        'pts': 19,
#        'idx': 5,
#        'qualColor': '#0046A7'},
#       {'name': 'Tottenham Hotspur',
#        'shortName': 'Tottenham',
#        'id': 8586,
#        'pageUrl': '/teams/8586/overview/tottenham-hotspur',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 14,
#        'wins': 5,
#        'draws': 4,
#        'losses': 5,
#        'scoresStr': '23-24',
#        'goalConDiff': -1,
#        'pts': 19,
#        'idx': 6,
#        'qualColor': None},
#       {'name': 'Fulham',
#        'shortName': 'Fulham',
#        'id': 9879,
#        'pageUrl': '/teams/9879/overview/fulham',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 13,
#        'wins': 5,
#        'draws': 2,
#        'losses': 6,
#        'scoresStr': '17-17',
#        'goalConDiff': 0,
#        'pts': 17,
#        'idx': 7,
#        'qualColor': None},
#       {'name': 'Chelsea',
#        'shortName': 'Chelsea',
#        'id': 8455,
#        'pageUrl': '/teams/8455/overview/chelsea',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 14,
#        'wins': 4,
#        'draws': 4,
#        'losses': 6,
#        'scoresStr': '13-18',
#        'goalConDiff': -5,
#        'pts': 16,
#        'idx': 8,
#        'qualColor': None},
#       {'name': 'Brentford',
#        'shortName': 'Brentford',
#        'id': 9937,
#        'pageUrl': '/teams/9937/overview/brentford',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 13,
#        'wins': 3,
#        'draws': 6,
#        'losses': 4,
#        'scoresStr': '15-20',
#        'goalConDiff': -5,
#        'pts': 15,
#        'idx': 9,
#        'qualColor': None},
#       {'name': 'Aston Villa',
#        'shortName': 'Aston Villa',
#        'id': 10252,
#        'pageUrl': '/teams/10252/overview/aston-villa',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 13,
#        'wins': 4,
#        'draws': 3,
#        'losses': 6,
#        'scoresStr': '12-20',
#        'goalConDiff': -8,
#        'pts': 15,
#        'idx': 10,
#        'qualColor': None},
#       {'name': 'Leicester City',
#        'shortName': 'Leicester',
#        'id': 8197,
#        'pageUrl': '/teams/8197/overview/leicester-city',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 14,
#        'wins': 4,
#        'draws': 1,
#        'losses': 9,
#        'scoresStr': '22-30',
#        'goalConDiff': -8,
#        'pts': 13,
#        'idx': 11,
#        'qualColor': None},
#       {'name': 'Southampton',
#        'shortName': 'Southampton',
#        'id': 8466,
#        'pageUrl': '/teams/8466/overview/southampton',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 14,
#        'wins': 4,
#        'draws': 1,
#        'losses': 9,
#        'scoresStr': '9-22',
#        'goalConDiff': -13,
#        'pts': 13,
#        'idx': 12,
#        'qualColor': None},
#       {'name': 'Liverpool',
#        'shortName': 'Liverpool',
#        'id': 8650,
#        'pageUrl': '/teams/8650/overview/liverpool',
#        'featuredInMatch': True,
#        'deduction': None,
#        'ongoing': None,
#        'played': 13,
#        'wins': 3,
#        'draws': 3,
#        'losses': 7,
#        'scoresStr': '13-20',
#        'goalConDiff': -7,
#        'pts': 12,
#        'idx': 13,
#        'qualColor': None},
#       {'name': 'Crystal Palace',
#        'shortName': 'Crystal Palace',
#        'id': 9826,
#        'pageUrl': '/teams/9826/overview/crystal-palace',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 14,
#        'wins': 2,
#        'draws': 4,
#        'losses': 8,
#        'scoresStr': '10-20',
#        'goalConDiff': -10,
#        'pts': 10,
#        'idx': 14,
#        'qualColor': None},
#       {'name': 'Wolverhampton Wanderers',
#        'shortName': 'Wolves',
#        'id': 8602,
#        'pageUrl': '/teams/8602/overview/wolverhampton-wanderers',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 14,
#        'wins': 2,
#        'draws': 4,
#        'losses': 8,
#        'scoresStr': '10-22',
#        'goalConDiff': -12,
#        'pts': 10,
#        'idx': 15,
#        'qualColor': None},
#       {'name': 'Leeds United',
#        'shortName': 'Leeds',
#        'id': 8463,
#        'pageUrl': '/teams/8463/overview/leeds-united',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 14,
#        'wins': 2,
#        'draws': 3,
#        'losses': 9,
#        'scoresStr': '17-26',
#        'goalConDiff': -9,
#        'pts': 9,
#        'idx': 16,
#        'qualColor': None},
#       {'name': 'Everton',
#        'shortName': 'Everton',
#        'id': 8668,
#        'pageUrl': '/teams/8668/overview/everton',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 14,
#        'wins': 1,
#        'draws': 6,
#        'losses': 7,
#        'scoresStr': '10-24',
#        'goalConDiff': -14,
#        'pts': 9,
#        'idx': 17,
#        'qualColor': None},
#       {'name': 'AFC Bournemouth',
#        'shortName': 'Bournemouth',
#        'id': 8678,
#        'pageUrl': '/teams/8678/overview/afc-bournemouth',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 14,
#        'wins': 2,
#        'draws': 2,
#        'losses': 10,
#        'scoresStr': '12-38',
#        'goalConDiff': -26,
#        'pts': 8,
#        'idx': 18,
#        'qualColor': '#FF4646'},
#       {'name': 'West Ham United',
#        'shortName': 'West Ham',
#        'id': 8654,
#        'pageUrl': '/teams/8654/overview/west-ham-united',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 13,
#        'wins': 1,
#        'draws': 3,
#        'losses': 9,
#        'scoresStr': '7-20',
#        'goalConDiff': -13,
#        'pts': 6,
#        'idx': 19,
#        'qualColor': '#FF4646'},
#       {'name': 'Nottingham Forest',
#        'shortName': 'Nottm Forest',
#        'id': 10203,
#        'pageUrl': '/teams/10203/overview/nottingham-forest',
#        'featuredInMatch': False,
#        'deduction': None,
#        'ongoing': None,
#        'played': 13,
#        'wins': 1,
#        'draws': 3,
#        'losses': 9,
#        'scoresStr': '4-32',
#        'goalConDiff': -28,
#        'pts': 6,
#        'idx': 20,
#        'qualColor': '#FF4646'}],
#      'form': [{'name': 'Arsenal',
#        'shortName': 'Arsenal',
#        'featuredInMatch': False,
#        'id': 9825,
#        'pageUrl': '/teams/9825/overview/arsenal',
#        'played': 5,
#        'wins': 5,
#        'draws': 0,
#        'losses': 0,
#        'scoresStr': '15-3',
#        'goalConDiff': 12,
#        'pts': 15,
#        'ongoing': None,
#        'idx': 1,
#        'qualColor': '#2AD572'},
#       {'name': 'Manchester City',
#        'shortName': 'Man City',
#        'featuredInMatch': False,
#        'id': 8456,
#        'pageUrl': '/teams/8456/overview/manchester-city',
#        'played': 5,
#        'wins': 4,
#        'draws': 1,
#        'losses': 0,
#        'scoresStr': '11-3',
#        'goalConDiff': 8,
#        'pts': 13,
#        'ongoing': None,
#        'idx': 2,
#        'qualColor': '#2AD572'},
#       {'name': 'Liverpool',
#        'shortName': 'Liverpool',
#        'featuredInMatch': True,
#        'id': 8650,
#        'pageUrl': '/teams/8650/overview/liverpool',
#        'played': 5,
#        'wins': 3,
#        'draws': 1,
#        'losses': 1,
#        'scoresStr': '11-1',
#        'goalConDiff': 10,
#        'pts': 10,
#        'ongoing': None,
#        'idx': 3,
#        'qualColor': '#2AD572'},
#       {'name': 'Tottenham Hotspur',
#        'shortName': 'Tottenham',
#        'featuredInMatch': False,
#        'id': 8586,
#        'pageUrl': '/teams/8586/overview/tottenham-hotspur',
#        'played': 5,
#        'wins': 3,
#        'draws': 1,
#        'losses': 1,
#        'scoresStr': '10-5',
#        'goalConDiff': 5,
#        'pts': 10,
#        'ongoing': None,
#        'idx': 4,
#        'qualColor': '#2AD572'},
#       {'name': 'Aston Villa',
#        'shortName': 'Aston Villa',
#        'featuredInMatch': False,
#        'id': 10252,
#        'pageUrl': '/teams/10252/overview/aston-villa',
#        'played': 5,
#        'wins': 3,
#        'draws': 1,
#        'losses': 1,
#        'scoresStr': '9-5',
#        'goalConDiff': 4,
#        'pts': 10,
#        'ongoing': None,
#        'idx': 5,
#        'qualColor': '#0046A7'},
#       {'name': 'Brighton & Hove Albion',
#        'shortName': 'Brighton',
#        'featuredInMatch': False,
#        'id': 10204,
#        'pageUrl': '/teams/10204/overview/brighton--hove-albion',
#        'played': 5,
#        'wins': 2,
#        'draws': 2,
#        'losses': 1,
#        'scoresStr': '8-4',
#        'goalConDiff': 4,
#        'pts': 8,
#        'ongoing': None,
#        'idx': 6,
#        'qualColor': None},
#       {'name': 'Brentford',
#        'shortName': 'Brentford',
#        'featuredInMatch': False,
#        'id': 9937,
#        'pageUrl': '/teams/9937/overview/brentford',
#        'played': 5,
#        'wins': 2,
#        'draws': 2,
#        'losses': 1,
#        'scoresStr': '7-5',
#        'goalConDiff': 2,
#        'pts': 8,
#        'ongoing': None,
#        'idx': 7,
#        'qualColor': None},
#       {'name': 'Manchester United',
#        'shortName': 'Man United',
#        'featuredInMatch': False,
#        'id': 10260,
#        'pageUrl': '/teams/10260/overview/manchester-united',
#        'played': 5,
#        'wins': 2,
#        'draws': 2,
#        'losses': 1,
#        'scoresStr': '7-9',
#        'goalConDiff': -2,
#        'pts': 8,
#        'ongoing': None,
#        'idx': 8,
#        'qualColor': None},
#       {'name': 'Leeds United',
#        'shortName': 'Leeds',
#        'featuredInMatch': False,
#        'id': 8463,
#        'pageUrl': '/teams/8463/overview/leeds-united',
#        'played': 5,
#        'wins': 2,
#        'draws': 1,
#        'losses': 2,
#        'scoresStr': '7-6',
#        'goalConDiff': 1,
#        'pts': 7,
#        'ongoing': None,
#        'idx': 9,
#        'qualColor': None},
#       {'name': 'Chelsea',
#        'shortName': 'Chelsea',
#        'featuredInMatch': False,
#        'id': 8455,
#        'pageUrl': '/teams/8455/overview/chelsea',
#        'played': 5,
#        'wins': 2,
#        'draws': 1,
#        'losses': 2,
#        'scoresStr': '6-6',
#        'goalConDiff': 0,
#        'pts': 7,
#        'ongoing': None,
#        'idx': 10,
#        'qualColor': None},
#       {'name': 'Fulham',
#        'shortName': 'Fulham',
#        'featuredInMatch': False,
#        'id': 9879,
#        'pageUrl': '/teams/9879/overview/fulham',
#        'played': 5,
#        'wins': 2,
#        'draws': 1,
#        'losses': 2,
#        'scoresStr': '6-7',
#        'goalConDiff': -1,
#        'pts': 7,
#        'ongoing': None,
#        'idx': 11,
#        'qualColor': None},
#       {'name': 'Newcastle United',
#        'shortName': 'Newcastle',
#        'featuredInMatch': False,
#        'id': 10261,
#        'pageUrl': '/teams/10261/overview/newcastle-united',
#        'played': 5,
#        'wins': 2,
#        'draws': 1,
#        'losses': 2,
#        'scoresStr': '5-7',
#        'goalConDiff': -2,
#        'pts': 7,
#        'ongoing': None,
#        'idx': 12,
#        'qualColor': None},
#       {'name': 'AFC Bournemouth',
#        'shortName': 'Bournemouth',
#        'featuredInMatch': False,
#        'id': 8678,
#        'pageUrl': '/teams/8678/overview/afc-bournemouth',
#        'played': 5,
#        'wins': 2,
#        'draws': 0,
#        'losses': 3,
#        'scoresStr': '5-10',
#        'goalConDiff': -5,
#        'pts': 6,
#        'ongoing': None,
#        'idx': 13,
#        'qualColor': None},
#       {'name': 'Southampton',
#        'shortName': 'Southampton',
#        'featuredInMatch': False,
#        'id': 8466,
#        'pageUrl': '/teams/8466/overview/southampton',
#        'played': 5,
#        'wins': 1,
#        'draws': 2,
#        'losses': 2,
#        'scoresStr': '4-6',
#        'goalConDiff': -2,
#        'pts': 5,
#        'ongoing': None,
#        'idx': 14,
#        'qualColor': None},
#       {'name': 'West Ham United',
#        'shortName': 'West Ham',
#        'featuredInMatch': False,
#        'id': 8654,
#        'pageUrl': '/teams/8654/overview/west-ham-united',
#        'played': 5,
#        'wins': 1,
#        'draws': 2,
#        'losses': 2,
#        'scoresStr': '6-8',
#        'goalConDiff': -2,
#        'pts': 5,
#        'ongoing': None,
#        'idx': 15,
#        'qualColor': None},
#       {'name': 'Everton',
#        'shortName': 'Everton',
#        'featuredInMatch': False,
#        'id': 8668,
#        'pageUrl': '/teams/8668/overview/everton',
#        'played': 5,
#        'wins': 1,
#        'draws': 2,
#        'losses': 2,
#        'scoresStr': '5-10',
#        'goalConDiff': -5,
#        'pts': 5,
#        'ongoing': None,
#        'idx': 16,
#        'qualColor': None},
#       {'name': 'Wolverhampton Wanderers',
#        'shortName': 'Wolves',
#        'featuredInMatch': False,
#        'id': 8602,
#        'pageUrl': '/teams/8602/overview/wolverhampton-wanderers',
#        'played': 5,
#        'wins': 1,
#        'draws': 1,
#        'losses': 3,
#        'scoresStr': '5-9',
#        'goalConDiff': -4,
#        'pts': 4,
#        'ongoing': None,
#        'idx': 17,
#        'qualColor': None},
#       {'name': 'Nottingham Forest',
#        'shortName': 'Nottm Forest',
#        'featuredInMatch': False,
#        'id': 10203,
#        'pageUrl': '/teams/10203/overview/nottingham-forest',
#        'played': 5,
#        'wins': 0,
#        'draws': 2,
#        'losses': 3,
#        'scoresStr': '5-12',
#        'goalConDiff': -7,
#        'pts': 2,
#        'ongoing': None,
#        'idx': 18,
#        'qualColor': '#FF4646'},
#       {'name': 'Crystal Palace',
#        'shortName': 'Crystal Palace',
#        'featuredInMatch': False,
#        'id': 9826,
#        'pageUrl': '/teams/9826/overview/crystal-palace',
#        'played': 5,
#        'wins': 0,
#        'draws': 1,
#        'losses': 4,
#        'scoresStr': '1-7',
#        'goalConDiff': -6,
#        'pts': 1,
#        'ongoing': None,
#        'idx': 19,
#        'qualColor': '#FF4646'},
#       {'name': 'Leicester City',
#        'shortName': 'Leicester',
#        'featuredInMatch': False,
#        'id': 8197,
#        'pageUrl': '/teams/8197/overview/leicester-city',
#        'played': 5,
#        'wins': 0,
#        'draws': 1,
#        'losses': 4,
#        'scoresStr': '2-9',
#        'goalConDiff': -7,
#        'pts': 1,
#        'ongoing': None,
#        'idx': 20,
#        'qualColor': '#FF4646'}]},
#     'tableFilterTypes': ['all', 'home', 'away', 'form'],
#     'composite': False},
#    'teamForm': {'8197': [{'result': -1,
#       'resultString': 'L',
#       'imageUrl': 'https://images.fotmob.com/image_resources/logo/teamlogo/10260_xsmall.png',
#       'linkToMatch': '/match/3901167/matchfacts/leicester-city-vs-manchester-united',
#       'date': None,
#       'teamPageUrl': '/teams/10260/overview/manchester-united',
#       'tooltipText': {'utcTime': '2023-02-19T14:00:00.000Z',
#        'homeTeam': 'Manchester United',
#        'homeScore': 3,
#        'awayTeam': 'Leicester City',
#        'awayScore': 0},
#       'score': '3 - 0',
#       'home': {'isOurTeam': False},
#       'away': {'isOurTeam': False}},
#      {'result': -1,
#       'resultString': 'L',
#       'imageUrl': 'https://images.fotmob.com/image_resources/logo/teamlogo/9825_xsmall.png',
#       'linkToMatch': '/match/3901177/matchfacts/leicester-city-vs-arsenal',
#       'date': None,
#       'teamPageUrl': '/teams/9825/overview/arsenal',
#       'tooltipText': {'utcTime': '2023-02-25T15:00:00.000Z',
#        'homeTeam': 'Leicester City',
#        'homeScore': 0,
#        'awayTeam': 'Arsenal',
#        'awayScore': 1},
#       'score': '0 - 1',
#       'home': {'isOurTeam': False},
#       'away': {'isOurTeam': False}},
#      {'result': -1,
#       'resultString': 'L',
#       'imageUrl': 'https://images.fotmob.com/image_resources/logo/teamlogo/8466_xsmall.png',
#       'linkToMatch': '/match/3901190/matchfacts/leicester-city-vs-southampton',
#       'date': None,
#       'teamPageUrl': '/teams/8466/overview/southampton',
#       'tooltipText': {'utcTime': '2023-03-04T17:30:00.000Z',
#        'homeTeam': 'Southampton',
#        'homeScore': 1,
#        'awayTeam': 'Leicester City',
#        'awayScore': 0},
#       'score': '1 - 0',
#       'home': {'isOurTeam': False},
#       'away': {'isOurTeam': False}},
#      {'result': -1,
#       'resultString': 'L',
#       'imageUrl': 'https://images.fotmob.com/image_resources/logo/teamlogo/8455_xsmall.png',
#       'linkToMatch': '/match/3901197/matchfacts/leicester-city-vs-chelsea',
#       'date': None,
#       'teamPageUrl': '/teams/8455/overview/chelsea',
#       'tooltipText': {'utcTime': '2023-03-11T15:00:00.000Z',
#        'homeTeam': 'Leicester City',
#        'homeScore': 1,
#        'awayTeam': 'Chelsea',
#        'awayScore': 3},
#       'score': '1 - 3',
#       'home': {'isOurTeam': False},
#       'away': {'isOurTeam': False}},
#      {'result': 0,
#       'resultString': 'D',
#       'imageUrl': 'https://images.fotmob.com/image_resources/logo/teamlogo/9937_xsmall.png',
#       'linkToMatch': '/match/3901204/matchfacts/leicester-city-vs-brentford',
#       'date': None,
#       'teamPageUrl': '/teams/9937/overview/brentford',
#       'tooltipText': {'utcTime': '2023-03-18T15:00:00.000Z',
#        'homeTeam': 'Brentford',
#        'homeScore': 1,
#        'awayTeam': 'Leicester City',
#        'awayScore': 1},
#       'score': '1 - 1',
#       'home': {'isOurTeam': False},
#       'away': {'isOurTeam': False}}],
#     '8455': [{'result': -1,
#       'resultString': 'L',
#       'imageUrl': 'https://images.fotmob.com/image_resources/logo/teamlogo/8466_xsmall.png',
#       'linkToMatch': '/match/3901165/matchfacts/chelsea-vs-southampton',
#       'date': None,
#       'teamPageUrl': '/teams/8466/overview/southampton',
#       'tooltipText': {'utcTime': '2023-02-18T15:00:00.000Z',
#        'homeTeam': 'Chelsea',
#        'homeScore': 0,
#        'awayTeam': 'Southampton',
#        'awayScore': 1},
#       'score': '0 - 1',
#       'home': {'isOurTeam': False},
#       'away': {'isOurTeam': False}},
#      {'result': -1,
#       'resultString': 'L',
# ...
#      'role': 'defenders'},
#     {'id': 209405,
#      'name': 'Virgil van Dijk',
#      'ccode': 'NED',
#      'cname': 'Netherlands',
#      'role': 'defenders'},
#     {'id': 357880,
#      'name': 'Andrew Robertson',
#      'ccode': 'SCO',
#      'cname': 'Scotland',
#      'role': 'defenders'},
#     {'id': 568571,
#      'name': 'Joseph Gomez',
#      'ccode': 'ENG',
#      'cname': 'England',
#      'role': 'defenders'},
#     {'id': 671529,
#      'name': 'Konstantinos Tsimikas',
#      'ccode': 'GRE',
#      'cname': 'Greece',
#      'role': 'defenders'},
#     {'id': 760712,
#      'name': 'Trent Alexander-Arnold',
#      'ccode': 'ENG',
#      'cname': 'England',
#      'role': 'defenders'},
#     {'id': 820140,
#      'name': 'Ibrahima Konaté',
#      'ccode': 'FRA',
#      'cname': 'France',
#      'role': 'defenders'},
#     {'id': 948567,
#      'name': 'Nathaniel Phillips',
#      'ccode': 'ENG',
#      'cname': 'England',
#      'role': 'defenders'},
#     {'id': 1076952,
#      'name': 'Calvin Ramsay',
#      'ccode': 'SCO',
#      'cname': 'Scotland',
#      'isInjured': True,
#      'role': 'defenders'},
#     {'id': 1081076,
#      'name': 'Rhys Williams',
#      'ccode': 'ENG',
#      'cname': 'England',
#      'role': 'defenders'}]],
#   ['midfielders',
#    [{'id': 38807,
#      'name': 'James Milner',
#      'ccode': 'ENG',
#      'cname': 'England',
#      'role': 'midfielders'},
#     {'id': 156008,
#      'name': 'Jordan Henderson',
#      'ccode': 'ENG',
#      'cname': 'England',
#      'isInjured': True,
#      'role': 'midfielders'},
#     {'id': 172949,
#      'name': 'Thiago Alcántara',
#      'ccode': 'ESP',
#      'cname': 'Spain',
#      'isInjured': True,
#      'role': 'midfielders'},
#     {'id': 359188,
#      'name': 'Fabinho',
#      'ccode': 'BRA',
#      'cname': 'Brazil',
#      'role': 'midfielders'},
#     {'id': 508889,
#      'name': 'Naby Keita',
#      'ccode': 'GUI',
#      'cname': 'Guinea',
#      'role': 'midfielders'},
#     {'id': 654044,
#      'name': 'Arthur',
#      'ccode': 'BRA',
#      'cname': 'Brazil',
#      'role': 'midfielders'},
#     {'id': 933768,
#      'name': 'Curtis Jones',
#      'ccode': 'ENG',
#      'cname': 'England',
#      'role': 'midfielders'},
#     {'id': 963964,
#      'name': 'Harvey Elliott',
#      'ccode': 'ENG',
#      'cname': 'England',
#      'role': 'midfielders'},
#     {'id': 963965,
#      'name': 'Fabio Carvalho',
#      'ccode': 'POR',
#      'cname': 'Portugal',
#      'role': 'midfielders'},
#     {'id': 1310118,
#      'name': 'Stefan Bajcetic',
#      'ccode': 'ESP',
#      'cname': 'Spain',
#      'isInjured': True,
#      'role': 'midfielders'}]],
#   ['attackers',
#    [{'id': 196386,
#      'name': 'Alex Oxlade-Chamberlain',
#      'ccode': 'ENG',
#      'cname': 'England',
#      'role': 'attackers'},
#     {'id': 242709,
#      'name': 'Roberto Firmino',
#      'ccode': 'BRA',
#      'cname': 'Brazil',
#      'role': 'attackers'},
#     {'id': 292462,
#      'name': 'Mohamed Salah',
#      'ccode': 'EGY',
#      'cname': 'Egypt',
#      'role': 'attackers'},
#     {'id': 570461,
#      'name': 'Diogo Jota',
#      'ccode': 'POR',
#      'cname': 'Portugal',
#      'role': 'attackers'},
#     {'id': 806552,
#      'name': 'Cody Gakpo',
#      'ccode': 'NED',
#      'cname': 'Netherlands',
#      'role': 'attackers'},
#     {'id': 860914,
#      'name': 'Luis Diaz',
#      'ccode': 'COL',
#      'cname': 'Colombia',
#      'isInjured': True,
#      'role': 'attackers'},
#     {'id': 950561,
#      'name': 'Darwin Nunez',
#      'ccode': 'URU',
#      'cname': 'Uruguay',
#      'isInjured': True,
#      'role': 'attackers'}]]],
#  'history': {'trophyList': [{'name': ['Premier League'],
#     'tournamentTemplateId': ['47'],
#     'area': ['England'],
#     'ccode': ['ENG'],
#     'won': ['19'],
#     'runnerup': ['15'],
#     'season_won': ['2019/2020,1989/1990,1987/1988,1985/1986,1983/1984,1982/1983,1981/1982,1979/1980,1978/1979,1976/1977,1975/1976,1972/1973,1965/1966,1963/1964,1946/1947,1922/1923,1921/1922,1905/1906,1900/1901'],
#     'season_runnerup': ['2021/2022,2018/2019,2013/2014,2008/2009,2001/2002,1990/1991,1988/1989,1986/1987,1984/1985,1977/1978,1974/1975,1973/1974,1968/1969,1909/1910,1898/1899']},
#    {'name': ['Championship'],
#     'tournamentTemplateId': ['48'],
#     'area': ['England'],
#     'ccode': ['ENG'],
#     'won': ['4'],
#     'runnerup': ['0'],
#     'season_won': ['1961/1962,1904/1905,1895/1896,1893/1894'],
#     'season_runnerup': ['']},
#    {'name': ['Community Shield'],
#     'tournamentTemplateId': ['247'],
#     'area': ['England'],
#     'ccode': ['ENG'],
#     'won': ['16'],
#     'runnerup': ['8'],
#     'season_won': ['2022/2023,2006/2007,2001/2002,1990/1991,1989/1990,1988/1989,1986/1987,1982/1983,1980/1981,1979/1980,1977/1978,1976/1977,1974/1975,1966/1967,1965/1966,1964/1965'],
#     'season_runnerup': ['2020/2021,2019/2020,2002/2003,1992/1993,1984/1985,1983/1984,1971/1972,1922/1923']},
#    {'name': ['FA Cup'],
#     'tournamentTemplateId': ['132'],
#     'area': ['England'],
#     'ccode': ['ENG'],
#     'won': ['8'],
#     'runnerup': ['7'],
#     'season_won': ['2021/2022,2005/2006,2000/2001,1991/1992,1988/1989,1985/1986,1973/1974,1964/1965'],
#     'season_runnerup': ['2011/2012,1995/1996,1987/1988,1976/1977,1970/1971,1949/1950,1913/1914']},
#    {'name': ['EFL Cup'],
#     'tournamentTemplateId': ['133'],
#     'area': ['England'],
#     'ccode': ['ENG'],
#     'won': ['9'],
#     'runnerup': ['4'],
#     'season_won': ['2021/2022,2011/2012,2002/2003,2000/2001,1994/1995,1983/1984,1982/1983,1981/1982,1980/1981'],
#     'season_runnerup': ['2015/2016,2004/2005,1986/1987,1977/1978']},
#    {'name': ['Champions League'],
#     'tournamentTemplateId': ['42'],
#     'area': ['Europe'],
#     'ccode': ['INT'],
#     'won': ['6'],
#     'runnerup': ['4'],
#     'season_won': ['2018/2019,2004/2005,1983/1984,1980/1981,1977/1978,1976/1977'],
#     'season_runnerup': ['2021/2022,2017/2018,2006/2007,1984/1985']},
#    {'name': ['Europa League'],
#     'tournamentTemplateId': ['73'],
#     'area': ['Europe'],
#     'ccode': ['INT'],
#     'won': ['3'],
#     'runnerup': ['1'],
#     'season_won': ['2000/2001,1975/1976,1972/1973'],
#     'season_runnerup': ['2015/2016']},
#    {'name': ['UEFA Super Cup'],
#     'tournamentTemplateId': ['74'],
#     'area': ['Europe'],
#     'ccode': ['INT'],
#     'won': ['4'],
#     'runnerup': ['2'],
#     'season_won': ['2019/2020,2005/2006,2001/2002,1977/1978'],
#     'season_runnerup': ['1984/1985,1978/1979']},
#    {'name': ['FIFA Club World Cup'],
#     'tournamentTemplateId': ['78'],
#     'area': ['World'],
#     'ccode': ['INT'],
#     'won': ['1'],
#     'runnerup': ['1'],
#     'season_won': ['2019 Qatar'],
#     'season_runnerup': ['2005 Japan']},
#    {'name': ['Inter Continental Cup'],
#     'tournamentTemplateId': ['-1'],
#     'area': ['World'],
#     'ccode': ['INT'],
#     'won': ['0'],
#     'runnerup': ['2'],
#     'season_won': [''],
#     'season_runnerup': ['1984,1981']},
#    {'name': ["UEFA Cup Winners' Cup"],
#     'tournamentTemplateId': ['-1'],
#     'area': ['Europe'],
#     'ccode': ['INT'],
#     'won': ['0'],
#     'runnerup': ['1'],
#     'season_won': [''],
#     'season_runnerup': ['1965/1966']},
#    {'name': ['Audi Cup'],
#     'tournamentTemplateId': ['9675'],
#     'area': ['World'],
#     'ccode': ['INT'],
#     'won': ['0'],
#     'runnerup': ['1'],
#     'season_won': [''],
#     'season_runnerup': ['2017']},
#    {'name': ['International Champions Cup'],
#     'tournamentTemplateId': ['9408'],
#     'area': ['World'],
#     'ccode': ['INT'],
#     'won': ['0'],
#     'runnerup': ['1'],
#     'season_won': [''],
#     'season_runnerup': ['2014']},
#    {'name': ['Premier League Asia Trophy'],
#     'tournamentTemplateId': ['9543'],
#     'area': ['World'],
#     'ccode': ['INT'],
#     'won': ['1'],
#     'runnerup': ['0'],
#     'season_won': ['2017'],
#     'season_runnerup': ['']}],
#   'historicalTableData': {'divisions': [{'divisionRank': 30,
#      'name': 'Premier League',
#      'templateId': 47}],
#    'ranks': [{'stageId': 820745,
#      'tournamentName': 'Premier League',
#      'tournamentId': 5261,
#      'templateId': 47,
#      'seasonName': '2010/2011',
#      'position': 6,
#      'numberOfTeams': 20,
#      'stats': {'points': 58, 'wins': 17, 'draws': 7, 'loss': 14},
#      'tableLink': 'https://data.fotmob.com/historic/47/season/5261/table.fot',
#      'isConsecutive': True},
#     {'stageId': 824334,
#      'tournamentName': 'Premier League',
#      'tournamentId': 6118,
#      'templateId': 47,
#      'seasonName': '2011/2012',
#      'position': 8,
#      'numberOfTeams': 20,
#      'stats': {'points': 52, 'wins': 14, 'draws': 10, 'loss': 14},
#      'tableLink': 'https://data.fotmob.com/historic/47/season/6118/table.fot',
#      'isConsecutive': True},
#     {'stageId': 827652,
#      'tournamentName': 'Premier League',
#      'tournamentId': 6938,
#      'templateId': 47,
#      'seasonName': '2012/2013',
#      'position': 7,
#      'numberOfTeams': 20,
#      'stats': {'points': 61, 'wins': 16, 'draws': 13, 'loss': 9},
#      'tableLink': 'https://data.fotmob.com/historic/47/season/6938/table.fot',
#      'isConsecutive': True},
#     {'stageId': 831975,
#      'tournamentName': 'Premier League',
#      'tournamentId': 7758,
#      'templateId': 47,
#      'seasonName': '2013/2014',
#      'position': 2,
#      'numberOfTeams': 20,
#      'stats': {'points': 84, 'wins': 26, 'draws': 6, 'loss': 6},
#      'tableLink': 'https://data.fotmob.com/historic/47/season/7758/table.fot',
#      'isConsecutive': True},
#     {'stageId': 836118,
#      'tournamentName': 'Premier League',
#      'tournamentId': 8598,
#      'templateId': 47,
#      'seasonName': '2014/2015',
#      'position': 6,
#      'numberOfTeams': 20,
#      'stats': {'points': 62, 'wins': 18, 'draws': 8, 'loss': 12},
#      'tableLink': 'https://data.fotmob.com/historic/47/season/8598/table.fot',
#      'isConsecutive': True},
#     {'stageId': 840449,
#      'tournamentName': 'Premier League',
#      'tournamentId': 9501,
#      'templateId': 47,
#      'seasonName': '2015/2016',
#      'position': 8,
#      'numberOfTeams': 20,
#      'stats': {'points': 60, 'wins': 16, 'draws': 12, 'loss': 10},
#      'tableLink': 'https://data.fotmob.com/historic/47/season/9501/table.fot',
#      'isConsecutive': True},
#     {'stageId': 844714,
#      'tournamentName': 'Premier League',
#      'tournamentId': 10418,
#      'templateId': 47,
#      'seasonName': '2016/2017',
#      'position': 4,
#      'numberOfTeams': 20,
#      'stats': {'points': 76, 'wins': 22, 'draws': 10, 'loss': 6},
#      'tableLink': 'https://data.fotmob.com/historic/47/season/10418/table.fot',
#      'isConsecutive': True},
#     {'stageId': 850080,
#      'tournamentName': 'Premier League',
#      'tournamentId': 11522,
#      'templateId': 47,
#      'seasonName': '2017/2018',
#      'position': 4,
#      'numberOfTeams': 20,
#      'stats': {'points': 75, 'wins': 21, 'draws': 12, 'loss': 5},
#      'tableLink': 'https://data.fotmob.com/historic/47/season/11522/table.fot',
#      'isConsecutive': True},
#     {'stageId': 855968,
#      'tournamentName': 'Premier League',
#      'tournamentId': 12776,
#      'templateId': 47,
#      'seasonName': '2018/2019',
#      'position': 2,
#      'numberOfTeams': 20,
#      'stats': {'points': 97, 'wins': 30, 'draws': 7, 'loss': 1},
#      'tableLink': 'https://data.fotmob.com/historic/47/season/12776/table.fot',
#      'isConsecutive': True},
#     {'stageId': 862234,
#      'tournamentName': 'Premier League',
#      'tournamentId': 14022,
#      'templateId': 47,
#      'seasonName': '2019/2020',
#      'position': 1,
#      'numberOfTeams': 20,
#      'stats': {'points': 99, 'wins': 32, 'draws': 3, 'loss': 3},
#      'tableLink': 'https://data.fotmob.com/historic/47/season/14022/table.fot',
#      'isConsecutive': True},
#     {'stageId': 868824,
#      'tournamentName': 'Premier League',
#      'tournamentId': 15382,
#      'templateId': 47,
#      'seasonName': '2020/2021',
#      'position': 3,
#      'numberOfTeams': 20,
#      'stats': {'points': 69, 'wins': 20, 'draws': 9, 'loss': 9},
#      'tableLink': 'https://data.fotmob.com/historic/47/season/15382/table.fot',
#      'isConsecutive': True},
#     {'stageId': 873678,
#      'tournamentName': 'Premier League',
#      'tournamentId': 16390,
#      'templateId': 47,
#      'seasonName': '2021/2022',
#      'position': 2,
#      'numberOfTeams': 20,
#      'stats': {'points': 92, 'wins': 28, 'draws': 8, 'loss': 2},
#      'tableLink': 'https://data.fotmob.com/historic/47/season/16390/table.fot',
#      'isConsecutive': True},
#     {'stageId': 879290,
#      'tournamentName': 'Premier League',
#      'tournamentId': 17664,
#      'templateId': 47,
#      'seasonName': '2022/2023',
#      'position': 6,
#      'numberOfTeams': 20,
#      'stats': {'points': 42, 'wins': 12, 'draws': 6, 'loss': 8},
#      'tableLink': 'https://data.fotmob.com/tables.ext.47.fot',
#      'isConsecutive': True}],
#    'isValid': True},
#   'teamColor': '#d3171e',
#   'tables': {'current': [{'link': [{'_': 'tables.ext.47.fot',
#        'name': ['Premier League'],
#        'ccode': ['ENG'],
#        'season': ['2022/2023'],
#        'stage_id': ['879290'],
#        'tournament_id': ['17664'],
#        'template_id': ['47'],
#        'league_id': ['47']}]}],
#    'historic': [{'link': [{'_': 'historic/47/season/16390/table.fot',
#        'name': ['Premier League'],
#        'ccode': ['ENG'],
#        'season': ['2021/2022'],
#        'stage_id': ['873678'],
#        'tournament_id': ['16390'],
#        'template_id': ['47'],
#        'league_id': ['47']},
#       {'_': 'historic/47/season/15382/table.fot',
#        'name': ['Premier League'],
#        'ccode': ['ENG'],
#        'season': ['2020/2021'],
#        'stage_id': ['868824'],
#        'tournament_id': ['15382'],
#        'template_id': ['47'],
#        'league_id': ['47']},
#       {'_': 'historic/47/season/14022/table.fot',
#        'name': ['Premier League'],
#        'ccode': ['ENG'],
#        'season': ['2019/2020'],
#        'stage_id': ['862234'],
#        'tournament_id': ['14022'],
#        'template_id': ['47'],
#        'league_id': ['47']},
#       {'_': 'historic/47/season/12776/table.fot',
#        'name': ['Premier League'],
#        'ccode': ['ENG'],
#        'season': ['2018/2019'],
#        'stage_id': ['855968'],
#        'tournament_id': ['12776'],
#        'template_id': ['47'],
#        'league_id': ['47']},
#       {'_': 'historic/47/season/11522/table.fot',
#        'name': ['Premier League'],
#        'ccode': ['ENG'],
#        'season': ['2017/2018'],
#        'stage_id': ['850080'],
#        'tournament_id': ['11522'],
#        'template_id': ['47'],
#        'league_id': ['47']},
#       {'_': 'historic/47/season/10418/table.fot',
#        'name': ['Premier League'],
#        'ccode': ['ENG'],
#        'season': ['2016/2017'],
#        'stage_id': ['844714'],
#        'tournament_id': ['10418'],
#        'template_id': ['47'],
#        'league_id': ['47']},
#       {'_': 'historic/47/season/9501/table.fot',
#        'name': ['Premier League'],
#        'ccode': ['ENG'],
#        'season': ['2015/2016'],
#        'stage_id': ['840449'],
#        'tournament_id': ['9501'],
#        'template_id': ['47'],
#        'league_id': ['47']},
#       {'_': 'historic/47/season/8598/table.fot',
#        'name': ['Premier League'],
#        'ccode': ['ENG'],
#        'season': ['2014/2015'],
#        'stage_id': ['836118'],
#        'tournament_id': ['8598'],
#        'template_id': ['47'],
#        'league_id': ['47']},
#       {'_': 'historic/47/season/7758/table.fot',
#        'name': ['Premier League'],
#        'ccode': ['ENG'],
#        'season': ['2013/2014'],
#        'stage_id': ['831975'],
#        'tournament_id': ['7758'],
#        'template_id': ['47'],
#        'league_id': ['47']},
#       {'_': 'historic/47/season/6938/table.fot',
#        'name': ['Premier League'],
#        'ccode': ['ENG'],
#        'season': ['2012/2013'],
#        'stage_id': ['827652'],
#        'tournament_id': ['6938'],
#        'template_id': ['47'],
#        'league_id': ['47']},
#       {'_': 'historic/47/season/6118/table.fot',
#        'name': ['Premier League'],
#        'ccode': ['ENG'],
#        'season': ['2011/2012'],
#        'stage_id': ['824334'],
#        'tournament_id': ['6118'],
#        'template_id': ['47'],
#        'league_id': ['47']},
#       {'_': 'historic/47/season/5261/table.fot',
#        'name': ['Premier League'],
#        'ccode': ['ENG'],
#        'season': ['2010/2011'],
#        'stage_id': ['820745'],
#        'tournament_id': ['5261'],
#        'template_id': ['47'],
#        'league_id': ['47']}]}]}}}

# %%
fixtures = data['fixtures']['fixtures']
fixtures
# Out:
# {'July 2022': [{'id': 3867987,
#    'pageUrl': '/match/3867987/matchfacts/liverpool-vs-manchester-united',
#    'monthYearKey': 'July 2022',
#    'opponent': {'id': 10260, 'name': 'Man United', 'score': 4},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'away': {'id': 10260, 'name': 'Man United', 'score': 4},
#    'displayTournament': True,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Club Friendlies'],
#    'result': -1,
#    'notStarted': False,
#    'tournament': {'name': 'Club Friendlies'},
#    'status': {'utcTime': '2022-07-12T13:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '0 - 4',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3867985,
#    'pageUrl': '/match/3867985/matchfacts/liverpool-vs-crystal-palace',
#    'monthYearKey': 'July 2022',
#    'opponent': {'id': 9826, 'name': 'Crystal Palace', 'score': 0},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 2},
#    'away': {'id': 9826, 'name': 'Crystal Palace', 'score': 0},
#    'displayTournament': True,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Club Friendlies'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'Club Friendlies'},
#    'status': {'utcTime': '2022-07-15T12:35:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '2 - 0',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3908588,
#    'pageUrl': '/match/3908588/matchfacts/rb-leipzig-vs-liverpool',
#    'monthYearKey': 'July 2022',
#    'opponent': {'id': 178475, 'name': 'RB Leipzig', 'score': 0},
#    'home': {'id': 178475, 'name': 'RB Leipzig', 'score': 0},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 5},
#    'displayTournament': True,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Club Friendlies'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'Club Friendlies'},
#    'status': {'utcTime': '2022-07-21T17:15:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '0 - 5',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3919736,
#    'pageUrl': '/match/3919736/matchfacts/salzburg-vs-liverpool',
#    'monthYearKey': 'July 2022',
#    'opponent': {'id': 10013, 'name': 'Salzburg', 'score': 1},
#    'home': {'id': 10013, 'name': 'Salzburg', 'score': 1},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'displayTournament': True,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Club Friendlies'],
#    'result': -1,
#    'notStarted': False,
#    'tournament': {'name': 'Club Friendlies'},
#    'status': {'utcTime': '2022-07-27T18:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '1 - 0',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3879968,
#    'pageUrl': '/match/3879968/matchfacts/liverpool-vs-manchester-city',
#    'monthYearKey': 'July 2022',
#    'opponent': {'id': 8456, 'name': 'Man City', 'score': 1},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 3},
#    'away': {'id': 8456, 'name': 'Man City', 'score': 1},
#    'displayTournament': True,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Community Shield'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'Community Shield'},
#    'status': {'utcTime': '2022-07-30T16:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '3 - 1',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3910481,
#    'pageUrl': '/match/3910481/matchfacts/liverpool-vs-strasbourg',
#    'monthYearKey': 'July 2022',
#    'opponent': {'id': 9848, 'name': 'Strasbourg', 'score': 3},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'away': {'id': 9848, 'name': 'Strasbourg', 'score': 3},
#    'displayTournament': True,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Club Friendlies'],
#    'result': -1,
#    'notStarted': False,
#    'tournament': {'name': 'Club Friendlies'},
#    'status': {'utcTime': '2022-07-31T18:30:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '0 - 3',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}}],
#  'August 2022': [{'id': 3900933,
#    'pageUrl': '/match/3900933/matchfacts/fulham-vs-liverpool',
#    'monthYearKey': 'August 2022',
#    'opponent': {'id': 9879, 'name': 'Fulham', 'score': 2},
#    'home': {'id': 9879, 'name': 'Fulham', 'score': 2},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 2},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Premier League'],
#    'result': 0,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2022-08-06T11:30:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '2 - 2',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3900947,
#    'pageUrl': '/match/3900947/matchfacts/liverpool-vs-crystal-palace',
#    'monthYearKey': 'August 2022',
#    'opponent': {'id': 9826, 'name': 'Crystal Palace', 'score': 1},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 1},
#    'away': {'id': 9826, 'name': 'Crystal Palace', 'score': 1},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Premier League'],
#    'result': 0,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2022-08-15T19:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '1 - 1',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3900958,
#    'pageUrl': '/match/3900958/matchfacts/manchester-united-vs-liverpool',
#    'monthYearKey': 'August 2022',
#    'opponent': {'id': 10260, 'name': 'Man United', 'score': 2},
#    'home': {'id': 10260, 'name': 'Man United', 'score': 2},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 1},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Premier League'],
#    'result': -1,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2022-08-22T19:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '2 - 1',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3900967,
#    'pageUrl': '/match/3900967/matchfacts/liverpool-vs-afc-bournemouth',
#    'monthYearKey': 'August 2022',
#    'opponent': {'id': 8678, 'name': 'Bournemouth', 'score': 0},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 9},
#    'away': {'id': 8678, 'name': 'Bournemouth', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Premier League'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2022-08-27T14:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '9 - 0',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3900980,
#    'pageUrl': '/match/3900980/matchfacts/liverpool-vs-newcastle-united',
#    'monthYearKey': 'August 2022',
#    'opponent': {'id': 10261, 'name': 'Newcastle', 'score': 1},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 2},
#    'away': {'id': 10261, 'name': 'Newcastle', 'score': 1},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Premier League'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2022-08-31T19:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '2 - 1',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}}],
#  'September 2022': [{'id': 3900986,
#    'pageUrl': '/match/3900986/matchfacts/everton-vs-liverpool',
#    'monthYearKey': 'September 2022',
#    'opponent': {'id': 8668, 'name': 'Everton', 'score': 0},
#    'home': {'id': 8668, 'name': 'Everton', 'score': 0},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Premier League'],
#    'result': 0,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2022-09-03T11:30:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '0 - 0',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 4010119,
#    'pageUrl': '/match/4010119/matchfacts/napoli-vs-liverpool',
#    'monthYearKey': 'September 2022',
#    'opponent': {'id': 9875, 'name': 'Napoli', 'score': 4},
#    'home': {'id': 9875, 'name': 'Napoli', 'score': 4},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 1},
#    'displayTournament': True,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Champions League'],
#    'result': -1,
#    'notStarted': False,
#    'tournament': {'name': 'Champions League'},
#    'status': {'utcTime': '2022-09-07T19:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '4 - 1',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 4010120,
#    'pageUrl': '/match/4010120/matchfacts/liverpool-vs-ajax',
#    'monthYearKey': 'September 2022',
#    'opponent': {'id': 8593, 'name': 'Ajax', 'score': 1},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 2},
#    'away': {'id': 8593, 'name': 'Ajax', 'score': 1},
#    'displayTournament': True,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Champions League'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'Champions League'},
#    'status': {'utcTime': '2022-09-13T19:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '2 - 1',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}}],
#  'October 2022': [{'id': 3901018,
#    'pageUrl': '/match/3901018/matchfacts/liverpool-vs-brighton--hove-albion',
#    'monthYearKey': 'October 2022',
#    'opponent': {'id': 10204, 'name': 'Brighton', 'score': 3},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 3},
#    'away': {'id': 10204, 'name': 'Brighton', 'score': 3},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Premier League'],
#    'result': 0,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2022-10-01T14:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '3 - 3',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 4010125,
#    'pageUrl': '/match/4010125/matchfacts/liverpool-vs-rangers',
#    'monthYearKey': 'October 2022',
#    'opponent': {'id': 8548, 'name': 'Rangers', 'score': 0},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 2},
#    'away': {'id': 8548, 'name': 'Rangers', 'score': 0},
#    'displayTournament': True,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Champions League'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'Champions League'},
#    'status': {'utcTime': '2022-10-04T19:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '2 - 0',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3901022,
#    'pageUrl': '/match/3901022/matchfacts/arsenal-vs-liverpool',
#    'monthYearKey': 'October 2022',
#    'opponent': {'id': 9825, 'name': 'Arsenal', 'score': 3},
#    'home': {'id': 9825, 'name': 'Arsenal', 'score': 3},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 2},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Premier League'],
#    'result': -1,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2022-10-09T15:30:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '3 - 2',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 4010127,
#    'pageUrl': '/match/4010127/matchfacts/rangers-vs-liverpool',
#    'monthYearKey': 'October 2022',
#    'opponent': {'id': 8548, 'name': 'Rangers', 'score': 1},
#    'home': {'id': 8548, 'name': 'Rangers', 'score': 1},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 7},
#    'displayTournament': True,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Champions League'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'Champions League'},
#    'status': {'utcTime': '2022-10-12T19:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '1 - 7',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3901037,
#    'pageUrl': '/match/3901037/matchfacts/liverpool-vs-manchester-city',
#    'monthYearKey': 'October 2022',
#    'opponent': {'id': 8456, 'name': 'Man City', 'score': 0},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 1},
#    'away': {'id': 8456, 'name': 'Man City', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Premier League'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2022-10-16T15:30:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '1 - 0',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3901050,
#    'pageUrl': '/match/3901050/matchfacts/liverpool-vs-west-ham-united',
#    'monthYearKey': 'October 2022',
#    'opponent': {'id': 8654, 'name': 'West Ham', 'score': 0},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 1},
#    'away': {'id': 8654, 'name': 'West Ham', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Premier League'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2022-10-19T18:30:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '1 - 0',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3901057,
#    'pageUrl': '/match/3901057/matchfacts/nottingham-forest-vs-liverpool',
#    'monthYearKey': 'October 2022',
#    'opponent': {'id': 10203, 'name': 'Nottm Forest', 'score': 1},
#    'home': {'id': 10203, 'name': 'Nottm Forest', 'score': 1},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Premier League'],
#    'result': -1,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2022-10-22T11:30:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '1 - 0',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 4010129,
#    'pageUrl': '/match/4010129/matchfacts/ajax-vs-liverpool',
#    'monthYearKey': 'October 2022',
#    'opponent': {'id': 8593, 'name': 'Ajax', 'score': 0},
#    'home': {'id': 8593, 'name': 'Ajax', 'score': 0},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 3},
#    'displayTournament': True,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Champions League'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'Champions League'},
#    'status': {'utcTime': '2022-10-26T19:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '0 - 3',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3901069,
#    'pageUrl': '/match/3901069/matchfacts/liverpool-vs-leeds-united',
#    'monthYearKey': 'October 2022',
#    'opponent': {'id': 8463, 'name': 'Leeds', 'score': 2},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 1},
#    'away': {'id': 8463, 'name': 'Leeds', 'score': 2},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Premier League'],
#    'result': -1,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2022-10-29T18:45:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '1 - 2',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}}],
#  'November 2022': [{'id': 4010130,
#    'pageUrl': '/match/4010130/matchfacts/liverpool-vs-napoli',
#    'monthYearKey': 'November 2022',
#    'opponent': {'id': 9875, 'name': 'Napoli', 'score': 0},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 2},
#    'away': {'id': 9875, 'name': 'Napoli', 'score': 0},
#    'displayTournament': True,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Champions League'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'Champions League'},
#    'status': {'utcTime': '2022-11-01T20:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '2 - 0',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3901079,
#    'pageUrl': '/match/3901079/matchfacts/tottenham-hotspur-vs-liverpool',
#    'monthYearKey': 'November 2022',
#    'opponent': {'id': 8586, 'name': 'Tottenham', 'score': 1},
#    'home': {'id': 8586, 'name': 'Tottenham', 'score': 1},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 2},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Premier League'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2022-11-06T16:30:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '1 - 2',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 4009218,
#    'pageUrl': '/match/4009218/matchfacts/liverpool-vs-derby-county',
#    'monthYearKey': 'November 2022',
#    'opponent': {'id': 10170, 'name': 'Derby', 'score': 2},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 3},
#    'away': {'id': 10170, 'name': 'Derby', 'score': 2},
#    'displayTournament': True,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | EFL Cup'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'EFL Cup'},
#    'status': {'utcTime': '2022-11-09T20:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '3 - 2',
#     'reason': {'short': 'Pen', 'long': 'After penalties'}}},
#   {'id': 3901085,
#    'pageUrl': '/match/3901085/matchfacts/liverpool-vs-southampton',
#    'monthYearKey': 'November 2022',
#    'opponent': {'id': 8466, 'name': 'Southampton', 'score': 1},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 3},
#    'away': {'id': 8466, 'name': 'Southampton', 'score': 1},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Premier League'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2022-11-12T15:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '3 - 1',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}}],
#  'December 2022': [{'id': 4064642,
#    'pageUrl': '/match/4064642/matchfacts/liverpool-vs-lyon',
#    'monthYearKey': 'December 2022',
#    'opponent': {'id': 9748, 'name': 'Lyon', 'score': 3},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 1},
#    'away': {'id': 9748, 'name': 'Lyon', 'score': 3},
#    'displayTournament': True,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Club Friendlies'],
#    'result': -1,
#    'notStarted': False,
#    'tournament': {'name': 'Club Friendlies'},
#    'status': {'utcTime': '2022-12-11T14:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '1 - 3',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 4064643,
#    'pageUrl': '/match/4064643/matchfacts/liverpool-vs-milan',
#    'monthYearKey': 'December 2022',
#    'opponent': {'id': 8564, 'name': 'Milan', 'score': 1},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 4},
#    'away': {'id': 8564, 'name': 'Milan', 'score': 1},
#    'displayTournament': True,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Club Friendlies'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'Club Friendlies'},
#    'status': {'utcTime': '2022-12-16T15:30:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '4 - 1',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 4062032,
#    'pageUrl': '/match/4062032/matchfacts/manchester-city-vs-liverpool',
#    'monthYearKey': 'December 2022',
#    'opponent': {'id': 8456, 'name': 'Man City', 'score': 3},
#    'home': {'id': 8456, 'name': 'Man City', 'score': 3},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 2},
#    'displayTournament': True,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | EFL Cup'],
#    'result': -1,
#    'notStarted': False,
#    'tournament': {'name': 'EFL Cup'},
#    'status': {'utcTime': '2022-12-22T20:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '3 - 2',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3901093,
#    'pageUrl': '/match/3901093/matchfacts/aston-villa-vs-liverpool',
#    'monthYearKey': 'December 2022',
#    'opponent': {'id': 10252, 'name': 'Aston Villa', 'score': 1},
#    'home': {'id': 10252, 'name': 'Aston Villa', 'score': 1},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 3},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Premier League'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2022-12-26T17:30:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '1 - 3',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3901105,
#    'pageUrl': '/match/3901105/matchfacts/liverpool-vs-leicester-city',
#    'monthYearKey': 'December 2022',
#    'opponent': {'id': 8197, 'name': 'Leicester', 'score': 1},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 2},
#    'away': {'id': 8197, 'name': 'Leicester', 'score': 1},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Premier League'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2022-12-30T20:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '2 - 1',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}}],
#  'January 2023': [{'id': 3901114,
#    'pageUrl': '/match/3901114/matchfacts/brentford-vs-liverpool',
#    'monthYearKey': 'January 2023',
#    'opponent': {'id': 9937, 'name': 'Brentford', 'score': 3},
#    'home': {'id': 9937, 'name': 'Brentford', 'score': 3},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 1},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Premier League'],
#    'result': -1,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-01-02T17:30:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '3 - 1',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 4072396,
#    'pageUrl': '/match/4072396/matchfacts/liverpool-vs-wolverhampton-wanderers',
#    'monthYearKey': 'January 2023',
#    'opponent': {'id': 8602, 'name': 'Wolves', 'score': 2},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 2},
#    'away': {'id': 8602, 'name': 'Wolves', 'score': 2},
#    'displayTournament': True,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | FA Cup'],
#    'result': 0,
#    'notStarted': False,
#    'tournament': {'name': 'FA Cup'},
#    'status': {'utcTime': '2023-01-07T20:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '2 - 2',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3901124,
#    'pageUrl': '/match/3901124/matchfacts/brighton--hove-albion-vs-liverpool',
#    'monthYearKey': 'January 2023',
#    'opponent': {'id': 10204, 'name': 'Brighton', 'score': 3},
#    'home': {'id': 10204, 'name': 'Brighton', 'score': 3},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Premier League'],
#    'result': -1,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-01-14T15:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '3 - 0',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 4094704,
#    'pageUrl': '/match/4094704/matchfacts/wolverhampton-wanderers-vs-liverpool',
#    'monthYearKey': 'January 2023',
#    'opponent': {'id': 8602, 'name': 'Wolves', 'score': 0},
#    'home': {'id': 8602, 'name': 'Wolves', 'score': 0},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 1},
#    'displayTournament': True,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | FA Cup'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'FA Cup'},
#    'status': {'utcTime': '2023-01-17T19:45:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '0 - 1',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3901138,
#    'pageUrl': '/match/3901138/matchfacts/liverpool-vs-chelsea',
#    'monthYearKey': 'January 2023',
#    'opponent': {'id': 8455, 'name': 'Chelsea', 'score': 0},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'away': {'id': 8455, 'name': 'Chelsea', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Premier League'],
#    'result': 0,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-01-21T12:30:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '0 - 0',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 4094724,
#    'pageUrl': '/match/4094724/matchfacts/brighton--hove-albion-vs-liverpool',
#    'monthYearKey': 'January 2023',
#    'opponent': {'id': 10204, 'name': 'Brighton', 'score': 2},
#    'home': {'id': 10204, 'name': 'Brighton', 'score': 2},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 1},
#    'displayTournament': True,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | FA Cup'],
#    'result': -1,
#    'notStarted': False,
#    'tournament': {'name': 'FA Cup'},
#    'status': {'utcTime': '2023-01-29T13:30:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '2 - 1',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}}],
#  'February 2023': [{'id': 3901151,
#    'pageUrl': '/match/3901151/matchfacts/wolverhampton-wanderers-vs-liverpool',
#    'monthYearKey': 'February 2023',
#    'opponent': {'id': 8602, 'name': 'Wolves', 'score': 3},
#    'home': {'id': 8602, 'name': 'Wolves', 'score': 3},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Premier League'],
#    'result': -1,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-02-04T15:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '3 - 0',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3901158,
#    'pageUrl': '/match/3901158/matchfacts/liverpool-vs-everton',
#    'monthYearKey': 'February 2023',
#    'opponent': {'id': 8668, 'name': 'Everton', 'score': 0},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 2},
#    'away': {'id': 8668, 'name': 'Everton', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Premier League'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-02-13T20:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '2 - 0',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3901168,
#    'pageUrl': '/match/3901168/matchfacts/newcastle-united-vs-liverpool',
#    'monthYearKey': 'February 2023',
#    'opponent': {'id': 10261, 'name': 'Newcastle', 'score': 0},
#    'home': {'id': 10261, 'name': 'Newcastle', 'score': 0},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 2},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Premier League'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-02-18T17:30:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '0 - 2',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 4060604,
#    'pageUrl': '/match/4060604/matchfacts/liverpool-vs-real-madrid',
#    'monthYearKey': 'February 2023',
#    'opponent': {'id': 8633, 'name': 'Real Madrid', 'score': 5},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 2},
#    'away': {'id': 8633, 'name': 'Real Madrid', 'score': 5},
#    'displayTournament': True,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Champions League'],
#    'result': -1,
#    'notStarted': False,
#    'tournament': {'name': 'Champions League'},
#    'status': {'utcTime': '2023-02-21T20:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '2 - 5',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3901173,
#    'pageUrl': '/match/3901173/matchfacts/crystal-palace-vs-liverpool',
#    'monthYearKey': 'February 2023',
#    'opponent': {'id': 9826, 'name': 'Crystal Palace', 'score': 0},
#    'home': {'id': 9826, 'name': 'Crystal Palace', 'score': 0},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Premier League'],
#    'result': 0,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-02-25T19:45:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '0 - 0',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}}],
#  'March 2023': [{'id': 3900998,
#    'pageUrl': '/match/3900998/matchfacts/liverpool-vs-wolverhampton-wanderers',
#    'monthYearKey': 'March 2023',
#    'opponent': {'id': 8602, 'name': 'Wolves', 'score': 0},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 2},
#    'away': {'id': 8602, 'name': 'Wolves', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Premier League'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-03-01T20:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '2 - 0',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3901187,
#    'pageUrl': '/match/3901187/matchfacts/liverpool-vs-manchester-united',
#    'monthYearKey': 'March 2023',
#    'opponent': {'id': 10260, 'name': 'Man United', 'score': 0},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 7},
#    'away': {'id': 10260, 'name': 'Man United', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Premier League'],
#    'result': 1,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-03-05T16:30:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '7 - 0',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3901192,
#    'pageUrl': '/match/3901192/matchfacts/afc-bournemouth-vs-liverpool',
#    'monthYearKey': 'March 2023',
#    'opponent': {'id': 8678, 'name': 'Bournemouth', 'score': 1},
#    'home': {'id': 8678, 'name': 'Bournemouth', 'score': 1},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Premier League'],
#    'result': -1,
#    'notStarted': False,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-03-11T12:30:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '1 - 0',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 4060605,
#    'pageUrl': '/match/4060605/matchfacts/real-madrid-vs-liverpool',
#    'monthYearKey': 'March 2023',
#    'opponent': {'id': 8633, 'name': 'Real Madrid', 'score': 1},
#    'home': {'id': 8633, 'name': 'Real Madrid', 'score': 1},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'displayTournament': True,
#    'isPastMatch': True,
#    'lastPlayedMatch': True,
#    'lnameArr': ['A', ' | Champions League'],
#    'result': -1,
#    'notStarted': False,
#    'tournament': {'name': 'Champions League'},
#    'status': {'utcTime': '2023-03-15T20:00:00.000Z',
#     'finished': True,
#     'started': True,
#     'cancelled': False,
#     'scoreStr': '1 - 0',
#     'reason': {'short': 'FT', 'long': 'Full-Time'}}},
#   {'id': 3901207,
#    'pageUrl': '/match/3901207/matchfacts/liverpool-vs-fulham',
#    'monthYearKey': 'March 2023',
#    'opponent': {'id': 9879, 'name': 'Fulham', 'score': 0},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'away': {'id': 9879, 'name': 'Fulham', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': True,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Premier League'],
#    'notStarted': True,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-03-18T15:00:00.000Z',
#     'cancelled': True,
#     'started': False,
#     'finished': True,
#     'reason': {'short': 'PP', 'long': 'Postponed'}}}],
#  'April 2023': [{'id': 3901218,
#    'pageUrl': '/match/3901218/matchfacts/manchester-city-vs-liverpool',
#    'monthYearKey': 'April 2023',
#    'opponent': {'id': 8456, 'name': 'Man City', 'score': 0},
#    'home': {'id': 8456, 'name': 'Man City', 'score': 0},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': False,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Premier League'],
#    'notStarted': True,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-04-01T11:30:00.000Z',
#     'started': False,
#     'cancelled': False,
#     'finished': False}},
#   {'id': 3901005,
#    'pageUrl': '/match/3901005/matchfacts/chelsea-vs-liverpool',
#    'monthYearKey': 'April 2023',
#    'opponent': {'id': 8455, 'name': 'Chelsea', 'score': 0},
#    'home': {'id': 8455, 'name': 'Chelsea', 'score': 0},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': False,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Premier League'],
#    'notStarted': True,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-04-04T19:00:00.000Z',
#     'started': False,
#     'cancelled': False,
#     'finished': False}},
#   {'id': 3901227,
#    'pageUrl': '/match/3901227/matchfacts/liverpool-vs-arsenal',
#    'monthYearKey': 'April 2023',
#    'opponent': {'id': 9825, 'name': 'Arsenal', 'score': 0},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'away': {'id': 9825, 'name': 'Arsenal', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': False,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Premier League'],
#    'notStarted': True,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-04-09T15:30:00.000Z',
#     'started': False,
#     'cancelled': False,
#     'finished': False}},
#   {'id': 3901235,
#    'pageUrl': '/match/3901235/matchfacts/leeds-united-vs-liverpool',
#    'monthYearKey': 'April 2023',
#    'opponent': {'id': 8463, 'name': 'Leeds', 'score': 0},
#    'home': {'id': 8463, 'name': 'Leeds', 'score': 0},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': False,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Premier League'],
#    'notStarted': True,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-04-17T19:00:00.000Z',
#     'started': False,
#     'cancelled': False,
#     'finished': False}},
#   {'id': 3901249,
#    'pageUrl': '/match/3901249/matchfacts/liverpool-vs-nottingham-forest',
#    'monthYearKey': 'April 2023',
#    'opponent': {'id': 10203, 'name': 'Nottm Forest', 'score': 0},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'away': {'id': 10203, 'name': 'Nottm Forest', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': False,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Premier League'],
#    'notStarted': True,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-04-22T14:00:00.000Z',
#     'started': False,
#     'cancelled': False,
#     'finished': False}},
#   {'id': 3901256,
#    'pageUrl': '/match/3901256/matchfacts/west-ham-united-vs-liverpool',
#    'monthYearKey': 'April 2023',
#    'opponent': {'id': 8654, 'name': 'West Ham', 'score': 0},
#    'home': {'id': 8654, 'name': 'West Ham', 'score': 0},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': False,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Premier League'],
#    'notStarted': True,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-04-26T18:45:00.000Z',
#     'started': False,
#     'cancelled': False,
#     'finished': False}},
#   {'id': 3901269,
#    'pageUrl': '/match/3901269/matchfacts/liverpool-vs-tottenham-hotspur',
#    'monthYearKey': 'April 2023',
#    'opponent': {'id': 8586, 'name': 'Tottenham', 'score': 0},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'away': {'id': 8586, 'name': 'Tottenham', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': False,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Premier League'],
#    'notStarted': True,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-04-30T15:30:00.000Z',
#     'started': False,
#     'cancelled': False,
#     'finished': False}}],
#  'May 2023': [{'id': 3901275,
#    'pageUrl': '/match/3901275/matchfacts/liverpool-vs-brentford',
#    'monthYearKey': 'May 2023',
#    'opponent': {'id': 9937, 'name': 'Brentford', 'score': 0},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'away': {'id': 9937, 'name': 'Brentford', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': False,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Premier League'],
#    'notStarted': True,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-05-06T14:00:00.000Z',
#     'started': False,
#     'cancelled': False,
#     'finished': False}},
#   {'id': 3901289,
#    'pageUrl': '/match/3901289/matchfacts/leicester-city-vs-liverpool',
#    'monthYearKey': 'May 2023',
#    'opponent': {'id': 8197, 'name': 'Leicester', 'score': 0},
#    'home': {'id': 8197, 'name': 'Leicester', 'score': 0},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': False,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Premier League'],
#    'notStarted': True,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-05-13T14:00:00.000Z',
#     'started': False,
#     'cancelled': False,
#     'finished': False}},
#   {'id': 3901295,
#    'pageUrl': '/match/3901295/matchfacts/liverpool-vs-aston-villa',
#    'monthYearKey': 'May 2023',
#    'opponent': {'id': 10252, 'name': 'Aston Villa', 'score': 0},
#    'home': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'away': {'id': 10252, 'name': 'Aston Villa', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': False,
#    'lastPlayedMatch': False,
#    'lnameArr': ['H', ' | Premier League'],
#    'notStarted': True,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-05-20T14:00:00.000Z',
#     'started': False,
#     'cancelled': False,
#     'finished': False}},
#   {'id': 3901311,
#    'pageUrl': '/match/3901311/matchfacts/southampton-vs-liverpool',
#    'monthYearKey': 'May 2023',
#    'opponent': {'id': 8466, 'name': 'Southampton', 'score': 0},
#    'home': {'id': 8466, 'name': 'Southampton', 'score': 0},
#    'away': {'id': 8650, 'name': 'Liverpool', 'score': 0},
#    'displayTournament': False,
#    'isPastMatch': False,
#    'lastPlayedMatch': False,
#    'lnameArr': ['A', ' | Premier League'],
#    'notStarted': True,
#    'tournament': {'name': 'Premier League'},
#    'status': {'utcTime': '2023-05-28T15:30:00.000Z',
#     'started': False,
#     'cancelled': False,
#     'finished': False}}]}

# %%
march_fix = fixtures['March 2023']
march_fix=pd.DataFrame(march_fix)

# %%
aug_fix = fixtures['August 2022']
aug_fix=pd.DataFrame(aug_fix)

# %%
sep_fix = fixtures['September 2022']
sep_fix=pd.DataFrame(sep_fix)

# %%
nov_fix = fixtures['November 2022']
nov_fix = pd.DataFrame(nov_fix)

# %%
oct_fix = fixtures['October 2022']
oct_fix=pd.DataFrame(oct_fix)

# %%
dec_fix = fixtures['December 2022']
dec_fix= pd.DataFrame(dec_fix)

# %%
feb_fix = fixtures['February 2023']
feb_fix = pd.DataFrame(feb_fix)

# %%
jan_fix = fixtures['January 2023']
jan_fix = pd.DataFrame(jan_fix)

# %%
march_fix
# Out:
#         id                                            pageUrl monthYearKey  \
# 0  3900998  /match/3900998/matchfacts/liverpool-vs-wolverh...   March 2023
# 1  3901187  /match/3901187/matchfacts/liverpool-vs-manches...   March 2023
# 2  3901192  /match/3901192/matchfacts/afc-bournemouth-vs-l...   March 2023
# 3  4060605  /match/4060605/matchfacts/real-madrid-vs-liver...   March 2023
# 4  3901207      /match/3901207/matchfacts/liverpool-vs-fulham   March 2023
#
#                                           opponent  \
# 0       {'id': 8602, 'name': 'Wolves', 'score': 0}
# 1  {'id': 10260, 'name': 'Man United', 'score': 0}
# 2  {'id': 8678, 'name': 'Bournemouth', 'score': 1}
# 3  {'id': 8633, 'name': 'Real Madrid', 'score': 1}
# 4       {'id': 9879, 'name': 'Fulham', 'score': 0}
#
#                                               home  \
# 0    {'id': 8650, 'name': 'Liverpool', 'score': 2}
# 1    {'id': 8650, 'name': 'Liverpool', 'score': 7}
# 2  {'id': 8678, 'name': 'Bournemouth', 'score': 1}
# 3  {'id': 8633, 'name': 'Real Madrid', 'score': 1}
# 4    {'id': 8650, 'name': 'Liverpool', 'score': 0}
#
#                                               away  displayTournament  \
# 0       {'id': 8602, 'name': 'Wolves', 'score': 0}              False
# 1  {'id': 10260, 'name': 'Man United', 'score': 0}              False
# 2    {'id': 8650, 'name': 'Liverpool', 'score': 0}              False
# 3    {'id': 8650, 'name': 'Liverpool', 'score': 0}               True
# 4       {'id': 9879, 'name': 'Fulham', 'score': 0}              False
#
#    isPastMatch  lastPlayedMatch                  lnameArr  result  notStarted  \
# 0         True            False    [H,  | Premier League]     1.0       False
# 1         True            False    [H,  | Premier League]     1.0       False
# 2         True            False    [A,  | Premier League]    -1.0       False
# 3         True             True  [A,  | Champions League]    -1.0       False
# 4        False            False    [H,  | Premier League]     NaN        True
#
#                      tournament  \
# 0    {'name': 'Premier League'}
# 1    {'name': 'Premier League'}
# 2    {'name': 'Premier League'}
# 3  {'name': 'Champions League'}
# 4    {'name': 'Premier League'}
#
#                                               status
# 0  {'utcTime': '2023-03-01T20:00:00.000Z', 'finis...
# 1  {'utcTime': '2023-03-05T16:30:00.000Z', 'finis...
# 2  {'utcTime': '2023-03-11T12:30:00.000Z', 'finis...
# 3  {'utcTime': '2023-03-15T20:00:00.000Z', 'finis...
# 4  {'utcTime': '2023-03-18T15:00:00.000Z', 'cance...

# %%
match_id = march_fix.id[2]
response = requests.get(f'https://www.fotmob.com/api/matchDetails?matchId={match_id}&ccode3=USA&timezone=America%2FChicago&refresh=true&includeBuzzTab=false&acceptLanguage=en-US')
data = response.content
data = json.loads(data)

matchId = data['general']['matchId']

homeTeam = data['general']['homeTeam']
awayTeam = data['general']['awayTeam']

home_team_id = homeTeam['id']
away_team_id = awayTeam['id']

homeTeamName = homeTeam['name']
awayTeamName = awayTeam['name']

homeTeam = pd.DataFrame(homeTeam, index=[0])
awayTeam = pd.DataFrame(awayTeam, index=[0])

shot_data = data['content']['shotmap']['shots']

df_shot = pd.DataFrame(shot_data)

df_shot['matchId'] = matchId
df_shot['Venue'] = ''
for index, row in df_shot.iterrows():
    if row['teamId'] == home_team_id:
        df_shot.loc[index, 'Venue'] = 'Home'
        df_shot.loc[index, 'TeamName'] = homeTeamName
    elif row['teamId'] == away_team_id:
        df_shot.loc[index, 'Venue'] = 'Away'
        df_shot.loc[index, 'TeamName'] = awayTeamName

def extract_value(d, key):
    return d[key]

df_shot['onGoalShot_X'] = df_shot['onGoalShot'].apply(extract_value, args=('x',))
df_shot['onGoalShot_Y'] = df_shot['onGoalShot'].apply(extract_value, args=('y',))
df_shot['onGoalShot_ZR'] = df_shot['onGoalShot'].apply(extract_value, args=('zoomRatio',))
df_shot.drop(['onGoalShot'], axis=1, inplace=True)

df_shot.to_sql("Matches", con, if_exists="append")
# Out:
# 20

# %%
df_shot.to_sql("Matches", con, if_exists="append")

con.commit()

# %%
pd.read_sql("Select * from test ", con)
# Out:
#     index          id     eventType  teamId  playerId              playerName  \
# 0       0  2518194727  AttemptSaved    8650    292462           Mohamed Salah
# 1       1  2518195715  AttemptSaved    8650    209405         Virgil van Dijk
# 2       2  2518198231          Miss    8678   1250253          Dango Ouattara
# 3       3  2518199405  AttemptSaved    8650    950561            Darwin Nunez
# 4       4  2518200289  AttemptSaved    8650    357880        Andrew Robertson
# 5       5  2518203181          Miss    8650    760712  Trent Alexander-Arnold
# 6       6  2518207707          Goal    8678    532743          Philip Billing
# 7       7  2518212347          Miss    8650    359188                 Fabinho
# 8       8  2518218765          Miss    8650    209405         Virgil van Dijk
# 9       9  2518220371          Miss    8678    591734         Dominic Solanke
# 10     10  2518222107          Miss    8650   1310118         Stefan Bajcetic
# 11     11  2518222869  AttemptSaved    8650    209405         Virgil van Dijk
# 12     12  2518239187          Miss    8650    820140         Ibrahima Konaté
# 13     13  2518241791  AttemptSaved    8650    570461              Diogo Jota
# 14     14  2518259135  AttemptSaved    8650    570461              Diogo Jota
# 15     15  2518260831          Miss    8650    292462           Mohamed Salah
# 16     16  2518274147  AttemptSaved    8678    439369           Ryan Christie
# 17     17  2518281557          Miss    8650    806552              Cody Gakpo
# 18     18  2518282781          Miss    8678    933576         Antoine Semenyo
# 19     19  2518286177          Miss    8650    806552              Cody Gakpo
#
#              x          y  min  minAdded  ...  isOwnGoal  firstName  \
# 0    87.855884  30.492501    5       NaN  ...          0    Mohamed
# 1    98.631582  37.355001    6       NaN  ...          0     Virgil
# 2   102.724136  23.018344    9       NaN  ...          0      Dango
# 3    83.723785  50.586754   11       NaN  ...          0     Darwin
# 4    97.280703  49.886117   13       NaN  ...          0     Andrew
# 5    94.482456  48.274650   17       NaN  ...          0      Trent
# 6    96.894737  32.856250   28       NaN  ...          0     Philip
# 7    74.376217  31.636251   35       NaN  ...          0
# 8    98.824561  36.897499   41       NaN  ...          0     Virgil
# 9    97.087716  43.440254   43       NaN  ...          0    Dominic
# 10   63.789808  37.768000   45       0.0  ...          0     Stefan
# 11   96.701757  48.134524   45       1.0  ...          0     Virgil
# 12   96.315791  26.516563   47       NaN  ...          0   Ibrahima
# 13   89.800003  43.230063   49       NaN  ...          0      Diogo
# 14  101.586208  41.141904   67       NaN  ...          0      Diogo
# 15   94.000000  34.000000   69       NaN  ...          0    Mohamed
# 16   96.798247  49.115412   83       NaN  ...          0       Ryan
# 17   97.859649  45.682295   90       0.0  ...          0       Cody
# 18   94.192980  50.586754   90       1.0  ...          0    Antoine
# 19  100.068968  18.113886   90       4.0  ...          0       Cody
#
#             lastName  teamColor  matchId  Venue         TeamName  \
# 0              Salah    #d3171e  3901192   Away        Liverpool
# 1           van Dijk    #d3171e  3901192   Away        Liverpool
# 2           Ouattara    #901818  3901192   Home  AFC Bournemouth
# 3              Nunez    #d3171e  3901192   Away        Liverpool
# 4          Robertson    #d3171e  3901192   Away        Liverpool
# 5   Alexander-Arnold    #d3171e  3901192   Away        Liverpool
# 6            Billing    #901818  3901192   Home  AFC Bournemouth
# 7            Fabinho    #d3171e  3901192   Away        Liverpool
# 8           van Dijk    #d3171e  3901192   Away        Liverpool
# 9            Solanke    #901818  3901192   Home  AFC Bournemouth
# 10          Bajcetic    #d3171e  3901192   Away        Liverpool
# 11          van Dijk    #d3171e  3901192   Away        Liverpool
# 12            Konaté    #d3171e  3901192   Away        Liverpool
# 13              Jota    #d3171e  3901192   Away        Liverpool
# 14              Jota    #d3171e  3901192   Away        Liverpool
# 15             Salah    #d3171e  3901192   Away        Liverpool
# 16          Christie    #901818  3901192   Home  AFC Bournemouth
# 17             Gakpo    #d3171e  3901192   Away        Liverpool
# 18           Semenyo    #901818  3901192   Home  AFC Bournemouth
# 19             Gakpo    #d3171e  3901192   Away        Liverpool
#
#     onGoalShot_X onGoalShot_Y onGoalShot_ZR
# 0   1.383267e+00     0.064550      1.000000
# 1   1.847222e+00     0.322751      1.000000
# 2   2.000000e+00     0.105483      0.899949
# 3   4.150132e-01     0.074742      1.000000
# 4   1.363095e+00     0.042467      1.000000
# 5   1.110223e-16     0.032306      0.275628
# 6   6.974206e-01     0.054358      1.000000
# 7   1.343906e+00     0.677249      0.378861
# 8   0.000000e+00     0.173712      0.818097
# 9   4.253015e-01     0.677249      0.589674
# 10  0.000000e+00     0.062102      0.440463
# 11  8.991402e-01     0.526594      1.000000
# 12  7.177562e-01     0.677249      0.482479
# 13  1.726190e+00     0.332943      1.000000
# 14  4.957011e-01     0.322751      1.000000
# 15  0.000000e+00     0.410499      0.725694
# 16  8.587963e-01     0.312559      1.000000
# 17  2.000000e+00     0.088101      0.624867
# 18  2.000000e+00     0.034957      0.489974
# 19  9.388299e-01     0.677249      0.758108
#
# [20 rows x 31 columns]

# %% [markdown]
# Feb Games

# %%
feb_fix.id
# Out:
# 0    3901151
# 1    3901158
# 2    3901168
# 3    4060604
# 4    3901173
# Name: id, dtype: int64

# %%
match_id = feb_fix.id[0]
response = requests.get(f'https://www.fotmob.com/api/matchDetails?matchId={match_id}&ccode3=USA&timezone=America%2FChicago&refresh=true&includeBuzzTab=false&acceptLanguage=en-US')
data = response.content
data = json.loads(data)

matchId = data['general']['matchId']

leagueId = data['general']['leagueId']
leagueId

team_logos = data['header']['teams']
team_logos = pd.DataFrame(team_logos)
team_logos


homeTeam = data['general']['homeTeam']
awayTeam = data['general']['awayTeam']

homeTeam = pd.DataFrame(homeTeam,index=[0])
awayTeam = pd.DataFrame(awayTeam,index=[0])

shot_data = data['content']['shotmap']['shots']

general = data ['general']
general = pd.DataFrame(general)
general

df_shot = pd.DataFrame(shot_data)

df_shot['matchId'] = matchId
df_shot

def extract_value(d, key):
    return d[key]
df_shot['x_value'] = df_shot['onGoalShot'].apply(extract_value, args=('x',))
df_shot['y_value'] = df_shot['onGoalShot'].apply(extract_value, args=('y',))
df_shot['zoomRatio_value'] = df_shot['onGoalShot'].apply(extract_value, args=('zoomRatio',))
df_shot.drop(['onGoalShot'], axis=1, inplace=True)


df_shot = df_shot.rename(columns={'x_value':'onGoalShot_X'})
df_shot = df_shot.rename(columns={'y_value':'onGoalShot_Y'})
df_shot = df_shot.rename(columns={'zoomRatio_value':'onGoalShot_ZR'})

df_shot.to_sql("Matches", con, if_exists="append")
# Out:
# 35

# %%
#ben_liv = df_shot

# %%
pd.read_sql("Select * from Matches where teamId = 8650 ", con)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 pd.read_sql("Select * from Matches where teamId = 8650 ", con)
#
# File ~/Documents/Coding Projects/lib/python3.9/site-packages/pandas/io/sql.py:564, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     561 pandas_sql = pandasSQL_builder(con)
#     563 if isinstance(pandas_sql, SQLiteDatabase):
# --> 564     return pandas_sql.read_query(
#     565         sql,
#     566         index_col=index_col,
#     567         params=params,
#     568         coerce_float=coerce_float,
#     569         parse_dates=parse_dates,
#     570         chunksize=chunksize,
#     571     )
#     573 try:
#     574     _is_table_name = pandas_sql.has_table(sql)
#
# File ~/Documents/Coding Projects/lib/python3.9/site-packages/pandas/io/sql.py:2078, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2066 def read_query(
#    2067     self,
#    2068     sql,
#    (...)
#    2074     dtype: DtypeArg | None = None,
#    2075 ) -> DataFrame | Iterator[DataFrame]:
#    2077     args = _convert_params(sql, params)
# -> 2078     cursor = self.execute(*args)
#    2079     columns = [col_desc[0] for col_desc in cursor.description]
#    2081     if chunksize is not None:
#
# File ~/Documents/Coding Projects/lib/python3.9/site-packages/pandas/io/sql.py:2016, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2015 def execute(self, *args, **kwargs):
# -> 2016     cur = self.con.cursor()
#    2017     try:
#    2018         cur.execute(*args, **kwargs)
#
# ProgrammingError: Cannot operate on a closed database.

# %%
con.commit()

# %%
con.close()

# %%
df_shot['x_value'] = df_shot['onGoalShot'].apply(extract_value, args=('x',))
df_shot['y_value'] = df_shot['onGoalShot'].apply(extract_value, args=('y',))
df_shot['zoomRatio_value'] = df_shot['onGoalShot'].apply(extract_value, args=('zoomRatio',))
df_shot = df_shot.rename(columns={'x_value':'onGoalShot_X'})
df_shot = df_shot.rename(columns={'y_value':'onGoalShot_Y'})
df_shot = df_shot.rename(columns={'zoomRatio_value':'onGoalShot_ZR'})

# %%
df_shot.drop(['onGoalShot'], axis=1, inplace=True)
df_shot
# Out:
#             id     eventType  teamId  playerId               playerName  \
# 0   2494735167  AttemptSaved    8650    950561             Darwin Nunez
# 1   2494735769  AttemptSaved    8650    950561             Darwin Nunez
# 2   2494736485  AttemptSaved    9937    688273            Vitaly Janelt
# 3   2494737067          Miss    9937    923312             Bryan Mbeumo
# 4   2494737323  AttemptSaved    9937    923312             Bryan Mbeumo
# 5   2494737459          Goal    8650    820140          Ibrahima Konaté
# 6   2494737893          Miss    8650    196386  Alex Oxlade-Chamberlain
# 7   2494737921  AttemptSaved    8650    671529    Konstantinos Tsimikas
# 8   2494737957  AttemptSaved    8650    671529    Konstantinos Tsimikas
# 9   2494737981  AttemptSaved    9937    650616           Mathias Jensen
# 10  2494738015  AttemptSaved    9937    266520       Christian Nørgaard
# 11  2494738017  AttemptSaved    9937    711357            Ethan Pinnock
# 12  2494738023  AttemptSaved    9937    711357            Ethan Pinnock
# 13  2494738505  AttemptSaved    8650    820140          Ibrahima Konaté
# 14  2494738511  AttemptSaved    8650    196386  Alex Oxlade-Chamberlain
# 15  2494739347          Miss    9937    666857              Yoane Wissa
# 16  2494739391          Goal    9937    666857              Yoane Wissa
# 17  2494739701  AttemptSaved    8650    671529    Konstantinos Tsimikas
# 18  2494742263          Goal    8650    196386  Alex Oxlade-Chamberlain
# 19  2494743057  AttemptSaved    8650    359188                  Fabinho
# 20  2494743895  AttemptSaved    8650    172949         Thiago Alcántara
# 21  2494743897  AttemptSaved    8650    172949         Thiago Alcántara
# 22  2494745161          Miss    8650    950561             Darwin Nunez
# 23  2494746203  AttemptSaved    8650    292462            Mohamed Salah
# 24  2494746273          Miss    8650    820140          Ibrahima Konaté
# 25  2494746689          Goal    9937    923312             Bryan Mbeumo
# 26  2494747031  AttemptSaved    8650    508889               Naby Keita
#
#              x          y  min minAdded  isBlocked  ...      period  \
# 0    92.400002  27.950714    3     None       True  ...   FirstHalf
# 1   101.112070  40.973808    8     None       True  ...   FirstHalf
# 2    85.494114  20.636178   13     None      False  ...   FirstHalf
# 3   102.534484  27.362380   17     None      False  ...   FirstHalf
# 4    94.000000  25.013437   18     None      False  ...   FirstHalf
# 5     6.754386  37.659999   19     None      False  ...   FirstHalf
# 6    93.500000  35.372499   24     None      False  ...   FirstHalf
# 7    96.315791  42.350625   24     None      False  ...   FirstHalf
# 8    96.605260  51.707772   25     None       True  ...   FirstHalf
# 9    96.219301  20.776306   26     None       True  ...   FirstHalf
# 10  102.155172  24.769937   26     None      False  ...   FirstHalf
# 11  101.586208  33.923751   26     None      False  ...   FirstHalf
# 12  101.586208  33.618750   26     None      False  ...   FirstHalf
# 13   97.763159  30.492501   33     None       True  ...   FirstHalf
# 14   77.079123  27.194284   33     None      False  ...   FirstHalf
# 15   94.771933  38.032142   39     None      False  ...   FirstHalf
# 16   97.859649  38.368333   42     None      False  ...   FirstHalf
# 17   96.412281  34.381250   44     None      False  ...   FirstHalf
# 18   96.219301  34.000000   50     None      False  ...  SecondHalf
# 19   82.034464  24.489681   55     None      False  ...  SecondHalf
# 20   82.372332  35.830001   60     None       True  ...  SecondHalf
# 21   87.104408  32.398751   60     None       True  ...  SecondHalf
# 22   94.385966  21.547005   70     None      False  ...  SecondHalf
# 23   95.736845  22.457835   80     None       True  ...  SecondHalf
# 24   95.640348  30.340001   80     None      False  ...  SecondHalf
# 25   93.099998  26.774046   84     None      False  ...  SecondHalf
# 26   95.061402  32.017501   88     None       True  ...  SecondHalf
#
#     isOwnGoal     firstName            lastName  teamColor  shortName  \
# 0       False        Darwin               Nunez    #d3171e        NaN
# 1       False        Darwin               Nunez    #d3171e        NaN
# 2       False        Vitaly              Janelt    #C00808        NaN
# 3       False         Bryan              Mbeumo    #C00808        NaN
# 4       False         Bryan              Mbeumo    #C00808        NaN
# 5        True      Ibrahima              Konaté    #d3171e        NaN
# 6       False          Alex  Oxlade-Chamberlain    #d3171e        NaN
# 7       False  Konstantinos            Tsimikas    #d3171e        NaN
# 8       False  Konstantinos            Tsimikas    #d3171e        NaN
# 9       False       Mathias              Jensen    #C00808        NaN
# 10      False     Christian            Nørgaard    #C00808        NaN
# 11      False         Ethan             Pinnock    #C00808        NaN
# 12      False         Ethan             Pinnock    #C00808        NaN
# 13      False      Ibrahima              Konaté    #d3171e        NaN
# 14      False          Alex  Oxlade-Chamberlain    #d3171e        NaN
# 15      False         Yoane               Wissa    #C00808        NaN
# 16      False         Yoane               Wissa    #C00808        NaN
# 17      False  Konstantinos            Tsimikas    #d3171e        NaN
# 18      False          Alex  Oxlade-Chamberlain    #d3171e        NaN
# 19      False                           Fabinho    #d3171e        NaN
# 20      False        Thiago           Alcántara    #d3171e     Thiago
# 21      False        Thiago           Alcántara    #d3171e     Thiago
# 22      False        Darwin               Nunez    #d3171e        NaN
# 23      False       Mohamed               Salah    #d3171e        NaN
# 24      False      Ibrahima              Konaté    #d3171e        NaN
# 25      False         Bryan              Mbeumo    #C00808        NaN
# 26      False          Naby               Keita    #d3171e        NaN
#
#     matchId  onGoalShot_X onGoalShot_Y onGoalShot_ZR
# 0   3901114  1.342923e+00     0.322751      1.000000
# 1   3901114  8.184524e-01     0.322751      1.000000
# 2   3901114  1.443783e+00     0.193651      1.000000
# 3   3901114  2.000000e+00     0.126459      0.535573
# 4   3901114  1.625331e+00     0.161376      1.000000
# 5   3901114  1.847222e+00     0.054358      1.000000
# 6   3901114  2.000000e+00     0.036992      0.388869
# 7   3901114  2.738095e-01     0.032275      1.000000
# 8   3901114  8.789683e-01     0.322751      1.000000
# 9   3901114  1.000000e+00     0.322751      1.000000
# 10  3901114  7.377646e-01     0.074742      1.000000
# 11  3901114  1.221892e+00     0.086633      1.000000
# 12  3901114  1.201720e+00     0.161376      1.000000
# 13  3901114  1.020172e+00     0.322751      1.000000
# 14  3901114  7.982804e-01     0.096825      1.000000
# 15  3901114  2.000000e+00     0.129028      0.365179
# 16  3901114  4.351852e-01     0.312559      1.000000
# 17  3901114  5.763889e-01     0.225926      1.000000
# 18  3901114  5.763889e-01     0.225926      1.000000
# 19  3901114  7.208995e-02     0.042467      1.000000
# 20  3901114  8.386243e-01     0.322751      1.000000
# 21  3901114  3.746693e-01     0.307463      1.000000
# 22  3901114  0.000000e+00     0.011473      0.160815
# 23  3901114  1.000000e+00     0.322751      1.000000
# 24  3901114  1.110223e-16     0.197615      0.642727
# 25  3901114  7.377646e-01     0.086633      1.000000
# 26  3901114  1.040344e+00     0.322751      1.000000
#
# [27 rows x 29 columns]
