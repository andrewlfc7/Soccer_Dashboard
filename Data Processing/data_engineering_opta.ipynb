# %%
import pandas as pd
import sqlite3
import json
from ast import literal_eval

# %%
from  analysis_tools import whoscored_data_engineering as wcde
import analysis_tools.whoscored_custom_events as ws_custom_events

# %%
data = open('Data/unprocess data/liverpool03_11_23.json', encoding='utf-8')
data = json.load(data)

# %%
event_data = data['matchCentreData']

# %%
player_id = event_data['playerIdNameDictionary']
player_id
# Out:
# {'328330': 'Marcos Senesi',
#  '76202': 'Neto',
#  '422183': 'Dango Ouattara',
#  '133464': 'Jefferson Lerma',
#  '145277': 'Philip Billing',
#  '362806': 'Mark Travers',
#  '397846': 'Matías Viña',
#  '83554': 'Ryan Fredericks',
#  '69877': 'Adam Smith',
#  '92550': 'Jack Stephens',
#  '136456': 'Lewis Cook',
#  '136459': 'Dominic Solanke',
#  '357073': 'Antoine Semenyo',
#  '332419': 'Lloyd Kelly',
#  '260784': 'Joe Rothwell',
#  '400610': 'Jaidon Anthony',
#  '128882': 'Ryan Christie',
#  '342842': 'Chris Mepham',
#  '295084': 'David Brooks',
#  '133190': 'Kieffer Moore',
#  '114147': 'Alisson',
#  '115916': 'Fabinho',
#  '284114': 'Arthur',
#  '96182': 'Roberto Firmino',
#  '74341': 'Joël Matip',
#  '108226': 'Mohamed Salah',
#  '345957': 'Ibrahima Konaté',
#  '301455': 'Konstantinos Tsimikas',
#  '95408': 'Virgil van Dijk',
#  '352825': 'Cody Gakpo',
#  '401385': 'Fábio Carvalho',
#  '235755': 'Diogo Jota',
#  '73399': 'Adrián',
#  '444540': 'Stefan Bajcetic',
#  '400828': 'Darwin Núñez',
#  '363982': 'Harvey Elliott',
#  '318871': 'Trent Alexander-Arnold',
#  '4511': 'James Milner',
#  '68659': 'Jordan Henderson',
#  '115726': 'Andrew Robertson'}

# %%
match_id = data['matchId']

# %%
home_data = data['matchCentreData']['home']

# %%
home_team_name =  event_data['home']['name']
# Out:
# 'Bournemouth'

# %%
away_team_name =  event_data['away']['name']
# Out:
# 'Liverpool'

# %%
home_teamID = event_data['home']['teamId']

# %%
away_teamID = event_data['away']['teamId']

# %%
events = event_data['events']
# Out:
# [{'id': 2518191939.0,
#   'eventId': 2,
#   'minute': 0,
#   'second': 0,
#   'teamId': 183,
#   'x': 0.0,
#   'y': 0.0,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 32, 'displayName': 'Start'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [],
#   'isTouch': False},
#  {'id': 2518191935.0,
#   'eventId': 2,
#   'minute': 0,
#   'second': 0,
#   'teamId': 26,
#   'x': 0.0,
#   'y': 0.0,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 32, 'displayName': 'Start'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [],
#   'isTouch': False},
#  {'id': 2518191993.0,
#   'eventId': 3,
#   'minute': 0,
#   'second': 1,
#   'teamId': 26,
#   'playerId': 363982,
#   'x': 50.1,
#   'y': 49.7,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '3.4'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '41.6'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '28.9'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '22.9'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 38, 215, 218],
#   'isTouch': True,
#   'endX': 28.9,
#   'endY': 41.6},
#  {'id': 2518192037.0,
#   'eventId': 4,
#   'minute': 0,
#   'second': 3,
#   'teamId': 26,
#   'playerId': 345957,
#   'x': 29.6,
#   'y': 41.6,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 1, 'displayName': 'Longball'}},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.6'},
#    {'type': {'value': 155, 'displayName': 'Chipped'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '78.2'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '62.2'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '42.3'}],
#   'satisfiedEventsTypes': [91, 120, 124, 128, 36, 37, 216, 218],
#   'isTouch': True,
#   'endX': 62.2,
#   'endY': 78.2},
#  {'id': 2518192067.0,
#   'eventId': 3,
#   'minute': 0,
#   'second': 6,
#   'teamId': 183,
#   'playerId': 422183,
#   'x': 35.6,
#   'y': 23.8,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 44, 'displayName': 'Aerial'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 233,
#      'displayName': 'OppositeRelatedEvent'},
#     'value': '5'},
#    {'type': {'value': 285, 'displayName': 'Defensive'}},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [197, 200],
#   'isTouch': False},
#  {'id': 2518192039.0,
#   'eventId': 5,
#   'minute': 0,
#   'second': 6,
#   'teamId': 26,
#   'playerId': 400828,
#   'x': 64.4,
#   'y': 76.2,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 44, 'displayName': 'Aerial'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Center'},
#    {'type': {'value': 286, 'displayName': 'Offensive'}},
#    {'type': {'value': 233, 'displayName': 'OppositeRelatedEvent'},
#     'value': '3'}],
#   'satisfiedEventsTypes': [198, 199],
#   'isTouch': False},
#  {'id': 2518192077.0,
#   'eventId': 4,
#   'minute': 0,
#   'second': 7,
#   'teamId': 183,
#   'playerId': 422183,
#   'x': 33.6,
#   'y': 25.1,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 3, 'displayName': 'HeadPass'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '12.2'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '45.1'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '14.9'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '5.7'}],
#   'satisfiedEventsTypes': [91, 118, 120, 29, 139, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 45.1,
#   'endY': 12.2},
#  {'id': 2518192095.0,
#   'eventId': 6,
#   'minute': 0,
#   'second': 8,
#   'teamId': 26,
#   'playerId': 115916,
#   'x': 56.1,
#   'y': 81.2,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '1.3'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '8.4'},
#    {'type': {'value': 3, 'displayName': 'HeadPass'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '93.0'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '58.4'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Left'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 139, 36, 37, 216, 218],
#   'isTouch': True,
#   'endX': 58.4,
#   'endY': 93.0},
#  {'id': 2518192115.0,
#   'eventId': 7,
#   'minute': 0,
#   'second': 10,
#   'teamId': 26,
#   'playerId': 115726,
#   'x': 58.4,
#   'y': 93.0,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 212, 'displayName': 'Length'},
#     'value': '25.6'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '74.4'},
#    {'type': {'value': 1, 'displayName': 'Longball'}},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '5.8'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '79.6'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'}],
#   'satisfiedEventsTypes': [91, 120, 128, 36, 38, 217, 218],
#   'isTouch': True,
#   'endX': 79.6,
#   'endY': 74.4},
#  {'id': 2518192163.0,
#   'eventId': 5,
#   'minute': 0,
#   'second': 11,
#   'teamId': 183,
#   'playerId': 92550,
#   'x': 20.4,
#   'y': 23.2,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '5.3'},
#    {'type': {'value': 3, 'displayName': 'HeadPass'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '5.9'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '27.3'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '13.8'}],
#   'satisfiedEventsTypes': [91, 117, 30, 139, 36, 38, 215, 218],
#   'isTouch': True,
#   'endX': 27.3,
#   'endY': 5.9},
#  {'id': 2518192173.0,
#   'eventId': 6,
#   'minute': 0,
#   'second': 14,
#   'teamId': 183,
#   'playerId': 422183,
#   'x': 27.3,
#   'y': 5.9,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '34.7'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '7.8'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '6.2'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '5.0'},
#    {'type': {'value': 3, 'displayName': 'HeadPass'}},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [91, 118, 120, 29, 139, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 34.7,
#   'endY': 5.0},
#  {'id': 2518192177.0,
#   'eventId': 8,
#   'minute': 0,
#   'second': 15,
#   'teamId': 26,
#   'playerId': 115726,
#   'x': 61.2,
#   'y': 87.9,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 61, 'displayName': 'BallTouch'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Left'}],
#   'satisfiedEventsTypes': [91, 69],
#   'isTouch': True},
#  {'id': 2518192185.0,
#   'eventId': 7,
#   'minute': 0,
#   'second': 15,
#   'teamId': 183,
#   'playerId': 145277,
#   'x': 30.0,
#   'y': 7.4,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 49, 'displayName': 'BallRecovery'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [93],
#   'isTouch': False},
#  {'id': 2518192207.0,
#   'eventId': 8,
#   'minute': 0,
#   'second': 16,
#   'teamId': 183,
#   'playerId': 145277,
#   'x': 30.0,
#   'y': 7.4,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 141, 'displayName': 'PassEndY'},
#     'value': '7.3'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '39.7'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '10.2'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '6.3'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 39.7,
#   'endY': 7.3},
#  {'id': 2518192213.0,
#   'eventId': 9,
#   'minute': 0,
#   'second': 18,
#   'teamId': 183,
#   'playerId': 136459,
#   'x': 40.4,
#   'y': 4.0,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 61, 'displayName': 'BallTouch'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'}],
#   'satisfiedEventsTypes': [91, 69],
#   'isTouch': True},
#  {'id': 2518192359.0,
#   'eventId': 10,
#   'minute': 0,
#   'second': 23,
#   'teamId': 26,
#   'playerId': 115726,
#   'x': 44.9,
#   'y': 100.0,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 141, 'displayName': 'PassEndY'},
#     'value': '95.6'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '3.4'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 107, 'displayName': 'ThrowIn'}},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '28.6'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '17.5'}],
#   'satisfiedEventsTypes': [91, 212, 35, 38, 215],
#   'isTouch': True,
#   'endX': 28.6,
#   'endY': 95.6},
#  {'id': 2518192399.0,
#   'eventId': 11,
#   'minute': 0,
#   'second': 28,
#   'teamId': 26,
#   'playerId': 95408,
#   'x': 27.5,
#   'y': 91.1,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 141, 'displayName': 'PassEndY'},
#     'value': '60.6'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '4.7'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '20.7'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '27.2'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 38, 215, 218],
#   'isTouch': True,
#   'endX': 27.2,
#   'endY': 60.6},
#  {'id': 2518192427.0,
#   'eventId': 12,
#   'minute': 0,
#   'second': 31,
#   'teamId': 26,
#   'playerId': 345957,
#   'x': 26.7,
#   'y': 50.1,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '4.9'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '31.0'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '26.8'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '11.3'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 38, 215, 218],
#   'isTouch': True,
#   'endX': 31.0,
#   'endY': 11.3},
#  {'id': 2518192437.0,
#   'eventId': 13,
#   'minute': 0,
#   'second': 34,
#   'teamId': 26,
#   'playerId': 318871,
#   'x': 31.1,
#   'y': 10.6,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '40.7'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '6.4'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '6.0'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '10.5'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 40.7,
#   'endY': 6.4},
#  {'id': 2518192453.0,
#   'eventId': 14,
#   'minute': 0,
#   'second': 35,
#   'teamId': 26,
#   'playerId': 108226,
#   'x': 40.7,
#   'y': 6.4,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '56.1'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '17.3'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Right'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '17.8'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.4'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 36, 37, 216, 218],
#   'isTouch': True,
#   'endX': 56.1,
#   'endY': 17.3},
#  {'id': 2518192461.0,
#   'eventId': 15,
#   'minute': 0,
#   'second': 37,
#   'teamId': 26,
#   'playerId': 363982,
#   'x': 56.1,
#   'y': 17.3,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 141, 'displayName': 'PassEndY'},
#     'value': '32.2'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '10.1'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '1.5'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '56.5'}],
#   'satisfiedEventsTypes': [91, 120, 29, 36, 37, 216, 218],
#   'isTouch': True,
#   'endX': 56.5,
#   'endY': 32.2},
#  {'id': 2518192471.0,
#   'eventId': 11,
#   'minute': 0,
#   'second': 38,
#   'teamId': 183,
#   'playerId': 145277,
#   'x': 42.6,
#   'y': 71.3,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 8, 'displayName': 'Interception'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'}],
#   'satisfiedEventsTypes': [91, 101, 56],
#   'isTouch': True},
#  {'id': 2518192481.0,
#   'eventId': 12,
#   'minute': 0,
#   'second': 39,
#   'teamId': 183,
#   'playerId': 133464,
#   'x': 36.4,
#   'y': 71.0,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 49, 'displayName': 'BallRecovery'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [93],
#   'isTouch': False},
#  {'id': 2518192505.0,
#   'eventId': 13,
#   'minute': 0,
#   'second': 41,
#   'teamId': 183,
#   'playerId': 133464,
#   'x': 36.6,
#   'y': 67.3,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 4, 'displayName': 'Foul'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 13, 'displayName': 'Foul'}},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 286, 'displayName': 'Offensive'}},
#    {'type': {'value': 233, 'displayName': 'OppositeRelatedEvent'},
#     'value': '16'}],
#   'satisfiedEventsTypes': [91, 63],
#   'isTouch': True},
#  {'id': 2518192529.0,
#   'eventId': 16,
#   'minute': 0,
#   'second': 41,
#   'teamId': 26,
#   'playerId': 115916,
#   'x': 63.4,
#   'y': 32.7,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 4, 'displayName': 'Foul'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 13, 'displayName': 'Foul'}},
#    {'type': {'value': 285, 'displayName': 'Defensive'}},
#    {'type': {'value': 233, 'displayName': 'OppositeRelatedEvent'},
#     'value': '13'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'}],
#   'satisfiedEventsTypes': [64],
#   'isTouch': False},
#  {'id': 2518192729.0,
#   'eventId': 14,
#   'minute': 0,
#   'second': 57,
#   'teamId': 183,
#   'playerId': 328330,
#   'x': 34.8,
#   'y': 70.4,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '81.2'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '94.2'},
#    {'type': {'value': 5, 'displayName': 'FreekickTaken'}},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.3'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Left'},
#    {'type': {'value': 1, 'displayName': 'Longball'}},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '51.3'},
#    {'type': {'value': 155, 'displayName': 'Chipped'}}],
#   'satisfiedEventsTypes': [91, 119, 117, 124, 127, 132, 205, 36, 37, 217, 218],
#   'isTouch': True,
#   'endX': 81.2,
#   'endY': 94.2},
#  {'id': 2518192777.0,
#   'eventId': 15,
#   'minute': 1,
#   'second': 2,
#   'teamId': 183,
#   'playerId': 136459,
#   'x': 80.3,
#   'y': 94.2,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '3.8'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Left'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '11.1'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '84.6'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '71.7'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 205, 35, 38, 217, 218],
#   'isTouch': True,
#   'endX': 71.7,
#   'endY': 84.6},
#  {'id': 2518192787.0,
#   'eventId': 16,
#   'minute': 1,
#   'second': 5,
#   'teamId': 183,
#   'playerId': 133464,
#   'x': 70.1,
#   'y': 77.8,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 3, 'displayName': 'TakeOn'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 233,
#      'displayName': 'OppositeRelatedEvent'},
#     'value': '17'},
#    {'type': {'value': 286, 'displayName': 'Offensive'}},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'}],
#   'satisfiedEventsTypes': [91, 53],
#   'isTouch': True},
#  {'id': 2518192793.0,
#   'eventId': 17,
#   'minute': 1,
#   'second': 5,
#   'teamId': 26,
#   'playerId': 352825,
#   'x': 29.9,
#   'y': 22.2,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 7, 'displayName': 'Tackle'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 285, 'displayName': 'Defensive'}},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 233, 'displayName': 'OppositeRelatedEvent'},
#     'value': '16'}],
#   'satisfiedEventsTypes': [91, 142],
#   'isTouch': True},
#  {'id': 2518192791.0,
#   'eventId': 17,
#   'minute': 1,
#   'second': 6,
#   'teamId': 183,
#   'playerId': 133464,
#   'x': 69.9,
#   'y': 78.3,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 61, 'displayName': 'BallTouch'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Center'}],
#   'satisfiedEventsTypes': [91],
#   'isTouch': True},
#  {'id': 2518192813.0,
#   'eventId': 18,
#   'minute': 1,
#   'second': 8,
#   'teamId': 26,
#   'playerId': 345957,
#   'x': 26.0,
#   'y': 28.9,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 49, 'displayName': 'BallRecovery'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [93],
#   'isTouch': False},
#  {'id': 2518192829.0,
#   'eventId': 19,
#   'minute': 1,
#   'second': 9,
#   'teamId': 26,
#   'playerId': 345957,
#   'x': 25.9,
#   'y': 28.0,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '5.1'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '20.0'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '6.0'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '28.3'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 38, 215, 218],
#   'isTouch': True,
#   'endX': 28.3,
#   'endY': 20.0},
#  {'id': 2518192845.0,
#   'eventId': 20,
#   'minute': 1,
#   'second': 10,
#   'teamId': 26,
#   'playerId': 363982,
#   'x': 28.3,
#   'y': 20.0,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '22.9'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '20.1'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '2.9'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '8.8'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 37, 215, 218],
#   'isTouch': True,
#   'endX': 20.1,
#   'endY': 22.9},
#  {'id': 2518192871.0,
#   'eventId': 21,
#   'minute': 1,
#   'second': 11,
#   'teamId': 26,
#   'playerId': 318871,
#   'x': 20.2,
#   'y': 22.6,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 212, 'displayName': 'Length'},
#     'value': '38.4'},
#    {'type': {'value': 155, 'displayName': 'Chipped'}},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Right'},
#    {'type': {'value': 1, 'displayName': 'Longball'}},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '6.1'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '11.0'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '56.0'}],
#   'satisfiedEventsTypes': [91, 120, 124, 128, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 56.0,
#   'endY': 11.0},
#  {'id': 2518192879.0,
#   'eventId': 18,
#   'minute': 1,
#   'second': 13,
#   'teamId': 183,
#   'playerId': 332419,
#   'x': 46.4,
#   'y': 90.9,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 49, 'displayName': 'BallRecovery'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [93],
#   'isTouch': False},
#  {'id': 2518192911.0,
#   'eventId': 19,
#   'minute': 1,
#   'second': 14,
#   'teamId': 183,
#   'playerId': 332419,
#   'x': 47.0,
#   'y': 93.9,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '8.0'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '82.2'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '47.2'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '4.7'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 47.2,
#   'endY': 82.2},
#  {'id': 2518192943.0,
#   'eventId': 20,
#   'minute': 1,
#   'second': 16,
#   'teamId': 183,
#   'playerId': 328330,
#   'x': 47.2,
#   'y': 82.2,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 212, 'displayName': 'Length'},
#     'value': '12.3'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Left'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '57.3'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '91.5'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.5'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 36, 37, 216, 218],
#   'isTouch': True,
#   'endX': 57.3,
#   'endY': 91.5},
#  {'id': 2518192951.0,
#   'eventId': 21,
#   'minute': 1,
#   'second': 18,
#   'teamId': 183,
#   'playerId': 400610,
#   'x': 62.2,
#   'y': 91.0,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 3, 'displayName': 'TakeOn'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 286, 'displayName': 'Offensive'}},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Left'},
#    {'type': {'value': 233, 'displayName': 'OppositeRelatedEvent'},
#     'value': '22'}],
#   'satisfiedEventsTypes': [91, 54],
#   'isTouch': True},
#  {'id': 2518192945.0,
#   'eventId': 22,
#   'minute': 1,
#   'second': 18,
#   'teamId': 26,
#   'playerId': 363982,
#   'x': 37.8,
#   'y': 9.0,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 45, 'displayName': 'Challenge'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 285, 'displayName': 'Defensive'}},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 233, 'displayName': 'OppositeRelatedEvent'},
#     'value': '21'}],
#   'satisfiedEventsTypes': [55],
#   'isTouch': False},
#  {'id': 2518192955.0,
#   'eventId': 22,
#   'minute': 1,
#   'second': 19,
#   'teamId': 183,
#   'playerId': 400610,
#   'x': 55.5,
#   'y': 85.7,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 61, 'displayName': 'BallTouch'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Left'}],
#   'satisfiedEventsTypes': [91, 69],
#   'isTouch': True},
#  {'id': 2518192969.0,
#   'eventId': 23,
#   'minute': 1,
#   'second': 21,
#   'teamId': 26,
#   'playerId': 115916,
#   'x': 31.3,
#   'y': 13.7,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 61, 'displayName': 'BallTouch'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'}],
#   'satisfiedEventsTypes': [91],
#   'isTouch': True},
#  {'id': 2518192987.0,
#   'eventId': 24,
#   'minute': 1,
#   'second': 22,
#   'teamId': 26,
#   'playerId': 318871,
#   'x': 36.5,
#   'y': 12.7,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 49, 'displayName': 'BallRecovery'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [93],
#   'isTouch': False},
#  {'id': 2518193003.0,
#   'eventId': 25,
#   'minute': 1,
#   'second': 22,
#   'teamId': 26,
#   'playerId': 318871,
#   'x': 36.5,
#   'y': 12.7,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '27.9'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '2.5'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '11.5'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '23.2'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 37, 215, 218],
#   'isTouch': True,
#   'endX': 27.9,
#   'endY': 23.2},
#  {'id': 2518193067.0,
#   'eventId': 26,
#   'minute': 1,
#   'second': 23,
#   'teamId': 26,
#   'playerId': 345957,
#   'x': 27.9,
#   'y': 23.2,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '19.3'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '2.5'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '12.8'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '39.4'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 37, 215, 218],
#   'isTouch': True,
#   'endX': 12.8,
#   'endY': 39.4},
#  {'id': 2518193099.0,
#   'eventId': 27,
#   'minute': 1,
#   'second': 29,
#   'teamId': 26,
#   'playerId': 114147,
#   'x': 13.2,
#   'y': 44.0,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.9'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '17.9'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '7.7'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '52.7'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 37, 215, 218],
#   'isTouch': True,
#   'endX': 17.9,
#   'endY': 52.7},
#  {'id': 2518193145.0,
#   'eventId': 28,
#   'minute': 1,
#   'second': 31,
#   'teamId': 26,
#   'playerId': 95408,
#   'x': 18.0,
#   'y': 51.9,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 212, 'displayName': 'Length'},
#     'value': '13.6'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '4.8'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '32.0'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '19.6'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 38, 215, 218],
#   'isTouch': True,
#   'endX': 19.6,
#   'endY': 32.0},
#  {'id': 2518193187.0,
#   'eventId': 29,
#   'minute': 1,
#   'second': 34,
#   'teamId': 26,
#   'playerId': 345957,
#   'x': 27.3,
#   'y': 21.7,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 141, 'displayName': 'PassEndY'},
#     'value': '5.8'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '18.8'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '5.7'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '42.0'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 42.0,
#   'endY': 5.8},
#  {'id': 2518193219.0,
#   'eventId': 30,
#   'minute': 1,
#   'second': 37,
#   'teamId': 26,
#   'playerId': 108226,
#   'x': 41.9,
#   'y': 4.7,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '3.0'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '29.6'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '13.0'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '7.0'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 37, 215, 218],
#   'isTouch': True,
#   'endX': 29.6,
#   'endY': 7.0},
#  {'id': 2518193267.0,
#   'eventId': 31,
#   'minute': 1,
#   'second': 40,
#   'teamId': 26,
#   'playerId': 318871,
#   'x': 29.5,
#   'y': 7.3,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '26.2'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '1.9'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '13.6'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '25.2'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 37, 215, 218],
#   'isTouch': True,
#   'endX': 25.2,
#   'endY': 26.2},
#  {'id': 2518193299.0,
#   'eventId': 32,
#   'minute': 1,
#   'second': 43,
#   'teamId': 26,
#   'playerId': 345957,
#   'x': 25.1,
#   'y': 26.8,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 141, 'displayName': 'PassEndY'},
#     'value': '42.7'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '12.6'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '17.0'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '2.5'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 37, 215, 218],
#   'isTouch': True,
#   'endX': 12.6,
#   'endY': 42.7},
#  {'id': 2518193317.0,
#   'eventId': 33,
#   'minute': 1,
#   'second': 45,
#   'teamId': 26,
#   'playerId': 114147,
#   'x': 12.7,
#   'y': 42.7,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '24.9'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '50.6'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '13.9'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.4'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 37, 215, 218],
#   'isTouch': True,
#   'endX': 24.9,
#   'endY': 50.6},
#  {'id': 2518193327.0,
#   'eventId': 34,
#   'minute': 1,
#   'second': 46,
#   'teamId': 26,
#   'playerId': 444540,
#   'x': 24.9,
#   'y': 50.6,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '17.5'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 156, 'displayName': 'LayOff'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '69.2'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '2.1'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '14.8'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 37, 215, 218],
#   'isTouch': True,
#   'endX': 17.5,
#   'endY': 69.2},
#  {'id': 2518193361.0,
#   'eventId': 35,
#   'minute': 1,
#   'second': 48,
#   'teamId': 26,
#   'playerId': 95408,
#   'x': 18.7,
#   'y': 69.3,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '14.9'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '32.8'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '66.6'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '6.2'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 38, 215, 218],
#   'isTouch': True,
#   'endX': 32.8,
#   'endY': 66.6},
#  {'id': 2518193367.0,
#   'eventId': 36,
#   'minute': 1,
#   'second': 51,
#   'teamId': 26,
#   'playerId': 352825,
#   'x': 32.1,
#   'y': 62.7,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '4.8'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '17.1'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '33.6'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '37.7'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 33.6,
#   'endY': 37.7},
#  {'id': 2518193393.0,
#   'eventId': 37,
#   'minute': 1,
#   'second': 52,
#   'teamId': 26,
#   'playerId': 115916,
#   'x': 33.5,
#   'y': 37.7,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '3.4'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '23.2'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '33.7'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '11.2'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 38, 215, 218],
#   'isTouch': True,
#   'endX': 23.2,
#   'endY': 33.7},
#  {'id': 2518193413.0,
#   'eventId': 38,
#   'minute': 1,
#   'second': 53,
#   'teamId': 26,
#   'playerId': 345957,
#   'x': 24.1,
#   'y': 33.8,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 141, 'displayName': 'PassEndY'},
#     'value': '9.4'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '5.5'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '23.5'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '40.0'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 40.0,
#   'endY': 9.4},
#  {'id': 2518193431.0,
#   'eventId': 39,
#   'minute': 1,
#   'second': 56,
#   'teamId': 26,
#   'playerId': 318871,
#   'x': 41.7,
#   'y': 7.9,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '63.6'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.4'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '24.6'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Right'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '20.8'}],
#   'satisfiedEventsTypes': [91, 120, 29, 36, 37, 216, 218],
#   'isTouch': True,
#   'endX': 63.6,
#   'endY': 20.8},
#  {'id': 2518193441.0,
#   'eventId': 23,
#   'minute': 1,
#   'second': 58,
#   'teamId': 183,
#   'playerId': 328330,
#   'x': 30.9,
#   'y': 80.9,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '38.2'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '86.0'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '8.4'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.4'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 37, 216, 218],
#   'isTouch': True,
#   'endX': 38.2,
#   'endY': 86.0},
#  {'id': 2518193445.0,
#   'eventId': 24,
#   'minute': 1,
#   'second': 59,
#   'teamId': 183,
#   'playerId': 133464,
#   'x': 38.0,
#   'y': 86.3,
#   'expandedMinute': 1,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 49, 'displayName': 'BallRecovery'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [93],
#   'isTouch': False},
#  {'id': 2518193455.0,
#   'eventId': 25,
#   'minute': 2,
#   'second': 0,
#   'teamId': 183,
#   'playerId': 133464,
#   'x': 38.0,
#   'y': 86.3,
#   'expandedMinute': 2,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '95.7'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '1.3'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '6.6'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '39.6'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 37, 216, 218],
#   'isTouch': True,
#   'endX': 39.6,
#   'endY': 95.7},
#  {'id': 2518193461.0,
#   'eventId': 26,
#   'minute': 2,
#   'second': 0,
#   'teamId': 183,
#   'playerId': 400610,
#   'x': 39.6,
#   'y': 95.7,
#   'expandedMinute': 2,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 141, 'displayName': 'PassEndY'},
#     'value': '87.9'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '8.0'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '45.3'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '5.6'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 45.3,
#   'endY': 87.9},
#  {'id': 2518193473.0,
#   'eventId': 27,
#   'minute': 2,
#   'second': 1,
#   'teamId': 183,
#   'playerId': 145277,
#   'x': 45.2,
#   'y': 87.8,
#   'expandedMinute': 2,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '42.7'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '4.1'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '4.9'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '81.8'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 38, 216, 218],
#   'isTouch': True,
#   'endX': 42.7,
#   'endY': 81.8},
#  {'id': 2518193507.0,
#   'eventId': 28,
#   'minute': 2,
#   'second': 2,
#   'teamId': 183,
#   'playerId': 133464,
#   'x': 42.7,
#   'y': 81.8,
#   'expandedMinute': 2,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 212, 'displayName': 'Length'},
#     'value': '36.2'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.4'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Left'},
#    {'type': {'value': 1, 'displayName': 'Longball'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '100.0'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '74.9'}],
#   'satisfiedEventsTypes': [91, 120, 128, 36, 37, 217, 218],
#   'isTouch': True,
#   'endX': 74.9,
#   'endY': 100.0},
#  {'id': 2518193615.0,
#   'eventId': 41,
#   'minute': 2,
#   'second': 17,
#   'teamId': 26,
#   'playerId': 318871,
#   'x': 28.1,
#   'y': 0.0,
#   'expandedMinute': 2,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 107, 'displayName': 'ThrowIn'}},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '13.7'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '16.6'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '8.9'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '2.7'}],
#   'satisfiedEventsTypes': [91, 212, 35, 37, 215],
#   'isTouch': True,
#   'endX': 13.7,
#   'endY': 8.9},
#  {'id': 2518193643.0,
#   'eventId': 42,
#   'minute': 2,
#   'second': 19,
#   'teamId': 26,
#   'playerId': 345957,
#   'x': 14.1,
#   'y': 10.9,
#   'expandedMinute': 2,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '5.9'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '5.8'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '22.8'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '9.8'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 38, 215, 218],
#   'isTouch': True,
#   'endX': 22.8,
#   'endY': 5.8},
#  {'id': 2518193705.0,
#   'eventId': 43,
#   'minute': 2,
#   'second': 21,
#   'teamId': 26,
#   'playerId': 318871,
#   'x': 22.8,
#   'y': 5.8,
#   'expandedMinute': 2,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '2.1'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '7.8'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '43.1'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '29.9'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 37, 215, 218],
#   'isTouch': True,
#   'endX': 7.8,
#   'endY': 43.1},
#  {'id': 2518193741.0,
#   'eventId': 44,
#   'minute': 2,
#   'second': 29,
#   'teamId': 26,
#   'playerId': 114147,
#   'x': 19.4,
#   'y': 36.2,
#   'expandedMinute': 2,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 212, 'displayName': 'Length'},
#     'value': '12.4'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '18.2'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '4.9'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '21.2'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 38, 215, 218],
#   'isTouch': True,
#   'endX': 21.2,
#   'endY': 18.2},
#  {'id': 2518193773.0,
#   'eventId': 45,
#   'minute': 2,
#   'second': 32,
#   'teamId': 26,
# ...
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 37, 216, 218],
#   'isTouch': True,
#   'endX': 45.0,
#   'endY': 56.7},
#  {'id': 2518249657.0,
#   'eventId': 436,
#   'minute': 56,
#   'second': 14,
#   'teamId': 183,
#   'playerId': 332419,
#   'x': 44.5,
#   'y': 58.3,
#   'expandedMinute': 58,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '84.8'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Left'},
#    {'type': {'value': 1, 'displayName': 'Longball'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '100.0'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '51.4'},
#    {'type': {'value': 155, 'displayName': 'Chipped'}},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.6'}],
#   'satisfiedEventsTypes': [91, 120, 124, 128, 36, 37, 217, 218],
#   'isTouch': True,
#   'endX': 84.8,
#   'endY': 100.0},
#  {'id': 2518249969.0,
#   'eventId': 633,
#   'minute': 56,
#   'second': 30,
#   'teamId': 26,
#   'playerId': 318871,
#   'x': 20.8,
#   'y': 0.0,
#   'expandedMinute': 58,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 107, 'displayName': 'ThrowIn'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '6.4'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '10.3'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '29.3'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.5'}],
#   'satisfiedEventsTypes': [91, 212, 36, 37, 215],
#   'isTouch': True,
#   'endX': 29.3,
#   'endY': 6.4},
#  {'id': 2518249977.0,
#   'eventId': 634,
#   'minute': 56,
#   'second': 31,
#   'teamId': 26,
#   'playerId': 444540,
#   'x': 29.3,
#   'y': 6.4,
#   'expandedMinute': 58,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 61, 'displayName': 'BallTouch'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'}],
#   'satisfiedEventsTypes': [91],
#   'isTouch': True},
#  {'id': 2518250547.0,
#   'eventId': 442,
#   'minute': 56,
#   'second': 32,
#   'teamId': 183,
#   'playerId': 145277,
#   'x': 66.4,
#   'y': 86.4,
#   'expandedMinute': 58,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '59.4'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '12.7'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '71.1'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '4.1'}],
#   'satisfiedEventsTypes': [91, 119, 117, 30, 35, 38, 216, 218],
#   'isTouch': True,
#   'endX': 59.4,
#   'endY': 71.1},
#  {'id': 2518249943.0,
#   'eventId': 438,
#   'minute': 56,
#   'second': 33,
#   'teamId': 183,
#   'playerId': 328330,
#   'x': 61.4,
#   'y': 71.1,
#   'expandedMinute': 58,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 49, 'displayName': 'BallRecovery'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [93],
#   'isTouch': False},
#  {'id': 2518250019.0,
#   'eventId': 439,
#   'minute': 56,
#   'second': 37,
#   'teamId': 183,
#   'playerId': 328330,
#   'x': 73.1,
#   'y': 58.8,
#   'expandedMinute': 58,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '84.3'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '5.3'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '34.0'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '20.6'}],
#   'satisfiedEventsTypes': [91, 120, 29, 36, 38, 217, 218],
#   'isTouch': True,
#   'endX': 84.3,
#   'endY': 34.0},
#  {'id': 2518250025.0,
#   'eventId': 635,
#   'minute': 56,
#   'second': 38,
#   'teamId': 26,
#   'playerId': 115726,
#   'x': 15.0,
#   'y': 65.3,
#   'expandedMinute': 58,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 49, 'displayName': 'BallRecovery'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [93],
#   'isTouch': False},
#  {'id': 2518250057.0,
#   'eventId': 636,
#   'minute': 56,
#   'second': 38,
#   'teamId': 26,
#   'playerId': 115726,
#   'x': 15.0,
#   'y': 65.3,
#   'expandedMinute': 58,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '9.3'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '54.0'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '9.7'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '4.1'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 38, 215, 218],
#   'isTouch': True,
#   'endX': 9.3,
#   'endY': 54.0},
#  {'id': 2518250063.0,
#   'eventId': 637,
#   'minute': 56,
#   'second': 40,
#   'teamId': 26,
#   'playerId': 114147,
#   'x': 9.3,
#   'y': 54.0,
#   'expandedMinute': 58,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 212, 'displayName': 'Length'},
#     'value': '27.9'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.5'},
#    {'type': {'value': 1, 'displayName': 'Longball'}},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '32.7'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '73.5'}],
#   'satisfiedEventsTypes': [91, 118, 120, 128, 36, 37, 215, 218],
#   'isTouch': True,
#   'endX': 32.7,
#   'endY': 73.5},
#  {'id': 2518250089.0,
#   'eventId': 440,
#   'minute': 56,
#   'second': 41,
#   'teamId': 183,
#   'playerId': 69877,
#   'x': 72.9,
#   'y': 30.3,
#   'expandedMinute': 58,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 140, 'displayName': 'PassEndX'},
#     'value': '85.6'},
#    {'type': {'value': 3, 'displayName': 'HeadPass'}},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Right'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '6.9'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '20.8'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '5.4'}],
#   'satisfiedEventsTypes': [91, 120, 29, 139, 36, 38, 217, 218],
#   'isTouch': True,
#   'endX': 85.6,
#   'endY': 6.9},
#  {'id': 2518250301.0,
#   'eventId': 638,
#   'minute': 56,
#   'second': 50,
#   'teamId': 26,
#   'playerId': 115726,
#   'x': 66.8,
#   'y': 90.9,
#   'expandedMinute': 58,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 2, 'displayName': 'OffsidePass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Left'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '88.4'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '79.6'},
#    {'type': {'value': 7, 'displayName': 'PlayerCaughtOffside'},
#     'value': '400828'}],
#   'satisfiedEventsTypes': [91, 217],
#   'isTouch': True,
#   'endX': 79.6,
#   'endY': 88.4},
#  {'id': 2518250277.0,
#   'eventId': 441,
#   'minute': 56,
#   'second': 50,
#   'teamId': 183,
#   'playerId': 332419,
#   'x': 29.5,
#   'y': 67.8,
#   'expandedMinute': 58,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 55, 'displayName': 'OffsideProvoked'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [62],
#   'isTouch': False},
#  {'id': 2518250939.0,
#   'eventId': 443,
#   'minute': 57,
#   'second': 24,
#   'teamId': 183,
#   'playerId': 76202,
#   'x': 26.0,
#   'y': 34.8,
#   'expandedMinute': 59,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '6.1'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Right'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '75.1'},
#    {'type': {'value': 1, 'displayName': 'Longball'}},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '52.7'},
#    {'type': {'value': 155, 'displayName': 'Chipped'}},
#    {'type': {'value': 5, 'displayName': 'FreekickTaken'}},
#    {'type': {'value': 241, 'displayName': 'IndirectFreekickTaken'}},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '19.0'}],
#   'satisfiedEventsTypes': [91, 120, 124, 128, 133, 36, 38, 217, 218],
#   'isTouch': True,
#   'endX': 75.1,
#   'endY': 19.0},
#  {'id': 2518250987.0,
#   'eventId': 639,
#   'minute': 57,
#   'second': 28,
#   'teamId': 26,
#   'playerId': 95408,
#   'x': 25.8,
#   'y': 78.8,
#   'expandedMinute': 59,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 141, 'displayName': 'PassEndY'},
#     'value': '79.5'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '34.6'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '9.3'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.1'},
#    {'type': {'value': 3, 'displayName': 'HeadPass'}}],
#   'satisfiedEventsTypes': [91, 118, 120, 29, 139, 36, 37, 216, 218],
#   'isTouch': True,
#   'endX': 34.6,
#   'endY': 79.5},
#  {'id': 2518250991.0,
#   'eventId': 444,
#   'minute': 57,
#   'second': 28,
#   'teamId': 183,
#   'playerId': 260784,
#   'x': 64.7,
#   'y': 18.6,
#   'expandedMinute': 59,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '5.1'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '65.5'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '2.4'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '15.3'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Right'}],
#   'satisfiedEventsTypes': [91, 120, 29, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 65.5,
#   'endY': 15.3},
#  {'id': 2518252147.0,
#   'eventId': 652,
#   'minute': 57,
#   'second': 29,
#   'teamId': 26,
#   'playerId': 235755,
#   'x': 33.9,
#   'y': 92.1,
#   'expandedMinute': 59,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 61, 'displayName': 'BallTouch'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 56, 'displayName': 'Zone'},
#     'value': 'Back'}],
#   'satisfiedEventsTypes': [91],
#   'isTouch': True},
#  {'id': 2518251031.0,
#   'eventId': 640,
#   'minute': 57,
#   'second': 30,
#   'teamId': 26,
#   'playerId': 444540,
#   'x': 29.0,
#   'y': 82.7,
#   'expandedMinute': 59,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 49, 'displayName': 'BallRecovery'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [93],
#   'isTouch': False},
#  {'id': 2518251051.0,
#   'eventId': 641,
#   'minute': 57,
#   'second': 30,
#   'teamId': 26,
#   'playerId': 444540,
#   'x': 28.8,
#   'y': 83.0,
#   'expandedMinute': 59,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '5.9'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '39.7'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '12.3'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '76.4'}],
#   'satisfiedEventsTypes': [91, 117, 30, 36, 38, 216, 218],
#   'isTouch': True,
#   'endX': 39.7,
#   'endY': 76.4},
#  {'id': 2518251061.0,
#   'eventId': 642,
#   'minute': 57,
#   'second': 31,
#   'teamId': 26,
#   'playerId': 400828,
#   'x': 39.7,
#   'y': 76.4,
#   'expandedMinute': 59,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 213, 'displayName': 'Angle'},
#     'value': '3.3'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '32.5'},
#    {'type': {'value': 156, 'displayName': 'LayOff'}},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '7.7'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Back'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '74.4'}],
#   'satisfiedEventsTypes': [91, 117, 30, 35, 38, 215, 218],
#   'isTouch': True,
#   'endX': 32.5,
#   'endY': 74.4},
#  {'id': 2518251111.0,
#   'eventId': 643,
#   'minute': 57,
#   'second': 32,
#   'teamId': 26,
#   'playerId': 352825,
#   'x': 37.6,
#   'y': 76.1,
#   'expandedMinute': 59,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [{'type': {'value': 212, 'displayName': 'Length'},
#     'value': '32.3'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Left'},
#    {'type': {'value': 3, 'displayName': 'HeadPass'}},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '0.3'},
#    {'type': {'value': 1, 'displayName': 'Longball'}},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '66.7'},
#    {'type': {'value': 141, 'displayName': 'PassEndY'}, 'value': '91.7'}],
#   'satisfiedEventsTypes': [91, 119, 117, 139, 127, 205, 36, 37, 217, 218],
#   'isTouch': True,
#   'endX': 66.7,
#   'endY': 91.7},
#  {'id': 2518251163.0,
#   'eventId': 644,
#   'minute': 57,
#   'second': 36,
#   'teamId': 26,
#   'playerId': 235755,
#   'x': 69.5,
#   'y': 93.0,
#   'expandedMinute': 59,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 1, 'displayName': 'Pass'},
#   'outcomeType': {'value': 0, 'displayName': 'Unsuccessful'},
#   'qualifiers': [{'type': {'value': 141, 'displayName': 'PassEndY'},
#     'value': '52.2'},
#    {'type': {'value': 56, 'displayName': 'Zone'}, 'value': 'Center'},
#    {'type': {'value': 213, 'displayName': 'Angle'}, 'value': '4.6'},
#    {'type': {'value': 212, 'displayName': 'Length'}, 'value': '28.0'},
#    {'type': {'value': 140, 'displayName': 'PassEndX'}, 'value': '65.8'}],
#   'satisfiedEventsTypes': [91, 120, 29, 35, 38, 216, 218],
#   'isTouch': True,
#   'endX': 65.8,
#   'endY': 52.2},
#  {'id': 2518251187.0,
#   'eventId': 445,
#   'minute': 57,
#   'second': 38,
#   'teamId': 183,
#   'playerId': 400610,
#   'x': 36.2,
#   'y': 49.0,
#   'expandedMinute': 59,
#   'period': {'value': 2, 'displayName': 'SecondHalf'},
#   'type': {'value': 49, 'displayName': 'BallRecovery'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [93],
#   'isTouch': False},
#  ...]

# %%
events = pd.DataFrame(events)
events
# Out:
#                 id  eventId  minute  second  teamId     x     y  \
# 0     2.518192e+09        2       0     0.0     183   0.0   0.0
# 1     2.518192e+09        2       0     0.0      26   0.0   0.0
# 2     2.518192e+09        3       0     1.0      26  50.1  49.7
# 3     2.518192e+09        4       0     3.0      26  29.6  41.6
# 4     2.518192e+09        3       0     6.0     183  35.6  23.8
# ...            ...      ...     ...     ...     ...   ...   ...
# 1592  2.518287e+09     1052      95    13.0      26   0.0   0.0
# 1593  2.518287e+09      710       0     0.0     183   0.0   0.0
# 1594  2.518287e+09     1053       0     0.0      26   0.0   0.0
# 1595  2.518163e+09        1       0     0.0      26   0.0   0.0
# 1596  2.518163e+09        1       0     0.0     183   0.0   0.0
#
#       expandedMinute                                     period  \
# 0                  0   {'value': 1, 'displayName': 'FirstHalf'}
# 1                  0   {'value': 1, 'displayName': 'FirstHalf'}
# 2                  0   {'value': 1, 'displayName': 'FirstHalf'}
# 3                  0   {'value': 1, 'displayName': 'FirstHalf'}
# 4                  0   {'value': 1, 'displayName': 'FirstHalf'}
# ...              ...                                        ...
# 1592              97  {'value': 2, 'displayName': 'SecondHalf'}
# 1593               7   {'value': 14, 'displayName': 'PostGame'}
# 1594               7   {'value': 14, 'displayName': 'PostGame'}
# 1595               0   {'value': 16, 'displayName': 'PreMatch'}
# 1596               0   {'value': 16, 'displayName': 'PreMatch'}
#
#                                               type  ...  endY relatedEventId  \
# 0            {'value': 32, 'displayName': 'Start'}  ...   NaN            NaN
# 1            {'value': 32, 'displayName': 'Start'}  ...   NaN            NaN
# 2              {'value': 1, 'displayName': 'Pass'}  ...  41.6            NaN
# 3              {'value': 1, 'displayName': 'Pass'}  ...  78.2            NaN
# 4           {'value': 44, 'displayName': 'Aerial'}  ...   NaN            NaN
# ...                                            ...  ...   ...            ...
# 1592           {'value': 30, 'displayName': 'End'}  ...   NaN            NaN
# 1593           {'value': 30, 'displayName': 'End'}  ...   NaN            NaN
# 1594           {'value': 30, 'displayName': 'End'}  ...   NaN            NaN
# 1595  {'value': 34, 'displayName': 'FormationSet'}  ...   NaN            NaN
# 1596  {'value': 34, 'displayName': 'FormationSet'}  ...   NaN            NaN
#
#      relatedPlayerId  blockedX  blockedY  goalMouthZ  goalMouthY  isShot  \
# 0                NaN       NaN       NaN         NaN         NaN     NaN
# 1                NaN       NaN       NaN         NaN         NaN     NaN
# 2                NaN       NaN       NaN         NaN         NaN     NaN
# 3                NaN       NaN       NaN         NaN         NaN     NaN
# 4                NaN       NaN       NaN         NaN         NaN     NaN
# ...              ...       ...       ...         ...         ...     ...
# 1592             NaN       NaN       NaN         NaN         NaN     NaN
# 1593             NaN       NaN       NaN         NaN         NaN     NaN
# 1594             NaN       NaN       NaN         NaN         NaN     NaN
# 1595             NaN       NaN       NaN         NaN         NaN     NaN
# 1596             NaN       NaN       NaN         NaN         NaN     NaN
#
#       isGoal  cardType
# 0        NaN       NaN
# 1        NaN       NaN
# 2        NaN       NaN
# 3        NaN       NaN
# 4        NaN       NaN
# ...      ...       ...
# 1592     NaN       NaN
# 1593     NaN       NaN
# 1594     NaN       NaN
# 1595     NaN       NaN
# 1596     NaN       NaN
#
# [1597 rows x 26 columns]

# %%
events['match_id'] = match_id

# %%
match_string = home_team_name +  " "  + "-" + " " + away_team_name

# %%
events['match_string'] = match_string

# %%
# Create a dictionary mapping team IDs to team names
team_name = {
    home_teamID: home_team_name,
    away_teamID: away_team_name
}
events['team_name'] = events['teamId'].map(team_name)

events
# Out:
#                 id  eventId  minute  second  teamId     x     y  \
# 0     2.518192e+09        2       0     0.0     183   0.0   0.0
# 1     2.518192e+09        2       0     0.0      26   0.0   0.0
# 2     2.518192e+09        3       0     1.0      26  50.1  49.7
# 3     2.518192e+09        4       0     3.0      26  29.6  41.6
# 4     2.518192e+09        3       0     6.0     183  35.6  23.8
# ...            ...      ...     ...     ...     ...   ...   ...
# 1592  2.518287e+09     1052      95    13.0      26   0.0   0.0
# 1593  2.518287e+09      710       0     0.0     183   0.0   0.0
# 1594  2.518287e+09     1053       0     0.0      26   0.0   0.0
# 1595  2.518163e+09        1       0     0.0      26   0.0   0.0
# 1596  2.518163e+09        1       0     0.0     183   0.0   0.0
#
#       expandedMinute                                     period  \
# 0                  0   {'value': 1, 'displayName': 'FirstHalf'}
# 1                  0   {'value': 1, 'displayName': 'FirstHalf'}
# 2                  0   {'value': 1, 'displayName': 'FirstHalf'}
# 3                  0   {'value': 1, 'displayName': 'FirstHalf'}
# 4                  0   {'value': 1, 'displayName': 'FirstHalf'}
# ...              ...                                        ...
# 1592              97  {'value': 2, 'displayName': 'SecondHalf'}
# 1593               7   {'value': 14, 'displayName': 'PostGame'}
# 1594               7   {'value': 14, 'displayName': 'PostGame'}
# 1595               0   {'value': 16, 'displayName': 'PreMatch'}
# 1596               0   {'value': 16, 'displayName': 'PreMatch'}
#
#                                               type  ... blockedX blockedY  \
# 0            {'value': 32, 'displayName': 'Start'}  ...      NaN      NaN
# 1            {'value': 32, 'displayName': 'Start'}  ...      NaN      NaN
# 2              {'value': 1, 'displayName': 'Pass'}  ...      NaN      NaN
# 3              {'value': 1, 'displayName': 'Pass'}  ...      NaN      NaN
# 4           {'value': 44, 'displayName': 'Aerial'}  ...      NaN      NaN
# ...                                            ...  ...      ...      ...
# 1592           {'value': 30, 'displayName': 'End'}  ...      NaN      NaN
# 1593           {'value': 30, 'displayName': 'End'}  ...      NaN      NaN
# 1594           {'value': 30, 'displayName': 'End'}  ...      NaN      NaN
# 1595  {'value': 34, 'displayName': 'FormationSet'}  ...      NaN      NaN
# 1596  {'value': 34, 'displayName': 'FormationSet'}  ...      NaN      NaN
#
#      goalMouthZ  goalMouthY  isShot  isGoal  cardType  match_id  \
# 0           NaN         NaN     NaN     NaN       NaN   1640895
# 1           NaN         NaN     NaN     NaN       NaN   1640895
# 2           NaN         NaN     NaN     NaN       NaN   1640895
# 3           NaN         NaN     NaN     NaN       NaN   1640895
# 4           NaN         NaN     NaN     NaN       NaN   1640895
# ...         ...         ...     ...     ...       ...       ...
# 1592        NaN         NaN     NaN     NaN       NaN   1640895
# 1593        NaN         NaN     NaN     NaN       NaN   1640895
# 1594        NaN         NaN     NaN     NaN       NaN   1640895
# 1595        NaN         NaN     NaN     NaN       NaN   1640895
# 1596        NaN         NaN     NaN     NaN       NaN   1640895
#
#                  match_string    team_name
# 0     Bournemouth - Liverpool  Bournemouth
# 1     Bournemouth - Liverpool    Liverpool
# 2     Bournemouth - Liverpool    Liverpool
# 3     Bournemouth - Liverpool    Liverpool
# 4     Bournemouth - Liverpool  Bournemouth
# ...                       ...          ...
# 1592  Bournemouth - Liverpool    Liverpool
# 1593  Bournemouth - Liverpool  Bournemouth
# 1594  Bournemouth - Liverpool    Liverpool
# 1595  Bournemouth - Liverpool    Liverpool
# 1596  Bournemouth - Liverpool  Bournemouth
#
# [1597 rows x 29 columns]

# %%
# Create a dictionary mapping team IDs to team names
team_dict = {home_teamID: 'Home', away_teamID: 'Away'}

# Add a column to the event data to indicate whether the corresponding data is for the home team or away team
events['Venue'] = events['teamId'].map(team_dict)

# %%
# Load the event ID json file
with open('data/event_id.json') as f:
    event_id = {value: key for key, value in json.load(f).items()}

# Replace the values in the 'satisfiedEventsTypes' column with the corresponding event type labels
events['satisfiedEventsTypes'] = events['satisfiedEventsTypes'].apply(lambda x: [event_id.get(i) for i in x])

# %%
# Extract the outcomeType values using the apply() function and a lambda function
events['outcomeType'] = events['outcomeType'].apply(lambda x: x['displayName'])

# %%
events['type'] = events['type'].apply(lambda x: x['displayName'])

# %%
events['period'] = events['period'].apply(lambda x: x['displayName'])
events
# Out:
#                 id  eventId  minute  second  teamId     x     y  \
# 0     2.518192e+09        2       0     0.0     183   0.0   0.0
# 1     2.518192e+09        2       0     0.0      26   0.0   0.0
# 2     2.518192e+09        3       0     1.0      26  50.1  49.7
# 3     2.518192e+09        4       0     3.0      26  29.6  41.6
# 4     2.518192e+09        3       0     6.0     183  35.6  23.8
# ...            ...      ...     ...     ...     ...   ...   ...
# 1592  2.518287e+09     1052      95    13.0      26   0.0   0.0
# 1593  2.518287e+09      710       0     0.0     183   0.0   0.0
# 1594  2.518287e+09     1053       0     0.0      26   0.0   0.0
# 1595  2.518163e+09        1       0     0.0      26   0.0   0.0
# 1596  2.518163e+09        1       0     0.0     183   0.0   0.0
#
#       expandedMinute      period          type  ... blockedY goalMouthZ  \
# 0                  0   FirstHalf         Start  ...      NaN        NaN
# 1                  0   FirstHalf         Start  ...      NaN        NaN
# 2                  0   FirstHalf          Pass  ...      NaN        NaN
# 3                  0   FirstHalf          Pass  ...      NaN        NaN
# 4                  0   FirstHalf        Aerial  ...      NaN        NaN
# ...              ...         ...           ...  ...      ...        ...
# 1592              97  SecondHalf           End  ...      NaN        NaN
# 1593               7    PostGame           End  ...      NaN        NaN
# 1594               7    PostGame           End  ...      NaN        NaN
# 1595               0    PreMatch  FormationSet  ...      NaN        NaN
# 1596               0    PreMatch  FormationSet  ...      NaN        NaN
#
#      goalMouthY  isShot  isGoal  cardType  match_id             match_string  \
# 0           NaN     NaN     NaN       NaN   1640895  Bournemouth - Liverpool
# 1           NaN     NaN     NaN       NaN   1640895  Bournemouth - Liverpool
# 2           NaN     NaN     NaN       NaN   1640895  Bournemouth - Liverpool
# 3           NaN     NaN     NaN       NaN   1640895  Bournemouth - Liverpool
# 4           NaN     NaN     NaN       NaN   1640895  Bournemouth - Liverpool
# ...         ...     ...     ...       ...       ...                      ...
# 1592        NaN     NaN     NaN       NaN   1640895  Bournemouth - Liverpool
# 1593        NaN     NaN     NaN       NaN   1640895  Bournemouth - Liverpool
# 1594        NaN     NaN     NaN       NaN   1640895  Bournemouth - Liverpool
# 1595        NaN     NaN     NaN       NaN   1640895  Bournemouth - Liverpool
# 1596        NaN     NaN     NaN       NaN   1640895  Bournemouth - Liverpool
#
#         team_name  Venue
# 0     Bournemouth   Home
# 1       Liverpool   Away
# 2       Liverpool   Away
# 3       Liverpool   Away
# 4     Bournemouth   Home
# ...           ...    ...
# 1592    Liverpool   Away
# 1593  Bournemouth   Home
# 1594    Liverpool   Away
# 1595    Liverpool   Away
# 1596  Bournemouth   Home
#
# [1597 rows x 30 columns]

# %%
events['qualifiers'] = events['qualifiers'].apply(lambda x: [{item['type']['displayName']: item.get('value', True)} for item in x])

# %%
events = events.rename(columns={'type': 'event_type'})

# %%
events
# Out:
#                 id  eventId  minute  second  teamId     x     y  \
# 0     2.518192e+09        2       0     0.0     183   0.0   0.0
# 1     2.518192e+09        2       0     0.0      26   0.0   0.0
# 2     2.518192e+09        3       0     1.0      26  50.1  49.7
# 3     2.518192e+09        4       0     3.0      26  29.6  41.6
# 4     2.518192e+09        3       0     6.0     183  35.6  23.8
# ...            ...      ...     ...     ...     ...   ...   ...
# 1592  2.518287e+09     1052      95    13.0      26   0.0   0.0
# 1593  2.518287e+09      710       0     0.0     183   0.0   0.0
# 1594  2.518287e+09     1053       0     0.0      26   0.0   0.0
# 1595  2.518163e+09        1       0     0.0      26   0.0   0.0
# 1596  2.518163e+09        1       0     0.0     183   0.0   0.0
#
#       expandedMinute      period    event_type  ... blockedY goalMouthZ  \
# 0                  0   FirstHalf         Start  ...      NaN        NaN
# 1                  0   FirstHalf         Start  ...      NaN        NaN
# 2                  0   FirstHalf          Pass  ...      NaN        NaN
# 3                  0   FirstHalf          Pass  ...      NaN        NaN
# 4                  0   FirstHalf        Aerial  ...      NaN        NaN
# ...              ...         ...           ...  ...      ...        ...
# 1592              97  SecondHalf           End  ...      NaN        NaN
# 1593               7    PostGame           End  ...      NaN        NaN
# 1594               7    PostGame           End  ...      NaN        NaN
# 1595               0    PreMatch  FormationSet  ...      NaN        NaN
# 1596               0    PreMatch  FormationSet  ...      NaN        NaN
#
#      goalMouthY  isShot  isGoal  cardType  match_id             match_string  \
# 0           NaN     NaN     NaN       NaN   1640895  Bournemouth - Liverpool
# 1           NaN     NaN     NaN       NaN   1640895  Bournemouth - Liverpool
# 2           NaN     NaN     NaN       NaN   1640895  Bournemouth - Liverpool
# 3           NaN     NaN     NaN       NaN   1640895  Bournemouth - Liverpool
# 4           NaN     NaN     NaN       NaN   1640895  Bournemouth - Liverpool
# ...         ...     ...     ...       ...       ...                      ...
# 1592        NaN     NaN     NaN       NaN   1640895  Bournemouth - Liverpool
# 1593        NaN     NaN     NaN       NaN   1640895  Bournemouth - Liverpool
# 1594        NaN     NaN     NaN       NaN   1640895  Bournemouth - Liverpool
# 1595        NaN     NaN     NaN       NaN   1640895  Bournemouth - Liverpool
# 1596        NaN     NaN     NaN       NaN   1640895  Bournemouth - Liverpool
#
#         team_name  Venue
# 0     Bournemouth   Home
# 1       Liverpool   Away
# 2       Liverpool   Away
# 3       Liverpool   Away
# 4     Bournemouth   Home
# ...           ...    ...
# 1592    Liverpool   Away
# 1593  Bournemouth   Home
# 1594    Liverpool   Away
# 1595    Liverpool   Away
# 1596  Bournemouth   Home
#
# [1597 rows x 30 columns]

# %%
#data = pd.read_csv('./Data/liverpool03_05_23.csv', index_col=0, low_memory=False)

# %%
events['period'] = events['period'].map({'FirstHalf': 1, 'SecondHalf': 2})

# %%
#data = data.rename(columns={'event_type':'eventType'})

# %%
events = wcde.cumulative_match_mins(events)

# %%
events = ws_custom_events.insert_ball_carries(events)

# %%
#data[data['event_type']=='Carry']

# %%
#data.event_type.unique()

# %%
events = ws_custom_events.get_xthreat(events)

# %%
#events['event_type'].unique()

# %%
events
# Out:
#       eventId  minute  second  teamId     x     y  expandedMinute  period  \
# 0         2.0     0.0     0.0     183   0.0   0.0             0.0     1.0
# 1         2.0     0.0     0.0      26   0.0   0.0             0.0     1.0
# 2         3.0     0.0     1.0      26  50.1  49.7             0.0     1.0
# 3         4.0     0.0     3.0      26  29.6  41.6             0.0     1.0
# 4         3.0     0.0     6.0     183  35.6  23.8             0.0     1.0
# ...       ...     ...     ...     ...   ...   ...             ...     ...
# 1765  11587.0    79.0     NaN     183  94.2  93.9            81.0     2.0
# 1766    710.0     0.0     0.0     183   0.0   0.0             7.0     NaN
# 1767   1053.0     0.0     0.0      26   0.0   0.0             7.0     NaN
# 1768      1.0     0.0     0.0      26   0.0   0.0             0.0     NaN
# 1769      1.0     0.0     0.0     183   0.0   0.0             0.0     NaN
#
#      type   outcomeType  ... match_id    event_type  cumulative_mins   index  \
# 0     NaN    Successful  ...  1640895         Start         0.000000     0.0
# 1     NaN    Successful  ...  1640895         Start         0.000000     1.0
# 2     NaN    Successful  ...  1640895          Pass         0.016667     2.0
# 3     NaN  Unsuccessful  ...  1640895          Pass         0.050000     3.0
# 4     NaN    Successful  ...  1640895        Aerial         0.100000     4.0
# ...   ...           ...  ...      ...           ...              ...     ...
# 1765  NaN  Unsuccessful  ...  1640895  OffsideGiven              NaN  1318.0
# 1766  NaN    Successful  ...  1640895           End         0.000000  1593.0
# 1767  NaN    Successful  ...  1640895           End         0.000000  1594.0
# 1768  NaN    Successful  ...  1640895  FormationSet         0.000000  1595.0
# 1769  NaN    Successful  ...  1640895  FormationSet         0.000000  1596.0
#
#                 id             match_string    team_name  Venue   xThreat  \
# 0     2.518192e+09  Bournemouth - Liverpool  Bournemouth   Home       NaN
# 1     2.518192e+09  Bournemouth - Liverpool    Liverpool   Away       NaN
# 2     2.518192e+09  Bournemouth - Liverpool    Liverpool   Away -0.004739
# 3     2.518192e+09  Bournemouth - Liverpool    Liverpool   Away       NaN
# 4     2.518192e+09  Bournemouth - Liverpool  Bournemouth   Home       NaN
# ...            ...                      ...          ...    ...       ...
# 1765  2.518281e+09  Bournemouth - Liverpool  Bournemouth   Home       NaN
# 1766  2.518287e+09  Bournemouth - Liverpool  Bournemouth   Home       NaN
# 1767  2.518287e+09  Bournemouth - Liverpool    Liverpool   Away       NaN
# 1768  2.518163e+09  Bournemouth - Liverpool    Liverpool   Away       NaN
# 1769  2.518163e+09  Bournemouth - Liverpool  Bournemouth   Home       NaN
#
#       xThreat_gen
# 0             NaN
# 1             NaN
# 2             0.0
# 3             NaN
# 4             NaN
# ...           ...
# 1765          NaN
# 1766          NaN
# 1767          NaN
# 1768          NaN
# 1769          NaN
#
# [1770 rows x 36 columns]

# %%
for i, row in events.iterrows():
    player_id_val = row['playerId']
    if not pd.isnull(player_id_val):
        player_name = player_id.get(str(int(player_id_val)), 'Unknown')
        events.at[i, 'playerName'] = player_name
    else:
        events.at[i, 'playerName'] = 'Unknown'

# %%
events.qualifiers
# Out:
# 0                                                      []
# 1                                                      []
# 2       [{'PassEndY': '57.3'}, {'PassEndX': '31.8'}, {...
# 3       [{'PassEndX': '77.6'}, {'Length': '46.1'}, {'C...
# 4       [{'PassEndX': '28.5'}, {'Length': '13.5'}, {'H...
#                               ...
# 1587                                                   []
# 1588                                                   []
# 1589                                                   []
# 1590    [{'CaptainPlayerId': '68659'}, {'InvolvedPlaye...
# 1591    [{'InvolvedPlayers': '79554,353418,118244,1143...
# Name: qualifiers, Length: 1592, dtype: object

# %%
data.cumulative_mins
# Out:
# 0       0.00
# 1       0.00
# 2       0.00
# 3       0.05
# 4       0.10
#         ...
# 1587     NaN
# 1588    0.00
# 1589    0.00
# 1590    0.00
# 1591    0.00
# Name: cumulative_mins, Length: 1592, dtype: float64

# %%
ws_custom_events.carry_into_box(events)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [42], line 1
# ----> 1 ws_custom_events.carry_into_box(events)
#
# File ~/Documents/Coding Projects/Soccer Coding Projects/Football_Anal/analysis_tools/whoscored_custom_events.py:256, in carry_into_box(single_event, successful_only)
#     241 """ Identify successful carry into box from whoscored-style pass event.
#     242
#     243 Function to identify successful carries that end up in the opposition box. The function takes in a single event,
#    (...)
#     252     bool: True = successful carry into the box, nan = not box carry, unsuccessful carry or not a carry.
#     253 """
#     255 # Determine if event is pass and check pass success
# --> 256 if single_event['event_type'] == 'Carry':
#     257
#     258     # Check success (if successful_only = True)
#     259     if successful_only:
#     260         check_success = single_event['outcomeType'] == 'Successful'
#
# File ~/Documents/Coding Projects/lib/python3.9/site-packages/pandas/core/generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
ws_custom_events.pass_into_box()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 ws_custom_events.pass_into_box()
#
# TypeError: pass_into_box() missing 1 required positional argument: 'single_event'

# %%
ws_custom_events.pre_assist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [19], line 1
# ----> 1 ws_custom_events.pre_assist()
#
# TypeError: pre_assist() missing 1 required positional argument: 'events'

# %%
ws_custom_events.carry_into_box()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [20], line 1
# ----> 1 ws_custom_events.carry_into_box()
#
# TypeError: carry_into_box() missing 1 required positional argument: 'single_event'

# %%
ws_custom_events.progressive_carry(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [23], line 1
# ----> 1 ws_custom_events.progressive_carry(data)
#
# File ~/Documents/Coding Projects/Soccer Coding Projects/Football_Anal/analysis_tools/whoscored_custom_events.py:163, in progressive_carry(single_event, successful_only)
#     145 """ Identify progressive carry from WhoScored-style carry event.
#     146
#     147 Function to identify progressive carries. A carry is considered progressive if the distance between the
#    (...)
#     159     bool: True = progressive carry, nan = non-progressive carry, unsuccessful progressive carry or not a carry
#     160 """
#     162 # Determine if event is pass
# --> 163 if single_event['event_type'] == 'Carry':
#     164
#     165     # Check success (if successful_only = True)
#     166     if successful_only:
#     167         check_success = single_event['outcomeType'] == 'Successful'
#
# File ~/Documents/Coding Projects/lib/python3.9/site-packages/pandas/core/generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
ws_custom_events.progressive_pass(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [22], line 1
# ----> 1 ws_custom_events.progressive_pass(data)
#
# File ~/Documents/Coding Projects/Soccer Coding Projects/Football_Anal/analysis_tools/whoscored_custom_events.py:104, in progressive_pass(single_event, inplay, successful_only)
#      85 """ Identify progressive pass from WhoScored-style pass event.
#      86
#      87 Function to identify progressive passes. A pass is considered progressive if the distance between the
#    (...)
#     100     bool: True = progressive pass, nan = non-progressive pass, unsuccessful progressive pass or not a pass
#     101 """
#     103 # Determine if event is pass
# --> 104 if single_event['event_type'] == 'Pass':
#     105
#     106     # Check success (if successful_only = True)
#     107     if successful_only:
#     108         check_success = single_event['outcomeType'] == 'Successful'
#
# File ~/Documents/Coding Projects/lib/python3.9/site-packages/pandas/core/generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
data = events

# %%
data['isTouch'].value_counts()
# Out:
# True     1327
# False     265
# Name: isTouch, dtype: int64

# %%
events
# Out:
#       eventId  minute  second  teamId     x     y  expandedMinute  period  \
# 0         2.0     0.0     0.0      32   0.0   0.0             0.0     1.0
# 1         2.0     0.0     0.0      26   0.0   0.0             0.0     1.0
# 2         3.0     0.0     0.0      32  50.0  50.0             0.0     1.0
# 3         4.0     0.0     3.0      32  33.9  59.7             0.0     1.0
# 4         3.0     0.0     6.0      26  19.9  30.3             0.0     1.0
# ...       ...     ...     ...     ...   ...   ...             ...     ...
# 1587  11655.0    85.0     NaN      32  77.3  87.1            87.0     2.0
# 1588    697.0     0.0     0.0      32   0.0   0.0             5.0     NaN
# 1589    879.0     0.0     0.0      26   0.0   0.0             5.0     NaN
# 1590      1.0     0.0     0.0      26   0.0   0.0             0.0     NaN
# 1591      1.0     0.0     0.0      32   0.0   0.0             0.0     NaN
#
#      type   outcomeType  ...    event_type cumulative_mins   index  \
# 0     NaN    Successful  ...         Start            0.00     0.0
# 1     NaN    Successful  ...         Start            0.00     1.0
# 2     NaN    Successful  ...          Pass            0.00     2.0
# 3     NaN  Unsuccessful  ...          Pass            0.05     3.0
# 4     NaN    Successful  ...          Pass            0.10     4.0
# ...   ...           ...  ...           ...             ...     ...
# 1587  NaN  Unsuccessful  ...  OffsideGiven             NaN  1311.0
# 1588  NaN    Successful  ...           End            0.00  1417.0
# 1589  NaN    Successful  ...           End            0.00  1418.0
# 1590  NaN    Successful  ...  FormationSet            0.00  1419.0
# 1591  NaN    Successful  ...  FormationSet            0.00  1420.0
#
#                 id         match_string  team_name  Venue   xThreat  \
# 0     2.516083e+09  Liverpool - Man Utd    Man Utd   Away       NaN
# 1     2.516083e+09  Liverpool - Man Utd  Liverpool   Home       NaN
# 2     2.516083e+09  Liverpool - Man Utd    Man Utd   Away -0.004143
# 3     2.516083e+09  Liverpool - Man Utd    Man Utd   Away       NaN
# 4     2.516083e+09  Liverpool - Man Utd  Liverpool   Home  0.001418
# ...            ...                  ...        ...    ...       ...
# 1587  2.516165e+09  Liverpool - Man Utd    Man Utd   Away       NaN
# 1588  2.516160e+09  Liverpool - Man Utd    Man Utd   Away       NaN
# 1589  2.516160e+09  Liverpool - Man Utd  Liverpool   Home       NaN
# 1590  2.516027e+09  Liverpool - Man Utd  Liverpool   Home       NaN
# 1591  2.516027e+09  Liverpool - Man Utd    Man Utd   Away       NaN
#
#       xThreat_gen          playerName
# 0             NaN             Unknown
# 1             NaN             Unknown
# 2        0.000000                Fred
# 3             NaN   Lisandro Martínez
# 4        0.001418     Ibrahima Konaté
# ...           ...                 ...
# 1587          NaN  Alejandro Garnacho
# 1588          NaN             Unknown
# 1589          NaN             Unknown
# 1590          NaN             Unknown
# 1591          NaN             Unknown
#
# [1592 rows x 37 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [142], line 1
# ----> 1 data['qualifiers'] = [literal_eval(x) for x in data['qualifiers']]
#       2 data['satisfiedEventsTypes'] = [literal_eval(x) for x in data['satisfiedEventsTypes']]
#       4 data['is_throw_or_corner'] = False
#
# Cell In [142], line 1, in <listcomp>(.0)
# ----> 1 data['qualifiers'] = [literal_eval(x) for x in data['qualifiers']]
#       2 data['satisfiedEventsTypes'] = [literal_eval(x) for x in data['satisfiedEventsTypes']]
#       4 data['is_throw_or_corner'] = False
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ast.py:105, in literal_eval(node_or_string)
#     103                 return left - right
#     104     return _convert_signed_num(node)
# --> 105 return _convert(node_or_string)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ast.py:104, in literal_eval.<locals>._convert(node)
#     102         else:
#     103             return left - right
# --> 104 return _convert_signed_num(node)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ast.py:78, in literal_eval.<locals>._convert_signed_num(node)
#      76     else:
#      77         return - operand
# ---> 78 return _convert_num(node)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ast.py:69, in literal_eval.<locals>._convert_num(node)
#      67 def _convert_num(node):
#      68     if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
# ---> 69         _raise_malformed_node(node)
#      70     return node.value
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ast.py:66, in literal_eval.<locals>._raise_malformed_node(node)
#      65 def _raise_malformed_node(node):
# ---> 66     raise ValueError(f'malformed node or string: {node!r}')
#
# ValueError: malformed node or string: []

# %%
events
# Out:
#       eventId  minute  second  teamId     x     y  expandedMinute  period  \
# 0         2.0     0.0     0.0     183   0.0   0.0             0.0     1.0
# 1         2.0     0.0     0.0      26   0.0   0.0             0.0     1.0
# 2         3.0     0.0     1.0      26  50.1  49.7             0.0     1.0
# 3         4.0     0.0     3.0      26  29.6  41.6             0.0     1.0
# 4         3.0     0.0     6.0     183  35.6  23.8             0.0     1.0
# ...       ...     ...     ...     ...   ...   ...             ...     ...
# 1765  11587.0    79.0     NaN     183  94.2  93.9            81.0     2.0
# 1766    710.0     0.0     0.0     183   0.0   0.0             7.0     NaN
# 1767   1053.0     0.0     0.0      26   0.0   0.0             7.0     NaN
# 1768      1.0     0.0     0.0      26   0.0   0.0             0.0     NaN
# 1769      1.0     0.0     0.0     183   0.0   0.0             0.0     NaN
#
#      type   outcomeType  ...    event_type cumulative_mins   index  \
# 0     NaN    Successful  ...         Start        0.000000     0.0
# 1     NaN    Successful  ...         Start        0.000000     1.0
# 2     NaN    Successful  ...          Pass        0.016667     2.0
# 3     NaN  Unsuccessful  ...          Pass        0.050000     3.0
# 4     NaN    Successful  ...        Aerial        0.100000     4.0
# ...   ...           ...  ...           ...             ...     ...
# 1765  NaN  Unsuccessful  ...  OffsideGiven             NaN  1318.0
# 1766  NaN    Successful  ...           End        0.000000  1593.0
# 1767  NaN    Successful  ...           End        0.000000  1594.0
# 1768  NaN    Successful  ...  FormationSet        0.000000  1595.0
# 1769  NaN    Successful  ...  FormationSet        0.000000  1596.0
#
#                 id             match_string    team_name  Venue   xThreat  \
# 0     2.518192e+09  Bournemouth - Liverpool  Bournemouth   Home       NaN
# 1     2.518192e+09  Bournemouth - Liverpool    Liverpool   Away       NaN
# 2     2.518192e+09  Bournemouth - Liverpool    Liverpool   Away -0.004739
# 3     2.518192e+09  Bournemouth - Liverpool    Liverpool   Away       NaN
# 4     2.518192e+09  Bournemouth - Liverpool  Bournemouth   Home       NaN
# ...            ...                      ...          ...    ...       ...
# 1765  2.518281e+09  Bournemouth - Liverpool  Bournemouth   Home       NaN
# 1766  2.518287e+09  Bournemouth - Liverpool  Bournemouth   Home       NaN
# 1767  2.518287e+09  Bournemouth - Liverpool    Liverpool   Away       NaN
# 1768  2.518163e+09  Bournemouth - Liverpool    Liverpool   Away       NaN
# 1769  2.518163e+09  Bournemouth - Liverpool  Bournemouth   Home       NaN
#
#       xThreat_gen       playerName
# 0             NaN          Unknown
# 1             NaN          Unknown
# 2             0.0   Harvey Elliott
# 3             NaN  Ibrahima Konaté
# 4             NaN   Dango Ouattara
# ...           ...              ...
# 1765          NaN   Jaidon Anthony
# 1766          NaN          Unknown
# 1767          NaN          Unknown
# 1768          NaN          Unknown
# 1769          NaN          Unknown
#
# [1770 rows x 37 columns]

# %%
events.to_csv('Data/liverpool03_11_23.csv')

# %%
events['is_throw_or_corner'].value_counts()
# Out:
# False    1455
# True        3
# Name: is_throw_or_corner, dtype: int64
