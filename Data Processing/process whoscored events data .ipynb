# %%
import json
import pandas as pd
import numpy as np
from tkinter import Tk     # from tkinter import Tk for Python 3.x
from tkinter.filedialog import askopenfilename
from tkinter import *
from tkinter import ttk
import sqlite3

# %%
con = sqlite3.connect("./Database/event_data22_23.db")
cur = con.cursor()

# %%
#Tk().withdraw() # we don't want a full GUI, so keep the root window from appearing
#matchfile = askopenfilename() # show an "Open" dialog box and return the path to the selected file

# %%
path = "Data/unprocess data/"
filename = input("Enter file name: ")
file_with_path = path + filename
f = open(file_with_path, encoding='utf-8')
data = json.load(f)
data
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In [2], line 4
#       2 filename = input("Enter file name: ")
#       3 file_with_path = path + filename
# ----> 4 f = open(file_with_path, encoding='utf-8')
#       5 data = json.load(f)
#       6 data
#
# IsADirectoryError: [Errno 21] Is a directory: 'Data/unprocess data/'

# %%
#data

# %%
path = "Data/"
filename = input("Enter file name: ")
file_with_path = path + filename
match_id = open(file_with_path, encoding='utf-8')
match_id = json.load(match_id)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In [3], line 4
#       2 filename = input("Enter file name: ")
#       3 file_with_path = path + filename
# ----> 4 match_id = open(file_with_path, encoding='utf-8')
#       5 match_id = json.load(match_id)
#
# IsADirectoryError: [Errno 21] Is a directory: 'Data/'

# %%
data
# Out:
# {'matchId': '1640740',
#  'matchCentreData': {'playerIdNameDictionary': {'114147': 'Alisson',
#    '115916': 'Fabinho',
#    '96182': 'Roberto Firmino',
#    '74341': 'Joël Matip',
#    '108226': 'Mohamed Salah',
#    '345957': 'Ibrahima Konaté',
#    '301455': 'Konstantinos Tsimikas',
#    '322176': 'Caoimhín Kelleher',
#    '352825': 'Cody Gakpo',
#    '95408': 'Virgil van Dijk',
#    '235755': 'Diogo Jota',
#    '401385': 'Fábio Carvalho',
#    '444540': 'Stefan Bajcetic',
#    '400828': 'Darwin Núñez',
#    '4511': 'James Milner',
#    '318871': 'Trent Alexander-Arnold',
#    '363982': 'Harvey Elliott',
#    '68659': 'Jordan Henderson',
#    '84146': 'Alex Oxlade-Chamberlain',
#    '115726': 'Andrew Robertson',
#    '403693': 'João Gomes',
#    '355401': 'Rayan Aït-Nouri',
#    '123481': 'Mario Lemina',
#    '372724': 'Nathan Collins',
#    '108186': 'Raúl Jiménez',
#    '122714': 'José Sá',
#    '409730': 'Hugo Bueno',
#    '296363': 'Nélson Semedo',
# ...

# %%
#f = open(matchfile)
#data = json.load(f)

# %%
#match_id = open('data/test1.json', encoding='utf-8')
#match_id = json.load(match_id)

# %%
data
# Out:
# {'matchId': '1636165',
#  'matchCentreData': {'playerIdNameDictionary': {'115916': 'Fabinho',
#    '96182': 'Roberto Firmino',
#    '74341': 'Joël Matip',
#    '377168': 'Luis Díaz',
#    '108226': 'Mohamed Salah',
#    '345957': 'Ibrahima Konaté',
#    '243510': 'Naby Keïta',
#    '95408': 'Virgil van Dijk',
#    '401385': 'Fábio Carvalho',
#    '73399': 'Adrián',
#    '74939': 'Thiago',
#    '400828': 'Darwin Núñez',
#    '411519': 'Harvey Davies',
#    '318871': 'Trent Alexander-Arnold',
#    '68659': 'Jordan Henderson',
#    '363982': 'Harvey Elliott',
#    '355354': 'Curtis Jones',
#    '4511': 'James Milner',
#    '136451': 'Joe Gomez',
#    '115726': 'Andrew Robertson',
#    '104749': 'Riyad Mahrez',
#    '365409': 'Julián Álvarez',
#    '73084': 'Kevin De Bruyne',
#    '121774': 'Ederson',
#    '77464': 'Ilkay Gündogan',
#    '133569': 'Stefan Ortega',
#    '122945': 'Nathan Aké',
#    '315227': 'Erling Haaland',
#    '136741': 'Bernardo Silva',
#    '313171': 'Rúben Dias',
# ...

# %%
#matchId = match_id['matchId']

# %%
matchId = 1640740

# %%
data = data['matchCentreData']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 data = data['matchCentreData']
#
# KeyError: 'matchCentreData'

# %%
home_team_name =  data['home']['name']
home_team_name
# Out:
# 'Liverpool'

# %%
away_team_name =  data['away']['name']
away_team_name
# Out:
# 'Wolves'

# %%
data['home']['name']
# Out:
# 'Liverpool'

# %%
data['home']['teamId']
# Out:
# 26

# %%
home_teamID = data['home']['teamId']

# %%
away_teamID = data['away']['teamId']

# %%
player_id = data['playerIdNameDictionary']
player_id
# Out:
# {'114147': 'Alisson',
#  '115916': 'Fabinho',
#  '96182': 'Roberto Firmino',
#  '74341': 'Joël Matip',
#  '108226': 'Mohamed Salah',
#  '345957': 'Ibrahima Konaté',
#  '301455': 'Konstantinos Tsimikas',
#  '322176': 'Caoimhín Kelleher',
#  '352825': 'Cody Gakpo',
#  '95408': 'Virgil van Dijk',
#  '235755': 'Diogo Jota',
#  '401385': 'Fábio Carvalho',
#  '444540': 'Stefan Bajcetic',
#  '400828': 'Darwin Núñez',
#  '4511': 'James Milner',
#  '318871': 'Trent Alexander-Arnold',
#  '363982': 'Harvey Elliott',
#  '68659': 'Jordan Henderson',
#  '84146': 'Alex Oxlade-Chamberlain',
#  '115726': 'Andrew Robertson',
#  '403693': 'João Gomes',
#  '355401': 'Rayan Aït-Nouri',
#  '123481': 'Mario Lemina',
#  '372724': 'Nathan Collins',
#  '108186': 'Raúl Jiménez',
#  '122714': 'José Sá',
#  '409730': 'Hugo Bueno',
#  '296363': 'Nélson Semedo',
#  '337916': 'Pedro Neto',
#  '300513': 'Daniel Podence',
#  '238244': 'Rúben Neves',
#  '16161': 'João Moutinho',
#  '394933': 'Matheus Nunes',
# ...

# %%
events = data['events']
events
# Out:
# [{'id': 2514063339.0,
#   'eventId': 2,
#   'minute': 0,
#   'second': 0,
#   'teamId': 161,
#   'x': 0.0,
#   'y': 0.0,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 32, 'displayName': 'Start'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [],
#   'isTouch': False},
#  {'id': 2514063345.0,
#   'eventId': 3,
#   'minute': 0,
#   'second': 0,
#   'teamId': 26,
#   'x': 0.0,
#   'y': 0.0,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 32, 'displayName': 'Start'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [],
#   'isTouch': False},
#  {'id': 2514063355.0,
#   'eventId': 3,
#   'minute': 0,
#   'second': 0,
#   'teamId': 161,
#   'playerId': 108186,
#   'x': 49.9,
#   'y': 50.0,
#   'expandedMinute': 0,
# ...

# %%
def get_recipient(events_df):
    """ Add pass recipient to whoscored-style event data.
    Determine the pass recipient from who-scored style event data, and add information to the event dataframe.
    Args:
        events_df (pandas.DataFrame, optional): WhoScored-style event dataframe
    Returns:
        pandas.DataFrame: WhoScored-style event dataframe with additional pass recipient column
        """

    # Initialise output dataframe
    events_out = events_df.copy()

    # Shift dataframe to calculate pass recipient
    events_out["pass_recipient"] = events_out["playerId"].shift(-1)

    return events_out

# %%
events = pd.DataFrame(events)
events
# Out:
#                 id  eventId  minute  second  teamId     x     y  \
# 0     2.440372e+09        2       0     0.0      26   0.0   0.0
# 1     2.440372e+09        2       0     0.0     167   0.0   0.0
# 2     2.440372e+09        3       0     0.0      26  50.3  50.4
# 3     2.440372e+09        4       0     3.0      26  29.2  39.7
# 4     2.440372e+09        3       0     6.0     167  26.6  28.1
# ...            ...      ...     ...     ...     ...   ...   ...
# 1502  2.440448e+09      909      97    28.0     167   0.0   0.0
# 1503  2.440448e+09      910       0     0.0     167   0.0   0.0
# 1504  2.440448e+09      760       0     0.0      26   0.0   0.0
# 1505  2.440286e+09        1       0     0.0      26   0.0   0.0
# 1506  2.440296e+09        1       0     0.0     167   0.0   0.0
#
#       expandedMinute                                     period  \
# 0                  0   {'value': 1, 'displayName': 'FirstHalf'}
# 1                  0   {'value': 1, 'displayName': 'FirstHalf'}
# ...

# %%
get_recipient(events)
# Out:
#                 id  eventId  minute  second  teamId     x     y  \
# 0     2.507550e+09        2       0     0.0      26   0.0   0.0
# 1     2.507550e+09        2       0     0.0      31   0.0   0.0
# 2     2.507550e+09        3       0     0.0      26  49.9  50.0
# 3     2.507550e+09        4       0     3.0      26  46.5  43.9
# 4     2.507550e+09        5       0     6.0      26  32.2  45.2
# ...            ...      ...     ...     ...     ...   ...   ...
# 1619  2.507587e+09      974      94     5.0      26   0.0   0.0
# 1620  2.507587e+09      975       0     0.0      26   0.0   0.0
# 1621  2.507587e+09      785       0     0.0      31   0.0   0.0
# 1622  2.507531e+09        1       0     0.0      26   0.0   0.0
# 1623  2.507531e+09        1       0     0.0      31   0.0   0.0
#
#       expandedMinute                                     period  \
# 0                  0   {'value': 1, 'displayName': 'FirstHalf'}
# 1                  0   {'value': 1, 'displayName': 'FirstHalf'}
# ...

# %%
print(type(player_id))
# Out:
# <class 'dict'>

# %%
events =  get_recipient(events)
events
# Out:
#                 id  eventId  matchminute  matchsecond  teamId     x     y  \
# 1     2.509371e+09        2            0          0.0      23   0.0   0.0
# 2     2.509371e+09        3            0          0.0      26  50.1  50.3
# 3     2.509371e+09        4            0          3.0      26  27.8  57.3
# 4     2.509372e+09        5            0         28.0      23  24.2   0.0
# 5     2.509372e+09        6            0         31.0      23  22.9   5.5
# ...            ...      ...          ...          ...     ...   ...   ...
# 1556  2.509465e+09      957           92         28.0      26  70.7  66.9
# 1557  2.509465e+09      958           92         30.0      26  77.6  73.5
# 1558  2.509465e+09      959           92         33.0      26  78.4  79.1
# 1559  2.509465e+09      960           92         37.0      26  94.5  83.9
# 1560  2.509613e+09      753           92         38.0      23   0.0   0.0
#
#       expandedMinute matchPeriod     event_type  ... goalMouthZ goalMouthY  \
# ...

# %%
tests = events
tests
# Out:
#                 id  eventId  minute  second  teamId     x     y  \
# 0     2.509371e+09        2       0     0.0      26   0.0   0.0
# 1     2.509371e+09        2       0     0.0      23   0.0   0.0
# 2     2.509371e+09        3       0     0.0      26  50.1  50.3
# 3     2.509371e+09        4       0     3.0      26  27.8  57.3
# 4     2.509372e+09        5       0    28.0      23  24.2   0.0
# ...            ...      ...     ...     ...     ...   ...   ...
# 1563  2.509466e+09      962      93    10.0      26   0.0   0.0
# 1564  2.509466e+09      963       0     0.0      26   0.0   0.0
# 1565  2.509467e+09      734       0     0.0      23   0.0   0.0
# 1566  2.509301e+09        1       0     0.0      26   0.0   0.0
# 1567  2.509301e+09        1       0     0.0      23   0.0   0.0
#
#       expandedMinute                                     period  \
# 0                  0   {'value': 1, 'displayName': 'FirstHalf'}
# 1                  0   {'value': 1, 'displayName': 'FirstHalf'}
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [253], line 1
# ----> 1 tests['playerName'] = tests['playerId'].map(player_id_df)
#       2 tests
#
# File ~/Documents/Coding Projects/lib/python3.9/site-packages/pandas/core/series.py:4539, in Series.map(self, arg, na_action)
#    4460 def map(
#    4461     self,
#    4462     arg: Callable | Mapping | Series,
#    4463     na_action: Literal["ignore"] | None = None,
#    4464 ) -> Series:
#    4465     """
#    4466     Map values of Series according to an input mapping or function.
#    4467
#    (...)
#    4537     dtype: object
#    4538     """
# -> 4539     new_values = self._map_values(arg, na_action=na_action)
#    4540     return self._constructor(new_values, index=self.index).__finalize__(
#    4541         self, method="map"
#    4542     )
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [228], line 4
#       1 player_id_df = pd.DataFrame.from_dict(player_id, orient='index', columns=['player_name'])
#       2 player_id_df['player_id'] = player_id_df.index.astype(int)
# ----> 4 test = pd.concat(player_id_df)
#       5 test.drop(['player_id'], axis=1, inplace=True)
#       6 test
#
# File ~/Documents/Coding Projects/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
pd.concat
# Out:
# <function pandas.core.reshape.concat.concat(objs: 'Iterable[NDFrame] | Mapping[HashableT, NDFrame]', *, axis: 'Axis' = 0, join: 'str' = 'outer', ignore_index: 'bool' = False, keys=None, levels=None, names=None, verify_integrity: 'bool' = False, sort: 'bool' = False, copy: 'bool' = True) -> 'DataFrame | Series'>

# %%
player_id_df = pd.DataFrame.from_dict(player_id, orient='index', columns=['playerName'])
player_id_df['playerId'] = player_id_df.index.astype(int)
player_id_df
# Out:
#                      playerName  playerId
# 114147                  Alisson    114147
# 115916                  Fabinho    115916
# 96182           Roberto Firmino     96182
# 74341                Joël Matip     74341
# 108226            Mohamed Salah    108226
# 345957          Ibrahima Konaté    345957
# 301455    Konstantinos Tsimikas    301455
# 322176        Caoimhín Kelleher    322176
# 352825               Cody Gakpo    352825
# 95408           Virgil van Dijk     95408
# 235755               Diogo Jota    235755
# 401385           Fábio Carvalho    401385
# 444540          Stefan Bajcetic    444540
# 400828             Darwin Núñez    400828
# 4511               James Milner      4511
# 318871   Trent Alexander-Arnold    318871
# 363982           Harvey Elliott    363982
# 68659          Jordan Henderson     68659
# 84146   Alex Oxlade-Chamberlain     84146
# 115726         Andrew Robertson    115726
# 403693               João Gomes    403693
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [237], line 1
# ----> 1 merged_df = pd.merge(tests, player_id_df, on='playerId', how='left')
#
# File ~/Documents/Coding Projects/lib/python3.9/site-packages/pandas/core/reshape/merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
# ...

# %%
# Load the event ID json file
with open('data/event_id.json') as f:
    event_id = {value: key for key, value in json.load(f).items()}

# Replace the values in the 'satisfiedEventsTypes' column with the corresponding event type labels
events['satisfiedEventsTypes'] = events['satisfiedEventsTypes'].apply(lambda x: [event_id.get(i) for i in x])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [21], line 6
#       3     event_id = {value: key for key, value in json.load(f).items()}
#       5 # Replace the values in the 'satisfiedEventsTypes' column with the corresponding event type labels
# ----> 6 events['satisfiedEventsTypes'] = events['satisfiedEventsTypes'].apply(lambda x: [event_id.get(i) for i in x])
#
# TypeError: list indices must be integers or slices, not str

# %%
# Extract the outcomeType values using the apply() function and a lambda function
events['outcomeType'] = events['outcomeType'].apply(lambda x: x['displayName'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [22], line 2
#       1 # Extract the outcomeType values using the apply() function and a lambda function
# ----> 2 events['outcomeType'] = events['outcomeType'].apply(lambda x: x['displayName'])
#
# TypeError: list indices must be integers or slices, not str

# %%
events['type'] = events['type'].apply(lambda x: x['displayName'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [23], line 1
# ----> 1 events['type'] = events['type'].apply(lambda x: x['displayName'])
#
# TypeError: list indices must be integers or slices, not str

# %%
events['period'] = events['period'].apply(lambda x: x['displayName'])
events
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [24], line 1
# ----> 1 events['period'] = events['period'].apply(lambda x: x['displayName'])
#       2 events
#
# TypeError: list indices must be integers or slices, not str

# %%
#events['cardType'] = events['cardType'].apply(lambda x: x['displayName'])

# %%
events['qualifiers'] = events['qualifiers'].apply(lambda x: [{item['type']['displayName']: item.get('value', True)} for item in x])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [26], line 1
# ----> 1 events['qualifiers'] = events['qualifiers'].apply(lambda x: [{item['type']['displayName']: item.get('value', True)} for item in x])
#
# TypeError: list indices must be integers or slices, not str

# %%
events
# Out:
#                 id  eventId  minute  second  teamId     x     y  \
# 0     2.507550e+09        2       0     0.0      26   0.0   0.0
# 1     2.507550e+09        2       0     0.0      31   0.0   0.0
# 2     2.507550e+09        3       0     0.0      26  49.9  50.0
# 3     2.507550e+09        4       0     3.0      26  46.5  43.9
# 4     2.507550e+09        5       0     6.0      26  32.2  45.2
# ...            ...      ...     ...     ...     ...   ...   ...
# 1619  2.507587e+09      974      94     5.0      26   0.0   0.0
# 1620  2.507587e+09      975       0     0.0      26   0.0   0.0
# 1621  2.507587e+09      785       0     0.0      31   0.0   0.0
# 1622  2.507531e+09        1       0     0.0      26   0.0   0.0
# 1623  2.507531e+09        1       0     0.0      31   0.0   0.0
#
#       expandedMinute      period          type  ... relatedEventId  \
# 0                  0   FirstHalf         Start  ...            NaN
# ...

# %%
events['matchID'] = matchId
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [27], line 1
# ----> 1 events['matchID'] = matchId
#
# TypeError: list indices must be integers or slices, not str

# %%
events
# Out:
# [{'id': 2514063339.0,
#   'eventId': 2,
#   'minute': 0,
#   'second': 0,
#   'teamId': 161,
#   'x': 0.0,
#   'y': 0.0,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 32, 'displayName': 'Start'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [],
#   'isTouch': False},
#  {'id': 2514063345.0,
#   'eventId': 3,
#   'minute': 0,
#   'second': 0,
#   'teamId': 26,
#   'x': 0.0,
#   'y': 0.0,
#   'expandedMinute': 0,
#   'period': {'value': 1, 'displayName': 'FirstHalf'},
#   'type': {'value': 32, 'displayName': 'Start'},
#   'outcomeType': {'value': 1, 'displayName': 'Successful'},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [],
#   'isTouch': False},
#  {'id': 2514063355.0,
#   'eventId': 3,
#   'minute': 0,
#   'second': 0,
#   'teamId': 161,
#   'playerId': 108186,
#   'x': 49.9,
#   'y': 50.0,
#   'expandedMinute': 0,
# ...

# %%
match_string = home_team_name +  " "  + "-" + " " + away_team_name

# %%
events
# Out:
#                 id  eventId  minute  second  teamId     x     y  \
# 0     2.507550e+09        2       0     0.0      26   0.0   0.0
# 1     2.507550e+09        2       0     0.0      31   0.0   0.0
# 2     2.507550e+09        3       0     0.0      26  49.9  50.0
# 3     2.507550e+09        4       0     3.0      26  46.5  43.9
# 4     2.507550e+09        5       0     6.0      26  32.2  45.2
# ...            ...      ...     ...     ...     ...   ...   ...
# 1619  2.507587e+09      974      94     5.0      26   0.0   0.0
# 1620  2.507587e+09      975       0     0.0      26   0.0   0.0
# 1621  2.507587e+09      785       0     0.0      31   0.0   0.0
# 1622  2.507531e+09        1       0     0.0      26   0.0   0.0
# 1623  2.507531e+09        1       0     0.0      31   0.0   0.0
#
#       expandedMinute      period          type  ... relatedPlayerId blockedX  \
# 0                  0   FirstHalf         Start  ...             NaN      NaN
# ...

# %%
events['match_string'] = match_string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [30], line 1
# ----> 1 events['match_string'] = match_string
#
# TypeError: list indices must be integers or slices, not str

# %%
#events['team_names'] = team_names

# %%
home_team_name
# Out:
# 'Liverpool'

# %%
# Create a dictionary mapping team IDs to team names
team_name = {
    home_teamID: home_team_name,
    away_teamID: away_team_name
}
#events['team_name'] = events['teamId'].map(team_name)




#events['team_names'] = team_names
# Out:
# {26: 'Liverpool', 167: 'Man City'}

# %%
events['playerName'] = events['playerId'].map(player_id)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [31], line 1
# ----> 1 events['playerName'] = events['playerId'].map(player_id)
#
# TypeError: list indices must be integers or slices, not str

# %%
events.playerName
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [32], line 1
# ----> 1 events.playerName
#
# AttributeError: 'list' object has no attribute 'playerName'

# %%
player_id
# Out:
# {'114147': 'Alisson',
#  '115916': 'Fabinho',
#  '96182': 'Roberto Firmino',
#  '74341': 'Joël Matip',
#  '108226': 'Mohamed Salah',
#  '345957': 'Ibrahima Konaté',
#  '301455': 'Konstantinos Tsimikas',
#  '322176': 'Caoimhín Kelleher',
#  '352825': 'Cody Gakpo',
#  '95408': 'Virgil van Dijk',
#  '235755': 'Diogo Jota',
#  '401385': 'Fábio Carvalho',
#  '444540': 'Stefan Bajcetic',
#  '400828': 'Darwin Núñez',
#  '4511': 'James Milner',
#  '318871': 'Trent Alexander-Arnold',
#  '363982': 'Harvey Elliott',
#  '68659': 'Jordan Henderson',
#  '84146': 'Alex Oxlade-Chamberlain',
#  '115726': 'Andrew Robertson',
#  '403693': 'João Gomes',
#  '355401': 'Rayan Aït-Nouri',
#  '123481': 'Mario Lemina',
#  '372724': 'Nathan Collins',
#  '108186': 'Raúl Jiménez',
#  '122714': 'José Sá',
#  '409730': 'Hugo Bueno',
#  '296363': 'Nélson Semedo',
#  '337916': 'Pedro Neto',
#  '300513': 'Daniel Podence',
#  '238244': 'Rúben Neves',
#  '16161': 'João Moutinho',
#  '394933': 'Matheus Nunes',
# ...

# %%
events.playerId
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [34], line 1
# ----> 1 events.playerId
#
# AttributeError: 'list' object has no attribute 'playerId'

# %%
def add_team_name(events_df, players_df):
""" Add team name to event data.

Function to add team name to whoscored event data, by extracting playerId and searching for team within whoscored
player data.

Args:
    events_df (pandas.DataFrame): whoscored-style dataframe of event data. Events can be from multiple matches.
    players_df (pandas.DataFrame): WhoScored-style dataframe of player information, can be from multiple matches.

Returns:
    pandas.DataFrame: whoscored-style event dataframe with additional 'team_name' column.
"""

# Initialise output dataframes
events_out = events.copy()
events_out['team_name'] = np.nan

# Get team name and add
events_out['player_name'] = events_out[['playerId', 'match_id']].apply(lambda x: players_df[players_df['match_id'] == x['match_id']].loc[x['playerId'], 'team'] if x['playerId'] == x['playerId'] else np.nan, axis=1)

return events_out

# %%
player_id_df
# Out:
#                     playerName  playerId
# 201755               Joelinton    201755
# 135891     Allan Saint-Maximin    135891
# 379732             Sven Botman    379732
# 303924          Miguel Almirón    303924
# 46092          Martin Dúbravka     46092
# 109227        Javier Manquillo    109227
# 299254          Alexander Isak    299254
# 82726             Fabian Schär     82726
# 83078          Kieran Trippier     83078
# 105171        Jamaal Lascelles    105171
# 105720               Nick Pope    105720
# 342811          Sean Longstaff    342811
# 349669          Anthony Gordon    349669
# 141486            Jacob Murphy    141486
# 82277                 Dan Burn     82277
# 134115           Callum Wilson    134115
# 402596         Elliot Anderson    402596
# 68648             Matt Ritchie     68648
# 112009            Paul Dummett    112009
# 350138             Jamal Lewis    350138
# 96182          Roberto Firmino     96182
# 114147                 Alisson    114147
# ...

# %%
events_df = events

# %%
def add_player_name(events_df, player_id):
    # Initialise output dataframes
    events_out = events_df.copy()
    events_out['playerName'] = np.nan

    # Map playerId to playerName
    events_out['playerName'] = player_id_df.set_index('playerId')['playerName'][events_out['playerId']].values
    events_out['playerName'] = events_out['playerName'].fillna('Unknown')

    return events_out

output_df = add_player_name(events_df, player_id_df)
print(output_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 12
#       8     events_out['playerName'] = events_out['playerName'].fillna('Unknown')
#      10     return events_out
# ---> 12 output_df = add_player_name(events_df, player_id_df)
#      13 print(output_df)
#
# NameError: name 'events_df' is not defined

# %%
events = events.rename(columns={'period':'matchPeriod'})

# %%
events = events.rename(columns={'minute':'matchminute'})

# %%
events = events.rename(columns={'second':'matchsecond'})

# %%
events
# Out:
#                 id  eventId  matchminute  matchsecond  teamId     x     y  \
# 0     2.507550e+09        3            0          0.0      26  49.9  50.0
# 1     2.507550e+09       10            0         32.0      26  44.8  55.7
# 2     2.507551e+09       35            2         32.0      26  38.9  19.4
# 3     2.507551e+09       36            2         32.0      26  38.9  19.4
# 4     2.507552e+09       66            5          2.0      26  28.0  21.8
# ...            ...      ...          ...          ...     ...   ...   ...
# 1605  2.507586e+09      955           92         20.0      26  43.6  34.4
# 1606  2.507586e+09      954           92         21.0      26  43.4  33.9
# 1607  2.507586e+09      956           92         23.0      26  46.5  53.6
# 1608  2.507586e+09      970           93         40.0      26  45.6  10.4
# 1609  2.507587e+09      972           93         54.0      26  60.6   6.6
#
#       expandedMinute matchPeriod    event_type  ... blockedY goalMouthZ  \
# ...

# %%
events.to_sql()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [37], line 1
# ----> 1 events.to_sql()
#
# TypeError: to_sql() missing 2 required positional arguments: 'name' and 'con'

# %%
events.to_csv("./Data/liverpool02_13eventdata.csv")

# %%
events.to_sql('event_data', con, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In [39], line 1
# ----> 1 events.to_sql('event_data', con, if_exists='replace')
#
# File ~/Documents/Coding Projects/lib/python3.9/site-packages/pandas/core/generic.py:2987, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2830 """
#    2831 Write records stored in a DataFrame to a SQL database.
#    2832
#    (...)
#    2983 [(1,), (None,), (2,)]
#    2984 """  # noqa:E501
#    2985 from pandas.io import sql
# -> 2987 return sql.to_sql(
#    2988     self,
#    2989     name,
#    2990     con,
#    2991     schema=schema,
#    2992     if_exists=if_exists,
#    2993     index=index,
#    2994     index_label=index_label,
#    2995     chunksize=chunksize,
#    2996     dtype=dtype,
#    2997     method=method,
#    2998 )
#
# ...
